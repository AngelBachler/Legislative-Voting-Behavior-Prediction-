# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET
from tqdm import tqdm

# --- 1. Descargar todas las legislaturas ---
url_legislaturas = "https://opendata.congreso.cl/wscamaradiputados.asmx/getLegislaturas"
response = requests.get(url_legislaturas)
response.raise_for_status()

root = ET.fromstring(response.content)

legislaturas = []
for leg in root.findall(".//{http://tempuri.org/}Legislatura"):
    legislaturas.append({
        "id_legislatura": leg.findtext("{http://tempuri.org/}ID"),
        "numero_legislatura": leg.findtext("{http://tempuri.org/}Numero"),
        "tipo_legislatura": leg.find("{http://tempuri.org/}Tipo").text,
        "codigo_tipo": leg.find("{http://tempuri.org/}Tipo").attrib.get("Codigo"),
        "fecha_inicio": leg.findtext("{http://tempuri.org/}FechaInicio"),
        "fecha_termino": leg.findtext("{http://tempuri.org/}FechaTermino")
    })

df_leg = pd.DataFrame(legislaturas)

print(f"✅ Legislaturas descargadas: {len(df_leg)}")

# --- 2. Descargar todas las sesiones por legislatura ---
all_sesiones = []

for _, row in tqdm(df_leg.iterrows(), total=len(df_leg), desc="Descargando sesiones"):
    leg_id = row["id_legislatura"]
    url_sesiones = f"https://opendata.congreso.cl/wscamaradiputados.asmx/getSesiones?prmLegislaturaID={leg_id}"
    
    try:
        res = requests.get(url_sesiones)
        res.raise_for_status()
        root_ses = ET.fromstring(res.content)
        
        for ses in root_ses.findall(".//{http://tempuri.org/}Sesion"):
            all_sesiones.append({
                "id_legislatura": leg_id,
                "numero_legislatura": row["numero_legislatura"],
                "id_sesion": ses.findtext("{http://tempuri.org/}ID"),
                "numero_sesion": ses.findtext("{http://tempuri.org/}Numero"),
                "fecha_inicio": ses.findtext("{http://tempuri.org/}Fecha"),
                "fecha_termino": ses.findtext("{http://tempuri.org/}FechaTermino"),
                "tipo_sesion": ses.find("{http://tempuri.org/}Tipo").text if ses.find("{http://tempuri.org/}Tipo") is not None else None,
                "codigo_tipo_sesion": ses.find("{http://tempuri.org/}Tipo").attrib.get("Codigo") if ses.find("{http://tempuri.org/}Tipo") is not None else None,
                "estado_sesion": ses.find("{http://tempuri.org/}Estado").text if ses.find("{http://tempuri.org/}Estado") is not None else None,
                "codigo_estado": ses.find("{http://tempuri.org/}Estado").attrib.get("Codigo") if ses.find("{http://tempuri.org/}Estado") is not None else None
            })
    
    except Exception as e:
        print(f"⚠️ Error al descargar sesiones para legislatura {leg_id}: {e}")

# --- 3. Crear DataFrame final ---
df_sesiones = pd.DataFrame(all_sesiones)

print(f"✅ Sesiones totales descargadas: {len(df_sesiones)}")
display(df_sesiones.head())
# Out:
# ✅ Legislaturas descargadas: 55
# Descargando sesiones: 100%|██████████| 55/55 [00:06<00:00,  8.06it/s]
# ✅ Sesiones totales descargadas: 4411
#   id_legislatura numero_legislatura id_sesion numero_sesion  \
# 0              3                319       850             2
# 1              3                319       851             3
# 2              3                319       852             5
# 3              3                319       853             6
# 4              3                319       854             7
#
#           fecha_inicio        fecha_termino tipo_sesion codigo_tipo_sesion  \
# 0  1990-03-20T15:01:00  1990-03-20T15:02:00   Ordinaria                 60
# 1  1990-03-21T00:00:00  1990-03-21T00:00:00   Ordinaria                 60
# 2  1990-03-28T00:00:00  1990-03-28T00:00:00   Ordinaria                 60
# 3  1990-04-03T15:00:00  1990-04-03T15:00:00   Ordinaria                 60
# 4  1990-04-04T00:00:00  1990-04-04T00:00:00   Ordinaria                 60
#
#   estado_sesion codigo_estado
# 0     Celebrada             1
# 1     Celebrada             1
# 2     Celebrada             1
# 3     Celebrada             1
# 4     Celebrada             1

# %%
import requests
import xml.etree.ElementTree as ET

# --- ID de sesión que quieres probar ---
sesion_id = 4714  # cámbialo por cualquier ID

# --- URL base del boletín ---
url_boletin = f"https://opendata.congreso.cl/wscamaradiputados.asmx/getSesionBoletinXML?prmSesionID={sesion_id}"

print(f"📥 Descargando boletín XML para sesión {sesion_id}...\n")

try:
    response = requests.get(url_boletin)
    response.raise_for_status()
    content = response.content.decode("utf-8", errors="replace").strip()

    # --- Intentar parsear el XML ---
    try:
        root = ET.fromstring(content)
        print(f"✅ XML bien formado para sesión {sesion_id}")
        print(f"Etiqueta raíz: {root.tag}")

    except ET.ParseError as e:
        print(f"❌ Error al parsear XML para sesión {sesion_id}: {e}")
        print("\n--- Contenido recibido ---\n")
        print(content[:1500])  # imprime los primeros 1500 caracteres
        print("\n--- Fin del contenido ---")

except Exception as e:
    print(f"⚠️ Error al descargar o abrir el XML para sesión {sesion_id}: {e}")
# Out:
# 📥 Descargando boletín XML para sesión 4714...
#
# ❌ Error al parsear XML para sesión 4714: no element found: line 1, column 38
#
# --- Contenido recibido ---
#
# <?xml version="1.0" encoding="utf-8"?>
#
# --- Fin del contenido ---

# %%
df_sesiones
# Out:
#      id_legislatura numero_legislatura id_sesion numero_sesion  \
# 0                 3                319       850             2
# 1                 3                319       851             3
# 2                 3                319       852             5
# 3                 3                319       853             6
# 4                 3                319       854             7
# ...             ...                ...       ...           ...
# 4406             57                373      4672            43
# 4407             57                373      4673            44
# 4408             57                373      4676            46
# 4409             57                373      4677            47
# 4410             57                373      4704            73
#
#              fecha_inicio        fecha_termino tipo_sesion codigo_tipo_sesion  \
# 0     1990-03-20T15:01:00  1990-03-20T15:02:00   Ordinaria                 60
# 1     1990-03-21T00:00:00  1990-03-21T00:00:00   Ordinaria                 60
# 2     1990-03-28T00:00:00  1990-03-28T00:00:00   Ordinaria                 60
# 3     1990-04-03T15:00:00  1990-04-03T15:00:00   Ordinaria                 60
# 4     1990-04-04T00:00:00  1990-04-04T00:00:00   Ordinaria                 60
# ...                   ...                  ...         ...                ...
# 4406  2025-07-01T10:05:41  2025-07-01T14:38:46   Ordinaria                 60
# 4407  2025-07-02T10:03:28  2025-07-02T14:05:33   Ordinaria                 60
# 4408  2025-07-08T10:05:16  2025-07-08T13:36:20   Ordinaria                 60
# 4409  2025-07-09T10:06:07  2025-07-09T14:12:41   Ordinaria                 60
# 4410  2025-09-29T16:31:23  2025-09-29T20:03:12   Ordinaria                 60
#
#      estado_sesion codigo_estado
# 0        Celebrada             1
# 1        Celebrada             1
# 2        Celebrada             1
# 3        Celebrada             1
# 4        Celebrada             1
# ...            ...           ...
# 4406     Celebrada             1
# 4407     Celebrada             1
# 4408     Celebrada             1
# 4409     Celebrada             1
# 4410     Celebrada             1
#
# [4411 rows x 10 columns]

# %%
import os
import requests
import xml.etree.ElementTree as ET
import pandas as pd
import xmltodict
import json
from datetime import datetime
from time import sleep

# -------------------------------
# Configuración de URLs y carpetas
# -------------------------------
URL_LEGISLATURAS = "https://opendata.congreso.cl/wscamaradiputados.asmx/getLegislaturas"
URL_SESIONES = "https://opendata.congreso.cl/wscamaradiputados.asmx/getSesiones?prmLegislaturaID={}"
URL_BOLETIN = "https://opendata.congreso.cl/wscamaradiputados.asmx/getSesionBoletinXML?prmSesionID={}"

base_dir = "boletines_json"
os.makedirs(base_dir, exist_ok=True)

# -------------------------------
# Función para limpiar nodos innecesarios
# -------------------------------
def clean_dict(data):
    """Elimina claves 'br' vacías o con solo None, recursivamente."""
    if isinstance(data, dict):
        cleaned = {}
        for k, v in data.items():
            if k == "br":
                # Omitir si es None, vacío o solo contiene None
                if v is None:
                    continue
                if isinstance(v, list) and all(x is None for x in v):
                    continue
            cleaned[k] = clean_dict(v)
        return cleaned
    elif isinstance(data, list):
        return [clean_dict(x) for x in data if x is not None]
    else:
        return data

# -------------------------------
# 1. Descargar lista de legislaturas
# -------------------------------
print("📘 Descargando lista de legislaturas...")
resp = requests.get(URL_LEGISLATURAS)
resp.raise_for_status()
root = ET.fromstring(resp.content)

legislaturas = []
for leg in root.findall(".//{http://tempuri.org/}Legislatura"):
    lid = int(leg.find("{http://tempuri.org/}ID").text)
    num = leg.find("{http://tempuri.org/}Numero").text
    tipo = leg.find("{http://tempuri.org/}Tipo").attrib.get("Codigo")
    legislaturas.append({"legislatura_id": lid, "numero": num, "tipo": tipo})

print(f"✅ Se encontraron {len(legislaturas)} legislaturas.\n")

# -------------------------------
# 2. Descargar sesiones y boletines válidos
# -------------------------------
records = []

for leg in legislaturas:
    lid = leg["legislatura_id"]
    numero_leg = leg["numero"]
    folder = os.path.join(base_dir, f"legislatura_{numero_leg}")
    os.makedirs(folder, exist_ok=True)

    print(f"📄 Descargando sesiones de legislatura {numero_leg} (ID {lid})...")

    try:
        res_ses = requests.get(URL_SESIONES.format(lid), timeout=20)
        res_ses.raise_for_status()
        root_ses = ET.fromstring(res_ses.content)
        sesiones = root_ses.findall(".//{http://tempuri.org/}Sesion")

        print(f"📌 {len(sesiones)} sesiones encontradas.\n")

        for ses in sesiones:
            sid = int(ses.find("{http://tempuri.org/}ID").text)
            num_sesion = ses.find("{http://tempuri.org/}Numero").text
            fecha = ses.find("{http://tempuri.org/}Fecha").text
            fecha_ter = ses.find("{http://tempuri.org/}FechaTermino").text
            tipo = ses.find("{http://tempuri.org/}Tipo").attrib.get("Codigo")
            estado = ses.find("{http://tempuri.org/}Estado").attrib.get("Codigo")

            print(f"📥 Verificando boletín XML para sesión {sid}...")

            try:
                res_boletin = requests.get(URL_BOLETIN.format(sid), timeout=25)
                res_boletin.raise_for_status()
                content = res_boletin.content.decode("utf-8", errors="replace").strip()

                # Si el contenido es demasiado corto, se descarta
                if len(content) < 100:
                    print(f"⚪ Boletín {sid} vacío, se omite.\n")
                    continue

                # Intentar parsear el XML
                try:
                    xml_parsed = xmltodict.parse(content)
                    estado_xml = "válido"
                except Exception:
                    print(f"⚠️ Error de formato en boletín {sid}, intentando reparar...")
                    try:
                        content_fixed = content.replace("&", "&amp;")
                        xml_parsed = xmltodict.parse(content_fixed)
                        estado_xml = "reparado"
                    except Exception:
                        print(f"❌ No se pudo reparar boletín {sid}.\n")
                        continue

                # Limpiar los nodos "br"
                xml_cleaned = clean_dict(xml_parsed)

                # Guardar como JSON con nombre por número de sesión
                json_path = os.path.join(folder, f"boletin_{num_sesion}.json")
                with open(json_path, "w", encoding="utf-8") as f:
                    json.dump(xml_cleaned, f, ensure_ascii=False, indent=2)

                print(f"✅ Guardado boletín sesión {num_sesion} ({estado_xml})\n")

                records.append({
                    "legislatura_id": lid,
                    "legislatura_numero": numero_leg,
                    "sesion_id": sid,
                    "numero_sesion": num_sesion,
                    "fecha_inicio": fecha,
                    "fecha_termino": fecha_ter,
                    "tipo_sesion": tipo,
                    "estado_sesion": estado,
                    "estado_xml": estado_xml,
                    "ruta_json": json_path,
                    "bytes": len(content.encode("utf-8")),
                    "fecha_descarga": datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                })

            except Exception as e:
                print(f"❌ Error descargando boletín sesión {sid}: {e}\n")

            sleep(0.5)

    except Exception as e:
        print(f"⚠️ Error procesando legislatura {numero_leg}: {e}\n")

# -------------------------------
# 3. Guardar dataset final
# -------------------------------
df = pd.DataFrame(records)
csv_path = os.path.join(base_dir, "dataset_boletines.csv")
df.to_csv(csv_path, index=False, encoding="utf-8")

print("\n✅ Descarga completa.")
print(f"📁 Archivos JSON guardados en: {os.path.abspath(base_dir)}")
print(f"🧾 Dataset total: {len(df)} boletines descargados.")
df.head()
# Out:
# 📘 Descargando lista de legislaturas...
# ✅ Se encontraron 55 legislaturas.
#
# 📄 Descargando sesiones de legislatura 319 (ID 3)...
# 📌 22 sesiones encontradas.
#
# 📥 Verificando boletín XML para sesión 850...
# ⚪ Boletín 850 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 851...
# ⚪ Boletín 851 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 852...
# ⚪ Boletín 852 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 853...
# ⚪ Boletín 853 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 854...
# ⚪ Boletín 854 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 855...
# ⚪ Boletín 855 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 856...
# ⚪ Boletín 856 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 857...
# ⚪ Boletín 857 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 858...
# ⚪ Boletín 858 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 859...
# ⚪ Boletín 859 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 860...
# ⚪ Boletín 860 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 861...
# ⚪ Boletín 861 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 862...
# ⚪ Boletín 862 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 863...
# ⚪ Boletín 863 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 864...
# ⚪ Boletín 864 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 865...
# ⚪ Boletín 865 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 866...
# ⚪ Boletín 866 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2402...
# ⚪ Boletín 2402 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2403...
# ⚪ Boletín 2403 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2404...
# ⚪ Boletín 2404 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2408...
# ⚪ Boletín 2408 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2407...
# ⚪ Boletín 2407 vacío, se omite.
#
# 📄 Descargando sesiones de legislatura 320 (ID 4)...
# 📌 35 sesiones encontradas.
#
# 📥 Verificando boletín XML para sesión 868...
# ⚪ Boletín 868 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 869...
# ⚪ Boletín 869 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 870...
# ⚪ Boletín 870 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 872...
# ⚪ Boletín 872 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 873...
# ⚪ Boletín 873 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 874...
# ⚪ Boletín 874 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 876...
# ⚪ Boletín 876 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 877...
# ⚪ Boletín 877 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 878...
# ⚪ Boletín 878 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 880...
# ⚪ Boletín 880 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 881...
# ⚪ Boletín 881 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 882...
# ⚪ Boletín 882 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 884...
# ⚪ Boletín 884 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 885...
# ⚪ Boletín 885 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 886...
# ⚪ Boletín 886 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 888...
# ⚪ Boletín 888 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 889...
# ⚪ Boletín 889 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 890...
# ⚪ Boletín 890 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 892...
# ⚪ Boletín 892 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 893...
# ⚪ Boletín 893 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 894...
# ⚪ Boletín 894 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 896...
# ⚪ Boletín 896 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 897...
# ⚪ Boletín 897 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 898...
# ⚪ Boletín 898 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 883...
# ⚪ Boletín 883 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 887...
# ⚪ Boletín 887 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 891...
# ⚪ Boletín 891 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 895...
# ⚪ Boletín 895 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 899...
# ⚪ Boletín 899 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 867...
# ⚪ Boletín 867 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 871...
# ⚪ Boletín 871 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 875...
# ⚪ Boletín 875 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 879...
# ⚪ Boletín 879 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2412...
# ⚪ Boletín 2412 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2547...
# ⚪ Boletín 2547 vacío, se omite.
#
# 📄 Descargando sesiones de legislatura 321 (ID 5)...
# 📌 57 sesiones encontradas.
#
# 📥 Verificando boletín XML para sesión 900...
# ⚪ Boletín 900 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 901...
# ⚪ Boletín 901 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 902...
# ⚪ Boletín 902 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 904...
# ⚪ Boletín 904 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 905...
# ⚪ Boletín 905 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 906...
# ⚪ Boletín 906 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 908...
# ⚪ Boletín 908 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 909...
# ⚪ Boletín 909 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 910...
# ⚪ Boletín 910 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 912...
# ⚪ Boletín 912 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 913...
# ⚪ Boletín 913 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 914...
# ⚪ Boletín 914 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 916...
# ⚪ Boletín 916 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 917...
# ⚪ Boletín 917 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 918...
# ⚪ Boletín 918 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 920...
# ⚪ Boletín 920 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 921...
# ⚪ Boletín 921 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 922...
# ⚪ Boletín 922 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 924...
# ⚪ Boletín 924 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 925...
# ⚪ Boletín 925 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 926...
# ⚪ Boletín 926 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 928...
# ⚪ Boletín 928 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 929...
# ⚪ Boletín 929 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 930...
# ⚪ Boletín 930 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 932...
# ⚪ Boletín 932 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 933...
# ⚪ Boletín 933 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 934...
# ⚪ Boletín 934 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 936...
# ⚪ Boletín 936 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 937...
# ⚪ Boletín 937 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 938...
# ⚪ Boletín 938 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 940...
# ⚪ Boletín 940 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 941...
# ⚪ Boletín 941 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 942...
# ⚪ Boletín 942 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 944...
# ⚪ Boletín 944 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 903...
# ⚪ Boletín 903 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 907...
# ⚪ Boletín 907 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 911...
# ⚪ Boletín 911 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 915...
# ⚪ Boletín 915 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 919...
# ⚪ Boletín 919 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 923...
# ⚪ Boletín 923 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 927...
# ⚪ Boletín 927 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 931...
# ⚪ Boletín 931 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 935...
# ⚪ Boletín 935 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 939...
# ⚪ Boletín 939 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 943...
# ⚪ Boletín 943 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2544...
# ⚪ Boletín 2544 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2545...
# ⚪ Boletín 2545 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2548...
# ⚪ Boletín 2548 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2549...
# ⚪ Boletín 2549 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2550...
# ⚪ Boletín 2550 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2552...
# ⚪ Boletín 2552 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2553...
# ⚪ Boletín 2553 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2554...
# ⚪ Boletín 2554 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2555...
# ⚪ Boletín 2555 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2556...
# ⚪ Boletín 2556 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2557...
# ⚪ Boletín 2557 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2546...
# ⚪ Boletín 2546 vacío, se omite.
#
# 📄 Descargando sesiones de legislatura 322 (ID 6)...
# 📌 41 sesiones encontradas.
#
# 📥 Verificando boletín XML para sesión 72...
# ✅ Guardado boletín sesión 1 (válido)
#
# 📥 Verificando boletín XML para sesión 73...
# ✅ Guardado boletín sesión 2 (válido)
#
# 📥 Verificando boletín XML para sesión 74...
# ✅ Guardado boletín sesión 3 (válido)
#
# 📥 Verificando boletín XML para sesión 75...
# ✅ Guardado boletín sesión 4 (válido)
#
# 📥 Verificando boletín XML para sesión 76...
# ✅ Guardado boletín sesión 5 (válido)
#
# 📥 Verificando boletín XML para sesión 77...
# ✅ Guardado boletín sesión 6 (válido)
#
# 📥 Verificando boletín XML para sesión 78...
# ✅ Guardado boletín sesión 7 (válido)
#
# 📥 Verificando boletín XML para sesión 79...
# ✅ Guardado boletín sesión 8 (válido)
#
# 📥 Verificando boletín XML para sesión 80...
# ✅ Guardado boletín sesión 9 (válido)
#
# 📥 Verificando boletín XML para sesión 81...
# ✅ Guardado boletín sesión 10 (válido)
#
# 📥 Verificando boletín XML para sesión 82...
# ✅ Guardado boletín sesión 11 (válido)
#
# 📥 Verificando boletín XML para sesión 83...
# ✅ Guardado boletín sesión 12 (válido)
#
# 📥 Verificando boletín XML para sesión 84...
# ✅ Guardado boletín sesión 13 (válido)
#
# 📥 Verificando boletín XML para sesión 85...
# ✅ Guardado boletín sesión 14 (válido)
#
# 📥 Verificando boletín XML para sesión 86...
# ✅ Guardado boletín sesión 15 (válido)
#
# 📥 Verificando boletín XML para sesión 87...
# ✅ Guardado boletín sesión 16 (válido)
#
# 📥 Verificando boletín XML para sesión 88...
# ✅ Guardado boletín sesión 17 (válido)
#
# 📥 Verificando boletín XML para sesión 89...
# ✅ Guardado boletín sesión 18 (válido)
#
# 📥 Verificando boletín XML para sesión 90...
# ✅ Guardado boletín sesión 19 (válido)
#
# 📥 Verificando boletín XML para sesión 91...
# ✅ Guardado boletín sesión 20 (válido)
#
# 📥 Verificando boletín XML para sesión 92...
# ✅ Guardado boletín sesión 21 (válido)
#
# 📥 Verificando boletín XML para sesión 93...
# ✅ Guardado boletín sesión 22 (válido)
#
# 📥 Verificando boletín XML para sesión 94...
# ✅ Guardado boletín sesión 23 (válido)
#
# 📥 Verificando boletín XML para sesión 95...
# ✅ Guardado boletín sesión 24 (válido)
#
# 📥 Verificando boletín XML para sesión 96...
# ✅ Guardado boletín sesión 25 (válido)
#
# 📥 Verificando boletín XML para sesión 97...
# ✅ Guardado boletín sesión 26 (válido)
#
# 📥 Verificando boletín XML para sesión 99...
# ✅ Guardado boletín sesión 28 (válido)
#
# 📥 Verificando boletín XML para sesión 100...
# ✅ Guardado boletín sesión 29 (válido)
#
# 📥 Verificando boletín XML para sesión 101...
# ✅ Guardado boletín sesión 30 (válido)
#
# 📥 Verificando boletín XML para sesión 103...
# ✅ Guardado boletín sesión 32 (válido)
#
# 📥 Verificando boletín XML para sesión 104...
# ✅ Guardado boletín sesión 33 (válido)
#
# 📥 Verificando boletín XML para sesión 105...
# ✅ Guardado boletín sesión 34 (válido)
#
# 📥 Verificando boletín XML para sesión 107...
# ✅ Guardado boletín sesión 36 (válido)
#
# 📥 Verificando boletín XML para sesión 108...
# ✅ Guardado boletín sesión 37 (válido)
#
# 📥 Verificando boletín XML para sesión 109...
# ✅ Guardado boletín sesión 38 (válido)
#
# 📥 Verificando boletín XML para sesión 111...
# ✅ Guardado boletín sesión 40 (válido)
#
# 📥 Verificando boletín XML para sesión 112...
# ✅ Guardado boletín sesión 41 (válido)
#
# 📥 Verificando boletín XML para sesión 98...
# ✅ Guardado boletín sesión 27 (válido)
#
# 📥 Verificando boletín XML para sesión 102...
# ✅ Guardado boletín sesión 31 (válido)
#
# 📥 Verificando boletín XML para sesión 106...
# ✅ Guardado boletín sesión 35 (válido)
#
# 📥 Verificando boletín XML para sesión 110...
# ✅ Guardado boletín sesión 39 (válido)
#
# 📄 Descargando sesiones de legislatura 323 (ID 7)...
# 📌 77 sesiones encontradas.
#
# 📥 Verificando boletín XML para sesión 945...
# ✅ Guardado boletín sesión 3 (válido)
#
# 📥 Verificando boletín XML para sesión 946...
# ✅ Guardado boletín sesión 4 (válido)
#
# 📥 Verificando boletín XML para sesión 948...
# ✅ Guardado boletín sesión 8 (válido)
#
# 📥 Verificando boletín XML para sesión 949...
# ✅ Guardado boletín sesión 9 (válido)
#
# 📥 Verificando boletín XML para sesión 950...
# ✅ Guardado boletín sesión 12 (válido)
#
# 📥 Verificando boletín XML para sesión 952...
# ✅ Guardado boletín sesión 20 (válido)
#
# 📥 Verificando boletín XML para sesión 953...
# ✅ Guardado boletín sesión 22 (válido)
#
# 📥 Verificando boletín XML para sesión 954...
# ✅ Guardado boletín sesión 23 (válido)
#
# 📥 Verificando boletín XML para sesión 956...
# ✅ Guardado boletín sesión 25 (válido)
#
# 📥 Verificando boletín XML para sesión 957...
# ✅ Guardado boletín sesión 27 (válido)
#
# 📥 Verificando boletín XML para sesión 958...
# ✅ Guardado boletín sesión 28 (válido)
#
# 📥 Verificando boletín XML para sesión 960...
# ✅ Guardado boletín sesión 31 (válido)
#
# 📥 Verificando boletín XML para sesión 961...
# ✅ Guardado boletín sesión 32 (válido)
#
# 📥 Verificando boletín XML para sesión 962...
# ✅ Guardado boletín sesión 34 (válido)
#
# 📥 Verificando boletín XML para sesión 964...
# ✅ Guardado boletín sesión 37 (válido)
#
# 📥 Verificando boletín XML para sesión 965...
# ✅ Guardado boletín sesión 38 (válido)
#
# 📥 Verificando boletín XML para sesión 966...
# ⚪ Boletín 966 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 968...
# ✅ Guardado boletín sesión 41 (válido)
#
# 📥 Verificando boletín XML para sesión 969...
# ✅ Guardado boletín sesión 42 (válido)
#
# 📥 Verificando boletín XML para sesión 970...
# ✅ Guardado boletín sesión 43 (válido)
#
# 📥 Verificando boletín XML para sesión 972...
# ✅ Guardado boletín sesión 45 (válido)
#
# 📥 Verificando boletín XML para sesión 973...
# ✅ Guardado boletín sesión 46 (válido)
#
# 📥 Verificando boletín XML para sesión 974...
# ⚪ Boletín 974 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 976...
# ⚪ Boletín 976 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 977...
# ✅ Guardado boletín sesión 50 (válido)
#
# 📥 Verificando boletín XML para sesión 978...
# ✅ Guardado boletín sesión 51 (válido)
#
# 📥 Verificando boletín XML para sesión 980...
# ✅ Guardado boletín sesión 53 (válido)
#
# 📥 Verificando boletín XML para sesión 981...
# ⚪ Boletín 981 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 982...
# ⚪ Boletín 982 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 983...
# ✅ Guardado boletín sesión 57 (válido)
#
# 📥 Verificando boletín XML para sesión 984...
# ✅ Guardado boletín sesión 58 (válido)
#
# 📥 Verificando boletín XML para sesión 985...
# ✅ Guardado boletín sesión 59 (válido)
#
# 📥 Verificando boletín XML para sesión 986...
# ✅ Guardado boletín sesión 60 (válido)
#
# 📥 Verificando boletín XML para sesión 987...
# ✅ Guardado boletín sesión 61 (válido)
#
# 📥 Verificando boletín XML para sesión 988...
# ✅ Guardado boletín sesión 62 (válido)
#
# 📥 Verificando boletín XML para sesión 989...
# ✅ Guardado boletín sesión 63 (válido)
#
# 📥 Verificando boletín XML para sesión 990...
# ✅ Guardado boletín sesión 64 (válido)
#
# 📥 Verificando boletín XML para sesión 991...
# ✅ Guardado boletín sesión 65 (válido)
#
# 📥 Verificando boletín XML para sesión 992...
# ✅ Guardado boletín sesión 66 (válido)
#
# 📥 Verificando boletín XML para sesión 993...
# ⚪ Boletín 993 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 994...
# ⚪ Boletín 994 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 995...
# ⚪ Boletín 995 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 996...
# ⚪ Boletín 996 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 997...
# ⚪ Boletín 997 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 998...
# ⚪ Boletín 998 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1000...
# ⚪ Boletín 1000 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1001...
# ⚪ Boletín 1001 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1002...
# ⚪ Boletín 1002 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 947...
# ✅ Guardado boletín sesión 6 (válido)
#
# 📥 Verificando boletín XML para sesión 951...
# ✅ Guardado boletín sesión 16 (válido)
#
# 📥 Verificando boletín XML para sesión 955...
# ✅ Guardado boletín sesión 24 (válido)
#
# 📥 Verificando boletín XML para sesión 959...
# ✅ Guardado boletín sesión 29 (válido)
#
# 📥 Verificando boletín XML para sesión 963...
# ✅ Guardado boletín sesión 36 (válido)
#
# 📥 Verificando boletín XML para sesión 967...
# ⚪ Boletín 967 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2447...
# ⚪ Boletín 2447 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2569...
# ✅ Guardado boletín sesión 17 (válido)
#
# 📥 Verificando boletín XML para sesión 971...
# ⚪ Boletín 971 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 975...
# ✅ Guardado boletín sesión 48 (válido)
#
# 📥 Verificando boletín XML para sesión 979...
# ✅ Guardado boletín sesión 52 (válido)
#
# 📥 Verificando boletín XML para sesión 999...
# ⚪ Boletín 999 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2564...
# ✅ Guardado boletín sesión 10 (válido)
#
# 📥 Verificando boletín XML para sesión 2565...
# ✅ Guardado boletín sesión 11 (válido)
#
# 📥 Verificando boletín XML para sesión 2566...
# ✅ Guardado boletín sesión 14 (válido)
#
# 📥 Verificando boletín XML para sesión 2570...
# ✅ Guardado boletín sesión 19 (válido)
#
# 📥 Verificando boletín XML para sesión 2571...
# ✅ Guardado boletín sesión 21 (válido)
#
# 📥 Verificando boletín XML para sesión 2572...
# ✅ Guardado boletín sesión 30 (válido)
#
# 📥 Verificando boletín XML para sesión 2573...
# ✅ Guardado boletín sesión 35 (válido)
#
# 📥 Verificando boletín XML para sesión 2576...
# ✅ Guardado boletín sesión 15 (válido)
#
# 📥 Verificando boletín XML para sesión 2577...
# ✅ Guardado boletín sesión 18 (válido)
#
# 📥 Verificando boletín XML para sesión 2578...
# ✅ Guardado boletín sesión 26 (válido)
#
# 📥 Verificando boletín XML para sesión 2579...
# ✅ Guardado boletín sesión 33 (válido)
#
# 📥 Verificando boletín XML para sesión 2560...
# ✅ Guardado boletín sesión 1 (válido)
#
# 📥 Verificando boletín XML para sesión 2561...
# ✅ Guardado boletín sesión 2 (válido)
#
# 📥 Verificando boletín XML para sesión 2562...
# ✅ Guardado boletín sesión 5 (válido)
#
# 📥 Verificando boletín XML para sesión 2563...
# ✅ Guardado boletín sesión 7 (válido)
#
# 📥 Verificando boletín XML para sesión 2568...
# ✅ Guardado boletín sesión 13 (válido)
#
# 📥 Verificando boletín XML para sesión 2974...
# ✅ Guardado boletín sesión 56 (válido)
#
# 📄 Descargando sesiones de legislatura 324 (ID 8)...
# 📌 43 sesiones encontradas.
#
# 📥 Verificando boletín XML para sesión 1004...
# ✅ Guardado boletín sesión 2 (válido)
#
# 📥 Verificando boletín XML para sesión 1005...
# ✅ Guardado boletín sesión 3 (válido)
#
# 📥 Verificando boletín XML para sesión 1006...
# ✅ Guardado boletín sesión 4 (válido)
#
# 📥 Verificando boletín XML para sesión 1008...
# ⚪ Boletín 1008 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1009...
# ⚪ Boletín 1009 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1010...
# ✅ Guardado boletín sesión 9 (válido)
#
# 📥 Verificando boletín XML para sesión 1012...
# ⚪ Boletín 1012 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1013...
# ⚪ Boletín 1013 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1014...
# ✅ Guardado boletín sesión 13 (válido)
#
# 📥 Verificando boletín XML para sesión 1016...
# ⚪ Boletín 1016 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1017...
# ✅ Guardado boletín sesión 17 (válido)
#
# 📥 Verificando boletín XML para sesión 1018...
# ✅ Guardado boletín sesión 18 (válido)
#
# 📥 Verificando boletín XML para sesión 1020...
# ⚪ Boletín 1020 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1021...
# ⚪ Boletín 1021 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1022...
# ⚪ Boletín 1022 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1024...
# ⚪ Boletín 1024 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1025...
# ✅ Guardado boletín sesión 29 (válido)
#
# 📥 Verificando boletín XML para sesión 1026...
# ⚪ Boletín 1026 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1028...
# ⚪ Boletín 1028 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1029...
# ⚪ Boletín 1029 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1030...
# ⚪ Boletín 1030 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1032...
# ⚪ Boletín 1032 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1033...
# ⚪ Boletín 1033 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1034...
# ✅ Guardado boletín sesión 39 (válido)
#
# 📥 Verificando boletín XML para sesión 1036...
# ⚪ Boletín 1036 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1003...
# ⚪ Boletín 1003 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1007...
# ✅ Guardado boletín sesión 6 (válido)
#
# 📥 Verificando boletín XML para sesión 1011...
# ⚪ Boletín 1011 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1015...
# ✅ Guardado boletín sesión 14 (válido)
#
# 📥 Verificando boletín XML para sesión 1019...
# ⚪ Boletín 1019 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1023...
# ✅ Guardado boletín sesión 23 (válido)
#
# 📥 Verificando boletín XML para sesión 1027...
# ⚪ Boletín 1027 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1031...
# ⚪ Boletín 1031 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1035...
# ⚪ Boletín 1035 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2581...
# ✅ Guardado boletín sesión 5 (válido)
#
# 📥 Verificando boletín XML para sesión 2582...
# ⚪ Boletín 2582 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2583...
# ✅ Guardado boletín sesión 24 (válido)
#
# 📥 Verificando boletín XML para sesión 2584...
# ⚪ Boletín 2584 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2585...
# ⚪ Boletín 2585 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2586...
# ⚪ Boletín 2586 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2587...
# ⚪ Boletín 2587 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2588...
# ✅ Guardado boletín sesión 41 (válido)
#
# 📥 Verificando boletín XML para sesión 2590...
# ✅ Guardado boletín sesión 42 (válido)
#
# 📄 Descargando sesiones de legislatura 325 (ID 9)...
# 📌 78 sesiones encontradas.
#
# 📥 Verificando boletín XML para sesión 1037...
# ⚪ Boletín 1037 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1038...
# ✅ Guardado boletín sesión 3 (válido)
#
# 📥 Verificando boletín XML para sesión 1040...
# ✅ Guardado boletín sesión 6 (válido)
#
# 📥 Verificando boletín XML para sesión 1041...
# ✅ Guardado boletín sesión 7 (válido)
#
# 📥 Verificando boletín XML para sesión 1042...
# ✅ Guardado boletín sesión 8 (válido)
#
# 📥 Verificando boletín XML para sesión 1044...
# ✅ Guardado boletín sesión 11 (válido)
#
# 📥 Verificando boletín XML para sesión 1045...
# ⚪ Boletín 1045 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1046...
# ⚪ Boletín 1046 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1048...
# ⚪ Boletín 1048 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1049...
# ⚪ Boletín 1049 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1050...
# ✅ Guardado boletín sesión 20 (válido)
#
# 📥 Verificando boletín XML para sesión 1052...
# ⚪ Boletín 1052 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1053...
# ⚪ Boletín 1053 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1054...
# ⚪ Boletín 1054 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1056...
# ✅ Guardado boletín sesión 27 (válido)
#
# 📥 Verificando boletín XML para sesión 1057...
# ✅ Guardado boletín sesión 29 (válido)
#
# 📥 Verificando boletín XML para sesión 1058...
# ✅ Guardado boletín sesión 30 (válido)
#
# 📥 Verificando boletín XML para sesión 1060...
# ✅ Guardado boletín sesión 32 (válido)
#
# 📥 Verificando boletín XML para sesión 1061...
# ✅ Guardado boletín sesión 33 (válido)
#
# 📥 Verificando boletín XML para sesión 1062...
# ✅ Guardado boletín sesión 34 (válido)
#
# 📥 Verificando boletín XML para sesión 1064...
# ✅ Guardado boletín sesión 36 (válido)
#
# 📥 Verificando boletín XML para sesión 1065...
# ✅ Guardado boletín sesión 37 (válido)
#
# 📥 Verificando boletín XML para sesión 1066...
# ✅ Guardado boletín sesión 39 (válido)
#
# 📥 Verificando boletín XML para sesión 1068...
# ✅ Guardado boletín sesión 41 (válido)
#
# 📥 Verificando boletín XML para sesión 1069...
# ⚪ Boletín 1069 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1070...
# ✅ Guardado boletín sesión 43 (válido)
#
# 📥 Verificando boletín XML para sesión 1072...
# ✅ Guardado boletín sesión 45 (válido)
#
# 📥 Verificando boletín XML para sesión 1073...
# ✅ Guardado boletín sesión 46 (válido)
#
# 📥 Verificando boletín XML para sesión 1074...
# ✅ Guardado boletín sesión 47 (válido)
#
# 📥 Verificando boletín XML para sesión 1076...
# ✅ Guardado boletín sesión 49 (válido)
#
# 📥 Verificando boletín XML para sesión 1077...
# ✅ Guardado boletín sesión 50 (válido)
#
# 📥 Verificando boletín XML para sesión 1078...
# ✅ Guardado boletín sesión 51 (válido)
#
# 📥 Verificando boletín XML para sesión 1080...
# ✅ Guardado boletín sesión 54 (válido)
#
# 📥 Verificando boletín XML para sesión 1081...
# ✅ Guardado boletín sesión 55 (válido)
#
# 📥 Verificando boletín XML para sesión 1082...
# ✅ Guardado boletín sesión 56 (válido)
#
# 📥 Verificando boletín XML para sesión 1084...
# ✅ Guardado boletín sesión 58 (válido)
#
# 📥 Verificando boletín XML para sesión 1085...
# ✅ Guardado boletín sesión 59 (válido)
#
# 📥 Verificando boletín XML para sesión 1086...
# ✅ Guardado boletín sesión 60 (válido)
#
# 📥 Verificando boletín XML para sesión 1088...
# ✅ Guardado boletín sesión 62 (válido)
#
# 📥 Verificando boletín XML para sesión 1089...
# ✅ Guardado boletín sesión 63 (válido)
#
# 📥 Verificando boletín XML para sesión 1090...
# ✅ Guardado boletín sesión 64 (válido)
#
# 📥 Verificando boletín XML para sesión 1092...
# ✅ Guardado boletín sesión 66 (válido)
#
# 📥 Verificando boletín XML para sesión 1093...
# ✅ Guardado boletín sesión 68 (válido)
#
# 📥 Verificando boletín XML para sesión 1094...
# ✅ Guardado boletín sesión 69 (válido)
#
# 📥 Verificando boletín XML para sesión 1096...
# ✅ Guardado boletín sesión 71 (válido)
#
# 📥 Verificando boletín XML para sesión 1097...
# ✅ Guardado boletín sesión 72 (válido)
#
# 📥 Verificando boletín XML para sesión 1098...
# ✅ Guardado boletín sesión 73 (válido)
#
# 📥 Verificando boletín XML para sesión 1100...
# ⚪ Boletín 1100 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1101...
# ⚪ Boletín 1101 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1102...
# ✅ Guardado boletín sesión 78 (válido)
#
# 📥 Verificando boletín XML para sesión 1039...
# ✅ Guardado boletín sesión 5 (válido)
#
# 📥 Verificando boletín XML para sesión 1043...
# ✅ Guardado boletín sesión 9 (válido)
#
# 📥 Verificando boletín XML para sesión 1047...
# ⚪ Boletín 1047 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1051...
# ⚪ Boletín 1051 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1055...
# ✅ Guardado boletín sesión 26 (válido)
#
# 📥 Verificando boletín XML para sesión 1059...
# ✅ Guardado boletín sesión 31 (válido)
#
# 📥 Verificando boletín XML para sesión 1063...
# ✅ Guardado boletín sesión 35 (válido)
#
# 📥 Verificando boletín XML para sesión 1067...
# ✅ Guardado boletín sesión 40 (válido)
#
# 📥 Verificando boletín XML para sesión 1071...
# ✅ Guardado boletín sesión 44 (válido)
#
# 📥 Verificando boletín XML para sesión 1075...
# ✅ Guardado boletín sesión 48 (válido)
#
# 📥 Verificando boletín XML para sesión 1079...
# ✅ Guardado boletín sesión 53 (válido)
#
# 📥 Verificando boletín XML para sesión 1083...
# ✅ Guardado boletín sesión 57 (válido)
#
# 📥 Verificando boletín XML para sesión 1087...
# ✅ Guardado boletín sesión 61 (válido)
#
# 📥 Verificando boletín XML para sesión 1091...
# ✅ Guardado boletín sesión 65 (válido)
#
# 📥 Verificando boletín XML para sesión 1095...
# ✅ Guardado boletín sesión 70 (válido)
#
# 📥 Verificando boletín XML para sesión 1099...
# ⚪ Boletín 1099 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2531...
# ✅ Guardado boletín sesión 2 (válido)
#
# 📥 Verificando boletín XML para sesión 2532...
# ✅ Guardado boletín sesión 4 (válido)
#
# 📥 Verificando boletín XML para sesión 2533...
# ✅ Guardado boletín sesión 10 (válido)
#
# 📥 Verificando boletín XML para sesión 2534...
# ⚪ Boletín 2534 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2535...
# ⚪ Boletín 2535 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2536...
# ⚪ Boletín 2536 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2537...
# ✅ Guardado boletín sesión 24 (válido)
#
# 📥 Verificando boletín XML para sesión 2538...
# ✅ Guardado boletín sesión 28 (válido)
#
# 📥 Verificando boletín XML para sesión 2539...
# ✅ Guardado boletín sesión 38 (válido)
#
# 📥 Verificando boletín XML para sesión 2540...
# ✅ Guardado boletín sesión 52 (válido)
#
# 📥 Verificando boletín XML para sesión 2541...
# ⚪ Boletín 2541 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2542...
# ⚪ Boletín 2542 vacío, se omite.
#
# 📄 Descargando sesiones de legislatura 326 (ID 10)...
# 📌 39 sesiones encontradas.
#
# 📥 Verificando boletín XML para sesión 1104...
# ✅ Guardado boletín sesión 2 (válido)
#
# 📥 Verificando boletín XML para sesión 1105...
# ✅ Guardado boletín sesión 3 (válido)
#
# 📥 Verificando boletín XML para sesión 1106...
# ✅ Guardado boletín sesión 4 (válido)
#
# 📥 Verificando boletín XML para sesión 1108...
# ✅ Guardado boletín sesión 6 (válido)
#
# 📥 Verificando boletín XML para sesión 1109...
# ✅ Guardado boletín sesión 7 (válido)
#
# 📥 Verificando boletín XML para sesión 1110...
# ✅ Guardado boletín sesión 8 (válido)
#
# 📥 Verificando boletín XML para sesión 1112...
# ✅ Guardado boletín sesión 11 (válido)
#
# 📥 Verificando boletín XML para sesión 1113...
# ✅ Guardado boletín sesión 12 (válido)
#
# 📥 Verificando boletín XML para sesión 1125...
# ✅ Guardado boletín sesión 29 (válido)
#
# 📥 Verificando boletín XML para sesión 1126...
# ✅ Guardado boletín sesión 30 (válido)
#
# 📥 Verificando boletín XML para sesión 1127...
# ✅ Guardado boletín sesión 31 (válido)
#
# 📥 Verificando boletín XML para sesión 1128...
# ✅ Guardado boletín sesión 33 (válido)
#
# 📥 Verificando boletín XML para sesión 1129...
# ✅ Guardado boletín sesión 34 (válido)
#
# 📥 Verificando boletín XML para sesión 1130...
# ✅ Guardado boletín sesión 36 (válido)
#
# 📥 Verificando boletín XML para sesión 1131...
# ✅ Guardado boletín sesión 37 (válido)
#
# 📥 Verificando boletín XML para sesión 1132...
# ✅ Guardado boletín sesión 39 (válido)
#
# 📥 Verificando boletín XML para sesión 1115...
# ✅ Guardado boletín sesión 14 (válido)
#
# 📥 Verificando boletín XML para sesión 1116...
# ✅ Guardado boletín sesión 15 (válido)
#
# 📥 Verificando boletín XML para sesión 1117...
# ✅ Guardado boletín sesión 18 (válido)
#
# 📥 Verificando boletín XML para sesión 1119...
# ✅ Guardado boletín sesión 21 (válido)
#
# 📥 Verificando boletín XML para sesión 1120...
# ⚪ Boletín 1120 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1121...
# ✅ Guardado boletín sesión 24 (válido)
#
# 📥 Verificando boletín XML para sesión 1123...
# ✅ Guardado boletín sesión 27 (válido)
#
# 📥 Verificando boletín XML para sesión 1124...
# ✅ Guardado boletín sesión 28 (válido)
#
# 📥 Verificando boletín XML para sesión 2302...
# ✅ Guardado boletín sesión 10 (válido)
#
# 📥 Verificando boletín XML para sesión 2303...
# ✅ Guardado boletín sesión 16 (válido)
#
# 📥 Verificando boletín XML para sesión 2305...
# ✅ Guardado boletín sesión 20 (válido)
#
# 📥 Verificando boletín XML para sesión 2306...
# ✅ Guardado boletín sesión 23 (válido)
#
# 📥 Verificando boletín XML para sesión 2307...
# ✅ Guardado boletín sesión 26 (válido)
#
# 📥 Verificando boletín XML para sesión 2309...
# ✅ Guardado boletín sesión 35 (válido)
#
# 📥 Verificando boletín XML para sesión 2310...
# ✅ Guardado boletín sesión 38 (válido)
#
# 📥 Verificando boletín XML para sesión 1103...
# ✅ Guardado boletín sesión 1 (válido)
#
# 📥 Verificando boletín XML para sesión 1107...
# ✅ Guardado boletín sesión 5 (válido)
#
# 📥 Verificando boletín XML para sesión 1111...
# ✅ Guardado boletín sesión 9 (válido)
#
# 📥 Verificando boletín XML para sesión 1114...
# ✅ Guardado boletín sesión 13 (válido)
#
# 📥 Verificando boletín XML para sesión 1118...
# ✅ Guardado boletín sesión 19 (válido)
#
# 📥 Verificando boletín XML para sesión 1122...
# ✅ Guardado boletín sesión 25 (válido)
#
# 📥 Verificando boletín XML para sesión 2304...
# ✅ Guardado boletín sesión 17 (válido)
#
# 📥 Verificando boletín XML para sesión 2308...
# ✅ Guardado boletín sesión 32 (válido)
#
# 📄 Descargando sesiones de legislatura 327 (ID 11)...
# 📌 37 sesiones encontradas.
#
# 📥 Verificando boletín XML para sesión 1133...
# ✅ Guardado boletín sesión 1 (válido)
#
# 📥 Verificando boletín XML para sesión 1134...
# ✅ Guardado boletín sesión 3 (válido)
#
# 📥 Verificando boletín XML para sesión 1135...
# ✅ Guardado boletín sesión 4 (válido)
#
# 📥 Verificando boletín XML para sesión 1136...
# ✅ Guardado boletín sesión 6 (válido)
#
# 📥 Verificando boletín XML para sesión 1137...
# ✅ Guardado boletín sesión 7 (válido)
#
# 📥 Verificando boletín XML para sesión 1138...
# ✅ Guardado boletín sesión 8 (válido)
#
# 📥 Verificando boletín XML para sesión 1139...
# ✅ Guardado boletín sesión 9 (válido)
#
# 📥 Verificando boletín XML para sesión 1140...
# ✅ Guardado boletín sesión 10 (válido)
#
# 📥 Verificando boletín XML para sesión 1141...
# ✅ Guardado boletín sesión 11 (válido)
#
# 📥 Verificando boletín XML para sesión 1143...
# ✅ Guardado boletín sesión 13 (válido)
#
# 📥 Verificando boletín XML para sesión 1144...
# ✅ Guardado boletín sesión 14 (válido)
#
# 📥 Verificando boletín XML para sesión 1145...
# ✅ Guardado boletín sesión 15 (válido)
#
# 📥 Verificando boletín XML para sesión 1147...
# ✅ Guardado boletín sesión 18 (válido)
#
# 📥 Verificando boletín XML para sesión 1148...
# ✅ Guardado boletín sesión 19 (válido)
#
# 📥 Verificando boletín XML para sesión 1149...
# ✅ Guardado boletín sesión 21 (válido)
#
# 📥 Verificando boletín XML para sesión 1151...
# ✅ Guardado boletín sesión 23 (válido)
#
# 📥 Verificando boletín XML para sesión 1152...
# ✅ Guardado boletín sesión 24 (válido)
#
# 📥 Verificando boletín XML para sesión 1153...
# ✅ Guardado boletín sesión 25 (válido)
#
# 📥 Verificando boletín XML para sesión 1155...
# ✅ Guardado boletín sesión 28 (válido)
#
# 📥 Verificando boletín XML para sesión 1156...
# ✅ Guardado boletín sesión 29 (válido)
#
# 📥 Verificando boletín XML para sesión 1157...
# ✅ Guardado boletín sesión 30 (válido)
#
# 📥 Verificando boletín XML para sesión 1159...
# ✅ Guardado boletín sesión 32 (válido)
#
# 📥 Verificando boletín XML para sesión 1160...
# ✅ Guardado boletín sesión 33 (válido)
#
# 📥 Verificando boletín XML para sesión 1161...
# ✅ Guardado boletín sesión 34 (válido)
#
# 📥 Verificando boletín XML para sesión 1163...
# ✅ Guardado boletín sesión 36 (válido)
#
# 📥 Verificando boletín XML para sesión 1164...
# ✅ Guardado boletín sesión 37 (válido)
#
# 📥 Verificando boletín XML para sesión 1142...
# ✅ Guardado boletín sesión 12 (válido)
#
# 📥 Verificando boletín XML para sesión 1146...
# ✅ Guardado boletín sesión 16 (válido)
#
# 📥 Verificando boletín XML para sesión 1150...
# ✅ Guardado boletín sesión 22 (válido)
#
# 📥 Verificando boletín XML para sesión 1154...
# ✅ Guardado boletín sesión 27 (válido)
#
# 📥 Verificando boletín XML para sesión 1158...
# ✅ Guardado boletín sesión 31 (válido)
#
# 📥 Verificando boletín XML para sesión 1162...
# ✅ Guardado boletín sesión 35 (válido)
#
# 📥 Verificando boletín XML para sesión 2630...
# ✅ Guardado boletín sesión 2 (válido)
#
# 📥 Verificando boletín XML para sesión 2631...
# ✅ Guardado boletín sesión 5 (válido)
#
# 📥 Verificando boletín XML para sesión 2632...
# ✅ Guardado boletín sesión 17 (válido)
#
# 📥 Verificando boletín XML para sesión 2633...
# ✅ Guardado boletín sesión 20 (válido)
#
# 📥 Verificando boletín XML para sesión 2634...
# ✅ Guardado boletín sesión 26 (válido)
#
# 📄 Descargando sesiones de legislatura 328 (ID 12)...
# 📌 26 sesiones encontradas.
#
# 📥 Verificando boletín XML para sesión 1165...
# ✅ Guardado boletín sesión 1 (válido)
#
# 📥 Verificando boletín XML para sesión 1167...
# ✅ Guardado boletín sesión 3 (válido)
#
# 📥 Verificando boletín XML para sesión 1168...
# ✅ Guardado boletín sesión 5 (válido)
#
# 📥 Verificando boletín XML para sesión 1169...
# ✅ Guardado boletín sesión 6 (válido)
#
# 📥 Verificando boletín XML para sesión 1171...
# ⚪ Boletín 1171 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1172...
# ✅ Guardado boletín sesión 12 (válido)
#
# 📥 Verificando boletín XML para sesión 1173...
# ✅ Guardado boletín sesión 13 (válido)
#
# 📥 Verificando boletín XML para sesión 1175...
# ✅ Guardado boletín sesión 16 (válido)
#
# 📥 Verificando boletín XML para sesión 1176...
# ✅ Guardado boletín sesión 18 (válido)
#
# 📥 Verificando boletín XML para sesión 1177...
# ✅ Guardado boletín sesión 19 (válido)
#
# 📥 Verificando boletín XML para sesión 1179...
# ✅ Guardado boletín sesión 23 (válido)
#
# 📥 Verificando boletín XML para sesión 1180...
# ✅ Guardado boletín sesión 25 (válido)
#
# 📥 Verificando boletín XML para sesión 2316...
# ✅ Guardado boletín sesión 4 (válido)
#
# 📥 Verificando boletín XML para sesión 2317...
# ✅ Guardado boletín sesión 7 (válido)
#
# 📥 Verificando boletín XML para sesión 2318...
# ⚪ Boletín 2318 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2320...
# ✅ Guardado boletín sesión 14 (válido)
#
# 📥 Verificando boletín XML para sesión 2321...
# ✅ Guardado boletín sesión 17 (válido)
#
# 📥 Verificando boletín XML para sesión 2322...
# ✅ Guardado boletín sesión 20 (válido)
#
# 📥 Verificando boletín XML para sesión 2324...
# ✅ Guardado boletín sesión 24 (válido)
#
# 📥 Verificando boletín XML para sesión 1166...
# ✅ Guardado boletín sesión 2 (válido)
#
# 📥 Verificando boletín XML para sesión 1170...
# ✅ Guardado boletín sesión 9 (válido)
#
# 📥 Verificando boletín XML para sesión 1174...
# ✅ Guardado boletín sesión 15 (válido)
#
# 📥 Verificando boletín XML para sesión 1178...
# ✅ Guardado boletín sesión 21 (válido)
#
# 📥 Verificando boletín XML para sesión 2319...
# ✅ Guardado boletín sesión 11 (válido)
#
# 📥 Verificando boletín XML para sesión 2323...
# ✅ Guardado boletín sesión 22 (válido)
#
# 📥 Verificando boletín XML para sesión 3475...
# ⚪ Boletín 3475 vacío, se omite.
#
# 📄 Descargando sesiones de legislatura 329 (ID 13)...
# 📌 41 sesiones encontradas.
#
# 📥 Verificando boletín XML para sesión 1181...
# ✅ Guardado boletín sesión 1 (válido)
#
# 📥 Verificando boletín XML para sesión 1183...
# ✅ Guardado boletín sesión 3 (válido)
#
# 📥 Verificando boletín XML para sesión 1184...
# ✅ Guardado boletín sesión 4 (válido)
#
# 📥 Verificando boletín XML para sesión 1185...
# ✅ Guardado boletín sesión 5 (válido)
#
# 📥 Verificando boletín XML para sesión 1187...
# ✅ Guardado boletín sesión 7 (válido)
#
# 📥 Verificando boletín XML para sesión 1188...
# ✅ Guardado boletín sesión 8 (válido)
#
# 📥 Verificando boletín XML para sesión 1189...
# ✅ Guardado boletín sesión 10 (válido)
#
# 📥 Verificando boletín XML para sesión 1191...
# ✅ Guardado boletín sesión 13 (válido)
#
# 📥 Verificando boletín XML para sesión 1192...
# ✅ Guardado boletín sesión 14 (válido)
#
# 📥 Verificando boletín XML para sesión 1193...
# ✅ Guardado boletín sesión 15 (válido)
#
# 📥 Verificando boletín XML para sesión 1195...
# ✅ Guardado boletín sesión 18 (válido)
#
# 📥 Verificando boletín XML para sesión 1196...
# ✅ Guardado boletín sesión 19 (válido)
#
# 📥 Verificando boletín XML para sesión 1197...
# ✅ Guardado boletín sesión 22 (válido)
#
# 📥 Verificando boletín XML para sesión 1199...
# ✅ Guardado boletín sesión 24 (válido)
#
# 📥 Verificando boletín XML para sesión 1200...
# ✅ Guardado boletín sesión 25 (válido)
#
# 📥 Verificando boletín XML para sesión 1201...
# ✅ Guardado boletín sesión 26 (válido)
#
# 📥 Verificando boletín XML para sesión 1203...
# ✅ Guardado boletín sesión 28 (válido)
#
# 📥 Verificando boletín XML para sesión 1204...
# ✅ Guardado boletín sesión 29 (válido)
#
# 📥 Verificando boletín XML para sesión 1205...
# ⚪ Boletín 1205 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1207...
# ⚪ Boletín 1207 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1208...
# ⚪ Boletín 1208 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1209...
# ⚪ Boletín 1209 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1211...
# ⚪ Boletín 1211 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1212...
# ⚪ Boletín 1212 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1213...
# ⚪ Boletín 1213 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1182...
# ✅ Guardado boletín sesión 2 (válido)
#
# 📥 Verificando boletín XML para sesión 1186...
# ✅ Guardado boletín sesión 6 (válido)
#
# 📥 Verificando boletín XML para sesión 1190...
# ✅ Guardado boletín sesión 12 (válido)
#
# 📥 Verificando boletín XML para sesión 1194...
# ✅ Guardado boletín sesión 16 (válido)
#
# 📥 Verificando boletín XML para sesión 1198...
# ✅ Guardado boletín sesión 23 (válido)
#
# 📥 Verificando boletín XML para sesión 1202...
# ✅ Guardado boletín sesión 27 (válido)
#
# 📥 Verificando boletín XML para sesión 1206...
# ⚪ Boletín 1206 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1210...
# ⚪ Boletín 1210 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2635...
# ✅ Guardado boletín sesión 9 (válido)
#
# 📥 Verificando boletín XML para sesión 2636...
# ✅ Guardado boletín sesión 11 (válido)
#
# 📥 Verificando boletín XML para sesión 2637...
# ✅ Guardado boletín sesión 17 (válido)
#
# 📥 Verificando boletín XML para sesión 2638...
# ✅ Guardado boletín sesión 20 (válido)
#
# 📥 Verificando boletín XML para sesión 2639...
# ✅ Guardado boletín sesión 21 (válido)
#
# 📥 Verificando boletín XML para sesión 2640...
# ⚪ Boletín 2640 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2641...
# ⚪ Boletín 2641 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2642...
# ⚪ Boletín 2642 vacío, se omite.
#
# 📄 Descargando sesiones de legislatura 330 (ID 14)...
# 📌 71 sesiones encontradas.
#
# 📥 Verificando boletín XML para sesión 1215...
# ✅ Guardado boletín sesión 2 (válido)
#
# 📥 Verificando boletín XML para sesión 1216...
# ✅ Guardado boletín sesión 3 (válido)
#
# 📥 Verificando boletín XML para sesión 1217...
# ✅ Guardado boletín sesión 4 (válido)
#
# 📥 Verificando boletín XML para sesión 1219...
# ✅ Guardado boletín sesión 7 (válido)
#
# 📥 Verificando boletín XML para sesión 1220...
# ✅ Guardado boletín sesión 8 (válido)
#
# 📥 Verificando boletín XML para sesión 1221...
# ✅ Guardado boletín sesión 9 (válido)
#
# 📥 Verificando boletín XML para sesión 1223...
# ✅ Guardado boletín sesión 11 (válido)
#
# 📥 Verificando boletín XML para sesión 1224...
# ✅ Guardado boletín sesión 12 (válido)
#
# 📥 Verificando boletín XML para sesión 1225...
# ✅ Guardado boletín sesión 13 (válido)
#
# 📥 Verificando boletín XML para sesión 1227...
# ✅ Guardado boletín sesión 15 (válido)
#
# 📥 Verificando boletín XML para sesión 1228...
# ✅ Guardado boletín sesión 17 (válido)
#
# 📥 Verificando boletín XML para sesión 1229...
# ✅ Guardado boletín sesión 18 (válido)
#
# 📥 Verificando boletín XML para sesión 1231...
# ✅ Guardado boletín sesión 20 (válido)
#
# 📥 Verificando boletín XML para sesión 1232...
# ✅ Guardado boletín sesión 21 (válido)
#
# 📥 Verificando boletín XML para sesión 1233...
# ✅ Guardado boletín sesión 22 (válido)
#
# 📥 Verificando boletín XML para sesión 1238...
# ✅ Guardado boletín sesión 29 (válido)
#
# 📥 Verificando boletín XML para sesión 1239...
# ✅ Guardado boletín sesión 30 (válido)
#
# 📥 Verificando boletín XML para sesión 1240...
# ✅ Guardado boletín sesión 32 (válido)
#
# 📥 Verificando boletín XML para sesión 1241...
# ✅ Guardado boletín sesión 33 (válido)
#
# 📥 Verificando boletín XML para sesión 1242...
# ✅ Guardado boletín sesión 35 (válido)
#
# 📥 Verificando boletín XML para sesión 1243...
# ✅ Guardado boletín sesión 37 (válido)
#
# 📥 Verificando boletín XML para sesión 1244...
# ✅ Guardado boletín sesión 38 (válido)
#
# 📥 Verificando boletín XML para sesión 1245...
# ✅ Guardado boletín sesión 39 (válido)
#
# 📥 Verificando boletín XML para sesión 1246...
# ✅ Guardado boletín sesión 40 (válido)
#
# 📥 Verificando boletín XML para sesión 1247...
# ✅ Guardado boletín sesión 41 (válido)
#
# 📥 Verificando boletín XML para sesión 1248...
# ✅ Guardado boletín sesión 42 (válido)
#
# 📥 Verificando boletín XML para sesión 1249...
# ✅ Guardado boletín sesión 43 (válido)
#
# 📥 Verificando boletín XML para sesión 1250...
# ⚪ Boletín 1250 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1251...
# ✅ Guardado boletín sesión 46 (válido)
#
# 📥 Verificando boletín XML para sesión 1252...
# ✅ Guardado boletín sesión 48 (válido)
#
# 📥 Verificando boletín XML para sesión 1253...
# ✅ Guardado boletín sesión 49 (válido)
#
# 📥 Verificando boletín XML para sesión 1254...
# ✅ Guardado boletín sesión 52 (válido)
#
# 📥 Verificando boletín XML para sesión 1256...
# ✅ Guardado boletín sesión 55 (válido)
#
# 📥 Verificando boletín XML para sesión 1257...
# ✅ Guardado boletín sesión 56 (válido)
#
# 📥 Verificando boletín XML para sesión 1258...
# ✅ Guardado boletín sesión 57 (válido)
#
# 📥 Verificando boletín XML para sesión 1260...
# ✅ Guardado boletín sesión 59 (válido)
#
# 📥 Verificando boletín XML para sesión 1261...
# ✅ Guardado boletín sesión 60 (válido)
#
# 📥 Verificando boletín XML para sesión 1262...
# ✅ Guardado boletín sesión 61 (válido)
#
# 📥 Verificando boletín XML para sesión 1264...
# ✅ Guardado boletín sesión 63 (válido)
#
# 📥 Verificando boletín XML para sesión 1265...
# ✅ Guardado boletín sesión 65 (válido)
#
# 📥 Verificando boletín XML para sesión 1266...
# ✅ Guardado boletín sesión 66 (válido)
#
# 📥 Verificando boletín XML para sesión 1268...
# ✅ Guardado boletín sesión 69 (válido)
#
# 📥 Verificando boletín XML para sesión 1269...
# ✅ Guardado boletín sesión 70 (válido)
#
# 📥 Verificando boletín XML para sesión 1270...
# ✅ Guardado boletín sesión 71 (válido)
#
# 📥 Verificando boletín XML para sesión 1236...
# ✅ Guardado boletín sesión 26 (válido)
#
# 📥 Verificando boletín XML para sesión 1237...
# ✅ Guardado boletín sesión 27 (válido)
#
# 📥 Verificando boletín XML para sesión 1214...
# ✅ Guardado boletín sesión 1 (válido)
#
# 📥 Verificando boletín XML para sesión 1218...
# ✅ Guardado boletín sesión 6 (válido)
#
# 📥 Verificando boletín XML para sesión 1222...
# ✅ Guardado boletín sesión 10 (válido)
#
# 📥 Verificando boletín XML para sesión 1226...
# ✅ Guardado boletín sesión 14 (válido)
#
# 📥 Verificando boletín XML para sesión 1230...
# ✅ Guardado boletín sesión 19 (válido)
#
# 📥 Verificando boletín XML para sesión 1234...
# ✅ Guardado boletín sesión 24 (válido)
#
# 📥 Verificando boletín XML para sesión 1255...
# ✅ Guardado boletín sesión 53 (válido)
#
# 📥 Verificando boletín XML para sesión 1259...
# ✅ Guardado boletín sesión 58 (válido)
#
# 📥 Verificando boletín XML para sesión 1263...
# ✅ Guardado boletín sesión 62 (válido)
#
# 📥 Verificando boletín XML para sesión 1267...
# ✅ Guardado boletín sesión 67 (válido)
#
# 📥 Verificando boletín XML para sesión 1235...
# ✅ Guardado boletín sesión 25 (válido)
#
# 📥 Verificando boletín XML para sesión 2616...
# ✅ Guardado boletín sesión 5 (válido)
#
# 📥 Verificando boletín XML para sesión 2617...
# ✅ Guardado boletín sesión 16 (válido)
#
# 📥 Verificando boletín XML para sesión 2618...
# ✅ Guardado boletín sesión 23 (válido)
#
# 📥 Verificando boletín XML para sesión 2619...
# ✅ Guardado boletín sesión 28 (válido)
#
# 📥 Verificando boletín XML para sesión 2620...
# ✅ Guardado boletín sesión 31 (válido)
#
# 📥 Verificando boletín XML para sesión 2621...
# ⚪ Boletín 2621 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2622...
# ✅ Guardado boletín sesión 36 (válido)
#
# 📥 Verificando boletín XML para sesión 2623...
# ✅ Guardado boletín sesión 44 (válido)
#
# 📥 Verificando boletín XML para sesión 2624...
# ✅ Guardado boletín sesión 47 (válido)
#
# 📥 Verificando boletín XML para sesión 2625...
# ⚪ Boletín 2625 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2626...
# ✅ Guardado boletín sesión 51 (válido)
#
# 📥 Verificando boletín XML para sesión 2627...
# ✅ Guardado boletín sesión 54 (válido)
#
# 📥 Verificando boletín XML para sesión 2628...
# ✅ Guardado boletín sesión 64 (válido)
#
# 📥 Verificando boletín XML para sesión 2629...
# ✅ Guardado boletín sesión 68 (válido)
#
# 📄 Descargando sesiones de legislatura 331 (ID 15)...
# 📌 39 sesiones encontradas.
#
# 📥 Verificando boletín XML para sesión 1272...
# ✅ Guardado boletín sesión 2 (válido)
#
# 📥 Verificando boletín XML para sesión 1273...
# ✅ Guardado boletín sesión 3 (válido)
#
# 📥 Verificando boletín XML para sesión 1274...
# ✅ Guardado boletín sesión 4 (válido)
#
# ...
# ✅ Guardado boletín sesión 41 (válido)
#
# 📥 Verificando boletín XML para sesión 364...
# ✅ Guardado boletín sesión 45 (válido)
#
# 📥 Verificando boletín XML para sesión 367...
# ✅ Guardado boletín sesión 48 (válido)
#
# 📥 Verificando boletín XML para sesión 371...
# ✅ Guardado boletín sesión 52 (válido)
#
# 📥 Verificando boletín XML para sesión 375...
# ✅ Guardado boletín sesión 56 (válido)
#
# 📥 Verificando boletín XML para sesión 379...
# ✅ Guardado boletín sesión 60 (válido)
#
# 📥 Verificando boletín XML para sesión 383...
# ✅ Guardado boletín sesión 65 (válido)
#
# 📥 Verificando boletín XML para sesión 387...
# ✅ Guardado boletín sesión 69 (válido)
#
# 📥 Verificando boletín XML para sesión 391...
# ✅ Guardado boletín sesión 73 (válido)
#
# 📥 Verificando boletín XML para sesión 395...
# ✅ Guardado boletín sesión 78 (válido)
#
# 📥 Verificando boletín XML para sesión 399...
# ✅ Guardado boletín sesión 83 (válido)
#
# 📥 Verificando boletín XML para sesión 403...
# ✅ Guardado boletín sesión 87 (válido)
#
# 📄 Descargando sesiones de legislatura 351 (ID 35)...
# 📌 45 sesiones encontradas.
#
# 📥 Verificando boletín XML para sesión 115...
# ⚪ Boletín 115 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 116...
# ⚪ Boletín 116 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 117...
# ⚪ Boletín 117 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 118...
# ⚪ Boletín 118 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 119...
# ⚪ Boletín 119 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 120...
# ⚪ Boletín 120 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 121...
# ⚪ Boletín 121 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 122...
# ⚪ Boletín 122 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 123...
# ⚪ Boletín 123 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 124...
# ⚪ Boletín 124 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 125...
# ⚪ Boletín 125 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 126...
# ⚪ Boletín 126 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 127...
# ⚪ Boletín 127 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 128...
# ⚪ Boletín 128 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 130...
# ⚪ Boletín 130 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 131...
# ⚪ Boletín 131 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 132...
# ⚪ Boletín 132 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 134...
# ⚪ Boletín 134 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 135...
# ⚪ Boletín 135 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 136...
# ⚪ Boletín 136 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 138...
# ⚪ Boletín 138 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 139...
# ⚪ Boletín 139 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 140...
# ⚪ Boletín 140 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 142...
# ⚪ Boletín 142 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 143...
# ⚪ Boletín 143 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 144...
# ⚪ Boletín 144 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 146...
# ⚪ Boletín 146 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 147...
# ⚪ Boletín 147 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 148...
# ⚪ Boletín 148 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 150...
# ⚪ Boletín 150 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 151...
# ⚪ Boletín 151 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 152...
# ⚪ Boletín 152 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 154...
# ⚪ Boletín 154 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 155...
# ⚪ Boletín 155 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 156...
# ⚪ Boletín 156 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 158...
# ⚪ Boletín 158 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 160...
# ⚪ Boletín 160 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 159...
# ⚪ Boletín 159 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 129...
# ⚪ Boletín 129 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 133...
# ⚪ Boletín 133 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 137...
# ⚪ Boletín 137 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 141...
# ⚪ Boletín 141 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 145...
# ⚪ Boletín 145 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 149...
# ⚪ Boletín 149 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 153...
# ⚪ Boletín 153 vacío, se omite.
#
# 📄 Descargando sesiones de legislatura 352 (ID 36)...
# 📌 79 sesiones encontradas.
#
# 📥 Verificando boletín XML para sesión 70...
# ⚪ Boletín 70 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 166...
# ⚪ Boletín 166 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 1...
# ⚪ Boletín 1 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 2...
# ⚪ Boletín 2 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 3...
# ⚪ Boletín 3 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 4...
# ⚪ Boletín 4 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 5...
# ⚪ Boletín 5 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 6...
# ⚪ Boletín 6 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 7...
# ⚪ Boletín 7 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 8...
# ⚪ Boletín 8 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 9...
# ⚪ Boletín 9 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 10...
# ⚪ Boletín 10 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 11...
# ⚪ Boletín 11 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 12...
# ⚪ Boletín 12 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 13...
# ⚪ Boletín 13 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 14...
# ⚪ Boletín 14 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 15...
# ⚪ Boletín 15 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 16...
# ⚪ Boletín 16 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 18...
# ⚪ Boletín 18 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 19...
# ⚪ Boletín 19 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 20...
# ⚪ Boletín 20 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 22...
# ⚪ Boletín 22 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 23...
# ✅ Guardado boletín sesión 46 (válido)
#
# 📥 Verificando boletín XML para sesión 24...
# ⚪ Boletín 24 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 26...
# ⚪ Boletín 26 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 27...
# ⚪ Boletín 27 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 28...
# ⚪ Boletín 28 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 30...
# ⚪ Boletín 30 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 31...
# ⚪ Boletín 31 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 32...
# ✅ Guardado boletín sesión 37 (válido)
#
# 📥 Verificando boletín XML para sesión 34...
# ⚪ Boletín 34 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 35...
# ⚪ Boletín 35 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 36...
# ⚪ Boletín 36 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 38...
# ✅ Guardado boletín sesión 31 (válido)
#
# 📥 Verificando boletín XML para sesión 39...
# ⚪ Boletín 39 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 40...
# ⚪ Boletín 40 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 42...
# ✅ Guardado boletín sesión 27 (válido)
#
# 📥 Verificando boletín XML para sesión 43...
# ✅ Guardado boletín sesión 26 (válido)
#
# 📥 Verificando boletín XML para sesión 44...
# ✅ Guardado boletín sesión 25 (válido)
#
# 📥 Verificando boletín XML para sesión 46...
# ✅ Guardado boletín sesión 23 (válido)
#
# 📥 Verificando boletín XML para sesión 47...
# ✅ Guardado boletín sesión 22 (válido)
#
# 📥 Verificando boletín XML para sesión 48...
# ✅ Guardado boletín sesión 21 (válido)
#
# 📥 Verificando boletín XML para sesión 50...
# ✅ Guardado boletín sesión 19 (válido)
#
# 📥 Verificando boletín XML para sesión 51...
# ✅ Guardado boletín sesión 18 (válido)
#
# 📥 Verificando boletín XML para sesión 52...
# ✅ Guardado boletín sesión 17 (válido)
#
# 📥 Verificando boletín XML para sesión 54...
# ✅ Guardado boletín sesión 15 (válido)
#
# 📥 Verificando boletín XML para sesión 55...
# ✅ Guardado boletín sesión 14 (válido)
#
# 📥 Verificando boletín XML para sesión 57...
# ✅ Guardado boletín sesión 12 (válido)
#
# 📥 Verificando boletín XML para sesión 58...
# ⚪ Boletín 58 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 59...
# ⚪ Boletín 59 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 61...
# ✅ Guardado boletín sesión 8 (válido)
#
# 📥 Verificando boletín XML para sesión 62...
# ⚪ Boletín 62 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 63...
# ✅ Guardado boletín sesión 6 (válido)
#
# 📥 Verificando boletín XML para sesión 65...
# ✅ Guardado boletín sesión 4 (válido)
#
# 📥 Verificando boletín XML para sesión 66...
# ✅ Guardado boletín sesión 3 (válido)
#
# 📥 Verificando boletín XML para sesión 67...
# ✅ Guardado boletín sesión 2 (válido)
#
# 📥 Verificando boletín XML para sesión 167...
# ⚪ Boletín 167 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 164...
# ⚪ Boletín 164 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 161...
# ⚪ Boletín 161 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 163...
# ⚪ Boletín 163 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 490...
# ⚪ Boletín 490 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 69...
# ⚪ Boletín 69 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 71...
# ⚪ Boletín 71 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 165...
# ⚪ Boletín 165 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 162...
# ⚪ Boletín 162 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 17...
# ⚪ Boletín 17 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 21...
# ⚪ Boletín 21 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 25...
# ⚪ Boletín 25 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 29...
# ✅ Guardado boletín sesión 40 (válido)
#
# 📥 Verificando boletín XML para sesión 33...
# ✅ Guardado boletín sesión 36 (válido)
#
# 📥 Verificando boletín XML para sesión 37...
# ⚪ Boletín 37 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 41...
# ⚪ Boletín 41 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 45...
# ⚪ Boletín 45 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 49...
# ✅ Guardado boletín sesión 20 (válido)
#
# 📥 Verificando boletín XML para sesión 53...
# ✅ Guardado boletín sesión 16 (válido)
#
# 📥 Verificando boletín XML para sesión 56...
# ✅ Guardado boletín sesión 13 (válido)
#
# 📥 Verificando boletín XML para sesión 60...
# ⚪ Boletín 60 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 64...
# ✅ Guardado boletín sesión 5 (válido)
#
# 📥 Verificando boletín XML para sesión 68...
# ✅ Guardado boletín sesión 1 (válido)
#
# 📄 Descargando sesiones de legislatura 353 (ID 37)...
# 📌 77 sesiones encontradas.
#
# 📥 Verificando boletín XML para sesión 606...
# ✅ Guardado boletín sesión 1 (válido)
#
# 📥 Verificando boletín XML para sesión 633...
# ✅ Guardado boletín sesión 25 (válido)
#
# 📥 Verificando boletín XML para sesión 644...
# ✅ Guardado boletín sesión 32 (válido)
#
# 📥 Verificando boletín XML para sesión 622...
# ✅ Guardado boletín sesión 13 (válido)
#
# 📥 Verificando boletín XML para sesión 636...
# ✅ Guardado boletín sesión 24 (válido)
#
# 📥 Verificando boletín XML para sesión 645...
# ✅ Guardado boletín sesión 33 (válido)
#
# 📥 Verificando boletín XML para sesión 648...
# ✅ Guardado boletín sesión 36 (válido)
#
# 📥 Verificando boletín XML para sesión 658...
# ⚪ Boletín 658 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 663...
# ✅ Guardado boletín sesión 49 (válido)
#
# 📥 Verificando boletín XML para sesión 664...
# ✅ Guardado boletín sesión 50 (válido)
#
# 📥 Verificando boletín XML para sesión 668...
# ✅ Guardado boletín sesión 54 (válido)
#
# 📥 Verificando boletín XML para sesión 669...
# ✅ Guardado boletín sesión 55 (válido)
#
# 📥 Verificando boletín XML para sesión 671...
# ✅ Guardado boletín sesión 57 (válido)
#
# 📥 Verificando boletín XML para sesión 674...
# ✅ Guardado boletín sesión 59 (válido)
#
# 📥 Verificando boletín XML para sesión 675...
# ✅ Guardado boletín sesión 60 (válido)
#
# 📥 Verificando boletín XML para sesión 682...
# ✅ Guardado boletín sesión 67 (válido)
#
# 📥 Verificando boletín XML para sesión 683...
# ✅ Guardado boletín sesión 68 (válido)
#
# 📥 Verificando boletín XML para sesión 684...
# ✅ Guardado boletín sesión 69 (válido)
#
# 📥 Verificando boletín XML para sesión 690...
# ✅ Guardado boletín sesión 75 (válido)
#
# 📥 Verificando boletín XML para sesión 607...
# ✅ Guardado boletín sesión 2 (válido)
#
# 📥 Verificando boletín XML para sesión 626...
# ✅ Guardado boletín sesión 17 (válido)
#
# 📥 Verificando boletín XML para sesión 614...
# ✅ Guardado boletín sesión 8 (válido)
#
# 📥 Verificando boletín XML para sesión 628...
# ✅ Guardado boletín sesión 19 (válido)
#
# 📥 Verificando boletín XML para sesión 629...
# ✅ Guardado boletín sesión 20 (válido)
#
# 📥 Verificando boletín XML para sesión 630...
# ✅ Guardado boletín sesión 21 (válido)
#
# 📥 Verificando boletín XML para sesión 643...
# ✅ Guardado boletín sesión 31 (válido)
#
# 📥 Verificando boletín XML para sesión 679...
# ✅ Guardado boletín sesión 64 (válido)
#
# 📥 Verificando boletín XML para sesión 686...
# ✅ Guardado boletín sesión 71 (válido)
#
# 📥 Verificando boletín XML para sesión 688...
# ✅ Guardado boletín sesión 73 (válido)
#
# 📥 Verificando boletín XML para sesión 689...
# ✅ Guardado boletín sesión 74 (válido)
#
# 📥 Verificando boletín XML para sesión 608...
# ✅ Guardado boletín sesión 3 (válido)
#
# 📥 Verificando boletín XML para sesión 609...
# ✅ Guardado boletín sesión 4 (válido)
#
# 📥 Verificando boletín XML para sesión 611...
# ✅ Guardado boletín sesión 6 (válido)
#
# 📥 Verificando boletín XML para sesión 618...
# ✅ Guardado boletín sesión 9 (válido)
#
# 📥 Verificando boletín XML para sesión 619...
# ✅ Guardado boletín sesión 10 (válido)
#
# 📥 Verificando boletín XML para sesión 620...
# ✅ Guardado boletín sesión 11 (válido)
#
# 📥 Verificando boletín XML para sesión 621...
# ✅ Guardado boletín sesión 12 (válido)
#
# 📥 Verificando boletín XML para sesión 632...
# ✅ Guardado boletín sesión 22 (válido)
#
# 📥 Verificando boletín XML para sesión 638...
# ✅ Guardado boletín sesión 26 (válido)
#
# 📥 Verificando boletín XML para sesión 646...
# ✅ Guardado boletín sesión 34 (válido)
#
# 📥 Verificando boletín XML para sesión 653...
# ✅ Guardado boletín sesión 41 (válido)
#
# 📥 Verificando boletín XML para sesión 656...
# ✅ Guardado boletín sesión 42 (válido)
#
# 📥 Verificando boletín XML para sesión 659...
# ✅ Guardado boletín sesión 45 (válido)
#
# 📥 Verificando boletín XML para sesión 662...
# ⚪ Boletín 662 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 673...
# ⚪ Boletín 673 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 610...
# ✅ Guardado boletín sesión 5 (válido)
#
# 📥 Verificando boletín XML para sesión 625...
# ✅ Guardado boletín sesión 16 (válido)
#
# 📥 Verificando boletín XML para sesión 624...
# ✅ Guardado boletín sesión 15 (válido)
#
# 📥 Verificando boletín XML para sesión 637...
# ⚪ Boletín 637 vacío, se omite.
#
# 📥 Verificando boletín XML para sesión 639...
# ✅ Guardado boletín sesión 27 (válido)
#
# 📥 Verificando boletín XML para sesión 641...
# ✅ Guardado boletín sesión 29 (válido)
#
# 📥 Verificando boletín XML para sesión 650...
# ✅ Guardado boletín sesión 38 (válido)
#
# 📥 Verificando boletín XML para sesión 651...
# ✅ Guardado boletín sesión 39 (válido)
#
# 📥 Verificando boletín XML para sesión 660...
# ✅ Guardado boletín sesión 46 (válido)
#
# 📥 Verificando boletín XML para sesión 661...
# ✅ Guardado boletín sesión 47 (válido)
#
# 📥 Verificando boletín XML para sesión 666...
# ✅ Guardado boletín sesión 52 (válido)
#
# 📥 Verificando boletín XML para sesión 676...
# ✅ Guardado boletín sesión 61 (válido)
#
# 📥 Verificando boletín XML para sesión 677...
# ✅ Guardado boletín sesión 62 (válido)
#
# 📥 Verificando boletín XML para sesión 680...
# ✅ Guardado boletín sesión 65 (válido)
#
# 📥 Verificando boletín XML para sesión 623...
# ✅ Guardado boletín sesión 14 (válido)
#
# 📥 Verificando boletín XML para sesión 640...
# ✅ Guardado boletín sesión 28 (válido)
#
# 📥 Verificando boletín XML para sesión 652...
# ✅ Guardado boletín sesión 40 (válido)

# %%
# !pip install pymupdf
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pymupdf in c:\users\conjv\appdata\roaming\python\python311\site-packages (1.26.4)

# %%
import fitz  # PyMuPDF
import json
import os
import re
from datetime import datetime
import locale # Para manejar meses en español

# --- Configuración ---
directorio_pdf_entrada = "C:/Users/conjv/Desktop/pdfs_descargados"  # CAMBIA ESTO a tu carpeta con PDFs
directorio_json_salida = "C:/Users/conjv/Desktop/json_descargados" # CAMBIA ESTO a tu carpeta de salida deseada

# Configurar locale a español para reconocer los nombres de los meses
# Puede variar según tu sistema operativo ('es_ES.UTF-8', 'es_CL.UTF-8', 'Spanish_Spain.1252' en Windows)
try:
    locale.setlocale(locale.LC_TIME, 'es_ES.UTF-8') 
except locale.Error:
    try:
        locale.setlocale(locale.LC_TIME, 'Spanish') # Para Windows
    except locale.Error:
        print("Advertencia: No se pudo configurar el locale a español. La extracción de fechas puede fallar.")
        # Continuar con el locale por defecto si falla español

def extraer_metadatos_desde_nombre(filename):
    """
    Intenta extraer metadatos del nombre del archivo PDF.
    Formato esperado: NUMLEG__LEGISLATURA__*_NUMSESION__TIPO__*FECHA*.pdf
    Ejemplo: 370__LEGISLATURA__mar._2022_-_mar._2023__5___ordinaria__23_marzo___2022.pdf
    """
    metadata = {
        '@NUMERO': '0',
        '@FECHA_INICIO': 'Unknown',
        '@FECHA_TERMINO': 'Unknown',
        '@TIPO': 'Unknown',
        'legislatura': 'Unknown'
    }

    # Extraer Legislatura (ej: 370)
    match_leg = re.match(r'(\d+)__LEGISLATURA', filename, re.IGNORECASE)
    if match_leg:
        metadata['legislatura'] = match_leg.group(1)

    # Buscar Número de Sesión y Tipo (ej: __5___ordinaria__)
    # Buscamos __NUMERO___TIPO__ (con underscores variables)
    match_ses_tipo = re.search(r'__(\d+)_{3,}(ordinaria|especial|extraordinaria)_{2,}', filename, re.IGNORECASE)
    if match_ses_tipo:
        metadata['@NUMERO'] = match_ses_tipo.group(1)
        metadata['@TIPO'] = match_ses_tipo.group(2).capitalize()

    # Buscar Fecha (ej: __23_marzo___2022) - Asume día_mes___año cerca del final
    # Este patrón es delicado y puede necesitar ajustes
    match_fecha = re.search(r'__(\d{1,2})_([a-zA-Záéíóúüñ]+)_{3,}(\d{4})\.pdf$', filename, re.IGNORECASE)
    if match_fecha:
        dia, mes_str, anio = match_fecha.groups()
        try:
            # Intentar convertir mes en español a número
            fecha_obj = datetime.strptime(f"{dia} {mes_str} {anio}", '%d %B %Y')
            fecha_formateada = fecha_obj.strftime('%d-%m-%Y')
            metadata['@FECHA_INICIO'] = fecha_formateada
            metadata['@FECHA_TERMINO'] = fecha_formateada # Asumir misma fecha
        except ValueError:
            # Si falla la conversión (locale incorrecto o mes mal escrito)
            print(f"Advertencia: No se pudo convertir la fecha '{dia} {mes_str} {anio}' para {filename}")
            metadata['@FECHA_INICIO'] = f"{dia}-{mes_str}-{anio}" # Guardar como se encontró
            metadata['@FECHA_TERMINO'] = metadata['@FECHA_INICIO']

    # Si no se encontró el tipo antes, buscarlo de forma más simple
    if metadata['@TIPO'] == 'Unknown':
         if 'ordinaria' in filename.lower():
             metadata['@TIPO'] = 'Ordinaria'
         elif 'especial' in filename.lower():
              metadata['@TIPO'] = 'Especial'
         elif 'extraordinaria' in filename.lower():
             metadata['@TIPO'] = 'Extraordinaria'


    return metadata

def convertir_pdf_a_json_boletin_v2(ruta_pdf, ruta_json_salida):
    """
    Convierte un PDF de boletín a un JSON con estructura básica,
    extrayendo metadatos del nombre del archivo.
    """
    try:
        # Extraer metadatos del nombre del archivo ANTES de abrir el PDF
        filename = os.path.basename(ruta_pdf)
        metadatos = extraer_metadatos_desde_nombre(filename)

        # Extraer texto del PDF
        doc = fitz.open(ruta_pdf)
        texto_completo = ""
        for page in doc:
            texto_completo += page.get_text("text") + "\n--- PAGE BREAK ---\n" # Marcar saltos de página
        doc.close()

        # Crear la estructura JSON
        json_data = {
            "BOLETINXML": {
                # Usar @TEMPLATE genérico si no se extrajo el tipo
                "@TEMPLATE": f"Sesión {metadatos['@TIPO']}" if metadatos['@TIPO'] != 'Unknown' else "Sesión", 
                "@VALID": "False", # Asumir False por defecto
                "SESION": {
                    "@NUMERO": metadatos['@NUMERO'],
                    "@FECHA_INICIO": metadatos['@FECHA_INICIO'],
                    "@FECHA_TERMINO": metadatos['@FECHA_TERMINO'], # Asumido igual a inicio
                    "@TIPO": metadatos['@TIPO'],
                    # Incluir metadato extraído de legislatura si se desea
                    # "@LEGISLATURA": metadatos['legislatura'], 
                    "#text": texto_completo.strip() 
                }
            }
        }

        # Asegurar que el directorio de salida exista
        os.makedirs(os.path.dirname(ruta_json_salida), exist_ok=True)

        # Guardar el JSON
        with open(ruta_json_salida, 'w', encoding='utf-8') as f:
            json.dump(json_data, f, ensure_ascii=False, indent=2)

        print(f"✅ Convertido: {filename} -> {os.path.basename(ruta_json_salida)}")
        return True

    except Exception as e:
        print(f"❌ Error convirtiendo {os.path.basename(ruta_pdf)}: {e}")
        return False

# --- Procesamiento Principal ---
print(f"🚀 Iniciando conversión de PDFs en '{directorio_pdf_entrada}'...")
archivos_convertidos = 0
archivos_fallidos = 0

# Crear directorio base de salida si no existe
os.makedirs(directorio_json_salida, exist_ok=True)

# Listar archivos en la carpeta de entrada
try:
    lista_pdfs = [f for f in os.listdir(directorio_pdf_entrada) if f.lower().endswith(".pdf")]
except FileNotFoundError:
     print(f"❌ Error: La carpeta de entrada '{directorio_pdf_entrada}' no existe.")
     lista_pdfs = [] # Detener si no existe la carpeta

if not lista_pdfs:
    print("🤷 No se encontraron archivos PDF en la carpeta de entrada.")
else:
    print(f"🔍 Encontrados {len(lista_pdfs)} archivos PDF para procesar.")
    for filename in lista_pdfs:
        ruta_pdf = os.path.join(directorio_pdf_entrada, filename)
        
        # Crear nombre de archivo JSON de salida
        nombre_json = os.path.splitext(filename)[0] + ".json"
        ruta_json = os.path.join(directorio_json_salida, nombre_json)

        if convertir_pdf_a_json_boletin_v2(ruta_pdf, ruta_json):
            archivos_convertidos += 1
        else:
            archivos_fallidos += 1
            
# --- Resumen Final ---
print("\n🏁 Proceso de conversión finalizado.")
print(f"   Archivos convertidos exitosamente: {archivos_convertidos}")
print(f"   Archivos con errores: {archivos_fallidos}")
if archivos_convertidos > 0:
    print(f"   Resultados guardados en: {os.path.abspath(directorio_json_salida)}")
# Out:
# 🚀 Iniciando conversión de PDFs en 'C:/Users/conjv/Desktop/pdfs_descargados'...
# 🔍 Encontrados 478 archivos PDF para procesar.
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__0___congreso_pleno__11_marzo___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__0___congreso_pleno__11_marzo___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__100___ordinaria__22_noviembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__100___ordinaria__22_noviembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__101___ordinaria__23_noviembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__101___ordinaria__23_noviembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__102___ordinaria__28_noviembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__102___ordinaria__28_noviembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__103___ordinaria__29_noviembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__103___ordinaria__29_noviembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__104___ordinaria__30_noviembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__104___ordinaria__30_noviembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__105___ordinaria__12_diciembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__105___ordinaria__12_diciembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__106___ordinaria__13_diciembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__106___ordinaria__13_diciembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__107___ordinaria__14_diciembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__107___ordinaria__14_diciembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__108___ordinaria__19_diciembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__108___ordinaria__19_diciembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__109___ordinaria__20_diciembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__109___ordinaria__20_diciembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__10___ordinaria__12_abril___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__10___ordinaria__12_abril___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__110___ordinaria__21_diciembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__110___ordinaria__21_diciembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__111___ordinaria__3_enero___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__111___ordinaria__3_enero___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__112___ordinaria__4_enero___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__112___ordinaria__4_enero___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__113___especial__4_enero___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__113___especial__4_enero___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__114___especial__5_enero___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__114___especial__5_enero___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__115___ordinaria__9_enero___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__115___ordinaria__9_enero___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__116___ordinaria__10_enero___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__116___ordinaria__10_enero___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__117___ordinaria__11_enero___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__117___ordinaria__11_enero___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__118___ordinaria__16_enero___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__118___ordinaria__16_enero___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__119___ordinaria__17_enero___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__119___ordinaria__17_enero___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__11___especial__12_abril___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__11___especial__12_abril___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__120___ordinaria__18_enero___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__120___ordinaria__18_enero___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__121___especial__19_enero___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__121___especial__19_enero___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__122___ordinaria__23_enero___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__122___ordinaria__23_enero___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__123___ordinaria__24_enero___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__123___ordinaria__24_enero___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__124___especial__24_enero___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__124___especial__24_enero___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__125___ordinaria__25_enero___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__125___ordinaria__25_enero___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__126___especial__25_enero___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__126___especial__25_enero___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__127___especial__26_enero___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__127___especial__26_enero___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__128___especial__30_enero___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__128___especial__30_enero___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__129___especial__23_febrero___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__129___especial__23_febrero___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__12___ordinaria__13_abril___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__12___ordinaria__13_abril___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__130___ordinaria__6_marzo___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__130___ordinaria__6_marzo___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__131___ordinaria__7_marzo___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__131___ordinaria__7_marzo___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__132___especial__7_marzo___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__132___especial__7_marzo___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__133___ordinaria__8_marzo___2023.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__133___ordinaria__8_marzo___2023.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__13___ordinaria__18_abril___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__13___ordinaria__18_abril___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__14___ordinaria__19_abril___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__14___ordinaria__19_abril___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__15___ordinaria__20_abril___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__15___ordinaria__20_abril___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__16___ordinaria__2_mayo___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__16___ordinaria__2_mayo___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__17___ordinaria__3_mayo___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__17___ordinaria__3_mayo___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__18___especial__3_mayo___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__18___especial__3_mayo___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__19___ordinaria__4_mayo___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__19___ordinaria__4_mayo___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__1___especial__15_marzo___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__1___especial__15_marzo___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__20___ordinaria__9_mayo___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__20___ordinaria__9_mayo___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__21___ordinaria__10_mayo___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__21___ordinaria__10_mayo___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__22___especial__10_mayo___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__22___especial__10_mayo___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__23___ordinaria__11_mayo___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__23___ordinaria__11_mayo___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__24___ordinaria__16_mayo___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__24___ordinaria__16_mayo___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__25___ordinaria__17_mayo___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__25___ordinaria__17_mayo___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__26___ordinaria__18_mayo___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__26___ordinaria__18_mayo___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__27___ordinaria__30_mayo___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__27___ordinaria__30_mayo___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__28___ordinaria__31_mayo___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__28___ordinaria__31_mayo___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__29___especial__31_mayo___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__29___especial__31_mayo___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__2___ordinaria__16_marzo___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__2___ordinaria__16_marzo___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__30___ordinaria__6_junio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__30___ordinaria__6_junio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__31___ordinaria__7_junio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__31___ordinaria__7_junio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__32___ordinaria__8_junio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__32___ordinaria__8_junio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__33___ordinaria__13_junio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__33___ordinaria__13_junio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__34___ordinaria__14_junio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__34___ordinaria__14_junio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__35___ordinaria__15_junio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__35___ordinaria__15_junio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__37___ordinaria__28_junio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__37___ordinaria__28_junio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__38___ordinaria__29_junio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__38___ordinaria__29_junio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__39___especial__29_junio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__39___especial__29_junio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__3___ordinaria__21_marzo___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__3___ordinaria__21_marzo___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__40___ordinaria__4_julio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__40___ordinaria__4_julio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__41___ordinaria__5_julio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__41___ordinaria__5_julio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__42___especial__5_julio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__42___especial__5_julio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__43___ordinaria__6_julio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__43___ordinaria__6_julio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__44___ordinaria__11_julio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__44___ordinaria__11_julio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__45___ordinaria__12_julio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__45___ordinaria__12_julio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__46___ordinaria__13_julio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__46___ordinaria__13_julio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__47___ordinaria__18_julio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__47___ordinaria__18_julio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__48___ordinaria__19_julio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__48___ordinaria__19_julio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__49___especial__19_julio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__49___especial__19_julio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__4___ordinaria__22_marzo___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__4___ordinaria__22_marzo___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__50___especial__20_julio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__50___especial__20_julio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__51___especial__20_julio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__51___especial__20_julio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__52___especial__29_julio___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__52___especial__29_julio___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__53___ordinaria__1_agosto___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__53___ordinaria__1_agosto___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__54___ordinaria__2_agosto___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__54___ordinaria__2_agosto___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__55___ordinaria__3_agosto___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__55___ordinaria__3_agosto___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__56___especial__3_agosto___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__56___especial__3_agosto___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__57___ordinaria__8_agosto___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__57___ordinaria__8_agosto___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__58___ordinaria__9_agosto___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__58___ordinaria__9_agosto___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__59___ordinaria__10_agosto___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__59___ordinaria__10_agosto___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__5___ordinaria__23_marzo___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__5___ordinaria__23_marzo___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__60___especial__10_agosto___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__60___especial__10_agosto___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__61___ordinaria__16_agosto___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__61___ordinaria__16_agosto___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__62___ordinaria__17_agosto___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__62___ordinaria__17_agosto___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__63___especial__17_agosto___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__63___especial__17_agosto___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__64___especial__17_agosto___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__64___especial__17_agosto___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__65___ordinaria__29_agosto___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__65___ordinaria__29_agosto___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__66___ordinaria__30_agosto___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__66___ordinaria__30_agosto___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__67___especial__30_agosto___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__67___especial__30_agosto___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__68___ordinaria__31_agosto___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__68___ordinaria__31_agosto___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__69___ordinaria__5_septiembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__69___ordinaria__5_septiembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__6___ordinaria__4_abril___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__6___ordinaria__4_abril___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__70___ordinaria__6_septiembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__70___ordinaria__6_septiembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__71___ordinaria__7_septiembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__71___ordinaria__7_septiembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__72___ordinaria__12_septiembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__72___ordinaria__12_septiembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__73___ordinaria__13_septiembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__73___ordinaria__13_septiembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__74___especial__13_septiembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__74___especial__13_septiembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__75___ordinaria__14_septiembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__75___ordinaria__14_septiembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__76___ordinaria__26_septiembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__76___ordinaria__26_septiembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__77___ordinaria__27_septiembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__77___ordinaria__27_septiembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__78___ordinaria__28_septiembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__78___ordinaria__28_septiembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__79___especial__28_septiembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__79___especial__28_septiembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__7___ordinaria__5_abril___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__7___ordinaria__5_abril___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__80___ordinaria__3_octubre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__80___ordinaria__3_octubre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__81___ordinaria__4_octubre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__81___ordinaria__4_octubre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__82___ordinaria__5_octubre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__82___ordinaria__5_octubre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__83___especial__5_octubre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__83___especial__5_octubre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__84___ordinaria__11_octubre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__84___ordinaria__11_octubre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__85___ordinaria__12_octubre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__85___ordinaria__12_octubre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__86___ordinaria__17_octubre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__86___ordinaria__17_octubre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__87___ordinaria__18_octubre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__87___ordinaria__18_octubre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__88___ordinaria__19_octubre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__88___ordinaria__19_octubre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__89___ordinaria__24_octubre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__89___ordinaria__24_octubre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__8___ordinaria__6_abril___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__8___ordinaria__6_abril___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__90___ordinaria__25_octubre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__90___ordinaria__25_octubre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__91___ordinaria__26_octubre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__91___ordinaria__26_octubre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__92___ordinaria__7_noviembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__92___ordinaria__7_noviembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__93___ordinaria__8_noviembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__93___ordinaria__8_noviembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__94___especial__8_noviembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__94___especial__8_noviembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__95___ordinaria__9_noviembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__95___ordinaria__9_noviembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__96___ordinaria__14_noviembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__96___ordinaria__14_noviembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__97___especial__15_noviembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__97___especial__15_noviembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__98___ordinaria__16_noviembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__98___ordinaria__16_noviembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__99___ordinaria__21_noviembre___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__99___ordinaria__21_noviembre___2022.json
# ✅ Convertido: 370__LEGISLATURA__mar._2022_-_mar._2023__9___ordinaria__11_abril___2022.pdf -> 370__LEGISLATURA__mar._2022_-_mar._2023__9___ordinaria__11_abril___2022.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__100___ordinaria__8_noviembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__100___ordinaria__8_noviembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__101___ordinaria__13_noviembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__101___ordinaria__13_noviembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__102___especial__14_noviembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__102___especial__14_noviembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__103___ordinaria__15_noviembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__103___ordinaria__15_noviembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__104___especial__16_noviembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__104___especial__16_noviembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__105___especial__17_noviembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__105___especial__17_noviembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__106___ordinaria__20_noviembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__106___ordinaria__20_noviembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__107___ordinaria__21_noviembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__107___ordinaria__21_noviembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__108___ordinaria__22_noviembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__108___ordinaria__22_noviembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__109___especial__27_noviembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__109___especial__27_noviembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__10___especial__28_marzo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__10___especial__28_marzo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__110___ordinaria__28_noviembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__110___ordinaria__28_noviembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__111___especial__28_noviembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__111___especial__28_noviembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__112___ordinaria__29_noviembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__112___ordinaria__29_noviembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__113___especial__29_noviembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__113___especial__29_noviembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__114___ordinaria__11_diciembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__114___ordinaria__11_diciembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__115___ordinaria__12_diciembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__115___ordinaria__12_diciembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__116___especial__12_diciembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__116___especial__12_diciembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__117___ordinaria__13_diciembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__117___ordinaria__13_diciembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__118___especial__13_diciembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__118___especial__13_diciembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__119___ordinaria__18_diciembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__119___ordinaria__18_diciembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__11___especial__29_marzo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__11___especial__29_marzo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__120___ordinaria__19_diciembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__120___ordinaria__19_diciembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__121___especial__19_diciembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__121___especial__19_diciembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__122___ordinaria__20_diciembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__122___ordinaria__20_diciembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__123___especial__21_diciembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__123___especial__21_diciembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__124___ordinaria__3_enero___2024.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__124___ordinaria__3_enero___2024.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__125___especial__3_enero___2024.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__125___especial__3_enero___2024.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__126___ordinaria__4_enero___2024.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__126___ordinaria__4_enero___2024.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__127___ordinaria__8_enero___2024.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__127___ordinaria__8_enero___2024.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__128___ordinaria__9_enero___2024.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__128___ordinaria__9_enero___2024.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__129___ordinaria__10_enero___2024.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__129___ordinaria__10_enero___2024.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__12___ordinaria__3_abril___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__12___ordinaria__3_abril___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__130___ordinaria__15_enero___2024.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__130___ordinaria__15_enero___2024.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__131___ordinaria__16_enero___2024.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__131___ordinaria__16_enero___2024.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__132___ordinaria__17_enero___2024.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__132___ordinaria__17_enero___2024.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__133___ordinaria__22_enero___2024.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__133___ordinaria__22_enero___2024.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__134___ordinaria__23_enero___2024.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__134___ordinaria__23_enero___2024.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__136___ordinaria__24_enero___2024.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__136___ordinaria__24_enero___2024.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__137___especial__25_enero___2024.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__137___especial__25_enero___2024.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__138___especial__29_enero___2024.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__138___especial__29_enero___2024.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__139___especial__30_enero___2024.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__139___especial__30_enero___2024.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__13___ordinaria__4_abril___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__13___ordinaria__4_abril___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__140___ordinaria__4_marzo___2024.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__140___ordinaria__4_marzo___2024.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__141___ordinaria__5_marzo___2024.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__141___ordinaria__5_marzo___2024.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__142___ordinaria__6_marzo___2024.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__142___ordinaria__6_marzo___2024.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__14___ordinaria__5_abril___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__14___ordinaria__5_abril___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__15___especial__5_abril___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__15___especial__5_abril___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__16___ordinaria__10_abril___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__16___ordinaria__10_abril___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__17___ordinaria__11_abril___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__17___ordinaria__11_abril___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__18___ordinaria__12_abril___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__18___ordinaria__12_abril___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__19___ordinaria__17_abril___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__19___ordinaria__17_abril___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__1___ordinaria__13_marzo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__1___ordinaria__13_marzo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__20___ordinaria__18_abril___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__20___ordinaria__18_abril___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__21___especial__18_abril___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__21___especial__18_abril___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__22___ordinaria__19_abril___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__22___ordinaria__19_abril___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__23___ordinaria__24_abril___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__23___ordinaria__24_abril___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__24___ordinaria__25_abril___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__24___ordinaria__25_abril___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__25___ordinaria__26_abril___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__25___ordinaria__26_abril___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__26___ordinaria__8_mayo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__26___ordinaria__8_mayo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__27___ordinaria__9_mayo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__27___ordinaria__9_mayo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__28___ordinaria__10_mayo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__28___ordinaria__10_mayo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__29___especial__10_mayo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__29___especial__10_mayo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__2___ordinaria__14_marzo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__2___ordinaria__14_marzo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__30___ordinaria__15_mayo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__30___ordinaria__15_mayo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__31___ordinaria__16_mayo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__31___ordinaria__16_mayo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__32___especial__16_mayo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__32___especial__16_mayo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__33___ordinaria__17_mayo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__33___ordinaria__17_mayo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__34___especial__17_mayo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__34___especial__17_mayo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__35___ordinaria__29_mayo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__35___ordinaria__29_mayo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__36___ordinaria__30_mayo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__36___ordinaria__30_mayo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__37___ordinaria__31_mayo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__37___ordinaria__31_mayo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__38___ordinaria__5_junio___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__38___ordinaria__5_junio___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__39___ordinaria__6_junio___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__39___ordinaria__6_junio___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__3___especial__14_marzo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__3___especial__14_marzo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__40___especial__6_junio___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__40___especial__6_junio___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__41___ordinaria__7_junio___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__41___ordinaria__7_junio___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__42___especial__7_junio___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__42___especial__7_junio___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__43___ordinaria__12_junio___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__43___ordinaria__12_junio___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__44___ordinaria__13_junio___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__44___ordinaria__13_junio___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__45___especial__13_junio___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__45___especial__13_junio___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__46___ordinaria__14_junio___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__46___ordinaria__14_junio___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__47___ordinaria__19_junio___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__47___ordinaria__19_junio___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__48___ordinaria__20_junio___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__48___ordinaria__20_junio___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__49___ordinaria__3_julio___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__49___ordinaria__3_julio___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__4___ordinaria__15_marzo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__4___ordinaria__15_marzo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__50___especial__4_julio___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__50___especial__4_julio___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__51___ordinaria__5_julio___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__51___ordinaria__5_julio___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__52___ordinaria__10_julio___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__52___ordinaria__10_julio___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__53___ordinaria__11_julio___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__53___ordinaria__11_julio___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__54___ordinaria__12_julio___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__54___ordinaria__12_julio___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__55___ordinaria__24_julio___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__55___ordinaria__24_julio___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__57___especial__25_julio___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__57___especial__25_julio___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__58___ordinaria__26_julio___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__58___ordinaria__26_julio___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__59___ordinaria__31_julio___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__59___ordinaria__31_julio___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__5___ordinaria__20_marzo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__5___ordinaria__20_marzo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__60___ordinaria__1_agosto___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__60___ordinaria__1_agosto___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__61___ordinaria__2_agosto___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__61___ordinaria__2_agosto___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__62___especial__2_agosto___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__62___especial__2_agosto___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__63___ordinaria__7_agosto___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__63___ordinaria__7_agosto___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__64___ordinaria__8_agosto___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__64___ordinaria__8_agosto___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__65___ordinaria__9_agosto___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__65___ordinaria__9_agosto___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__66___ordinaria__21_agosto___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__66___ordinaria__21_agosto___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__67___ordinaria__22_agosto___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__67___ordinaria__22_agosto___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__68___ordinaria__23_agosto___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__68___ordinaria__23_agosto___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__69___ordinaria__28_agosto___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__69___ordinaria__28_agosto___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__6___ordinaria__21_marzo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__6___ordinaria__21_marzo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__70___ordinaria__29_agosto___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__70___ordinaria__29_agosto___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__71___ordinaria__30_agosto___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__71___ordinaria__30_agosto___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__72___ordinaria__4_septiembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__72___ordinaria__4_septiembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__73___ordinaria__5_septiembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__73___ordinaria__5_septiembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__74___ordinaria__6_septiembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__74___ordinaria__6_septiembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__75___especial__6_septiembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__75___especial__6_septiembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__76___ordinaria__11_septiembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__76___ordinaria__11_septiembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__77___ordinaria__12_septiembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__77___ordinaria__12_septiembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__78___especial__12_septiembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__78___especial__12_septiembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__79___ordinaria__13_septiembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__79___ordinaria__13_septiembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__7___ordinaria__22_marzo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__7___ordinaria__22_marzo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__80___ordinaria__25_septiembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__80___ordinaria__25_septiembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__81___ordinaria__26_septiembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__81___ordinaria__26_septiembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__82___especial__26_septiembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__82___especial__26_septiembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__83___ordinaria__27_septiembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__83___ordinaria__27_septiembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__84___especial__27_septiembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__84___especial__27_septiembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__85___ordinaria__2_octubre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__85___ordinaria__2_octubre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__86___ordinaria__3_octubre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__86___ordinaria__3_octubre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__87___ordinaria__4_octubre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__87___ordinaria__4_octubre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__88___ordinaria__10_octubre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__88___ordinaria__10_octubre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__89___ordinaria__11_octubre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__89___ordinaria__11_octubre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__8___especial__22_marzo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__8___especial__22_marzo___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__90___especial__12_octubre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__90___especial__12_octubre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__91___ordinaria__16_octubre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__91___ordinaria__16_octubre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__92___ordinaria__17_octubre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__92___ordinaria__17_octubre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__93___especial__17_octubre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__93___especial__17_octubre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__94___ordinaria__18_octubre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__94___ordinaria__18_octubre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__95___ordinaria__23_octubre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__95___ordinaria__23_octubre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__96___ordinaria__24_octubre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__96___ordinaria__24_octubre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__97___ordinaria__25_octubre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__97___ordinaria__25_octubre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__98___ordinaria__6_noviembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__98___ordinaria__6_noviembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__99___ordinaria__7_noviembre___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__99___ordinaria__7_noviembre___2023.json
# ✅ Convertido: 371__LEGISLATURA__mar._2023_-_mar._2024__9___especial__28_marzo___2023.pdf -> 371__LEGISLATURA__mar._2023_-_mar._2024__9___especial__28_marzo___2023.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__100___especial__12_noviembre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__100___especial__12_noviembre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__101___especial__12_noviembre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__101___especial__12_noviembre___2024.json
# ...
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__79___ordinaria__25_septiembre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__79___ordinaria__25_septiembre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__7___especial__19_marzo___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__7___especial__19_marzo___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__80___ordinaria__30_septiembre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__80___ordinaria__30_septiembre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__81___ordinaria__1_octubre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__81___ordinaria__1_octubre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__82___especial__1_octubre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__82___especial__1_octubre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__83___ordinaria__2_octubre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__83___ordinaria__2_octubre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__84___ordinaria__7_octubre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__84___ordinaria__7_octubre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__85___ordinaria__8_octubre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__85___ordinaria__8_octubre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__86___ordinaria__9_octubre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__86___ordinaria__9_octubre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__87___especial__10_octubre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__87___especial__10_octubre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__88___ordinaria__14_octubre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__88___ordinaria__14_octubre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__89___ordinaria__15_octubre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__89___ordinaria__15_octubre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__8___ordinaria__20_marzo___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__8___ordinaria__20_marzo___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__90___ordinaria__16_octubre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__90___ordinaria__16_octubre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__91___especial__16_octubre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__91___especial__16_octubre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__92___ordinaria__28_octubre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__92___ordinaria__28_octubre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__93___ordinaria__29_octubre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__93___ordinaria__29_octubre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__94___especial__29_octubre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__94___especial__29_octubre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__95___ordinaria__30_octubre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__95___ordinaria__30_octubre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__96___ordinaria__4_noviembre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__96___ordinaria__4_noviembre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__97___ordinaria__5_noviembre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__97___ordinaria__5_noviembre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__98___ordinaria__6_noviembre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__98___ordinaria__6_noviembre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__99___ordinaria__11_noviembre___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__99___ordinaria__11_noviembre___2024.json
# ✅ Convertido: 372__LEGISLATURA__mar._2024_-_mar._2025__9___especial__20_marzo___2024.pdf -> 372__LEGISLATURA__mar._2024_-_mar._2025__9___especial__20_marzo___2024.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__10___ordinaria__8_abril___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__10___ordinaria__8_abril___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__11___ordinaria__9_abril___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__11___ordinaria__9_abril___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__12___ordinaria__14_abril___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__12___ordinaria__14_abril___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__13___ordinaria__15_abril___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__13___ordinaria__15_abril___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__14___especial__15_abril___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__14___especial__15_abril___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__15___ordinaria__16_abril___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__15___ordinaria__16_abril___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__16___ordinaria__21_abril___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__16___ordinaria__21_abril___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__17___ordinaria__22_abril___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__17___ordinaria__22_abril___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__18___ordinaria__23_abril___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__18___ordinaria__23_abril___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__19___ordinaria__5_mayo___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__19___ordinaria__5_mayo___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__1___ordinaria__11_marzo___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__1___ordinaria__11_marzo___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__20___ordinaria__6_mayo___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__20___ordinaria__6_mayo___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__21___especial__6_mayo___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__21___especial__6_mayo___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__22___ordinaria__7_mayo___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__22___ordinaria__7_mayo___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__23___ordinaria__12_mayo___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__23___ordinaria__12_mayo___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__24___ordinaria__13_mayo___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__24___ordinaria__13_mayo___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__25___ordinaria__14_mayo___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__25___ordinaria__14_mayo___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__26___especial__15_mayo___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__26___especial__15_mayo___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__27___ordinaria__19_mayo___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__27___ordinaria__19_mayo___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__28___especial__19_mayo___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__28___especial__19_mayo___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__29___ordinaria__20_mayo___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__29___ordinaria__20_mayo___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__2___ordinaria__12_marzo___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__2___ordinaria__12_marzo___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__30___ordinaria__2_junio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__30___ordinaria__2_junio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__31___ordinaria__3_junio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__31___ordinaria__3_junio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__32___especial__3_junio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__32___especial__3_junio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__33___ordinaria__4_junio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__33___ordinaria__4_junio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__34___ordinaria__9_junio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__34___ordinaria__9_junio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__35___ordinaria__10_junio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__35___ordinaria__10_junio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__36___ordinaria__11_junio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__36___ordinaria__11_junio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__37___especial__16_junio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__37___especial__16_junio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__38___ordinaria__16_junio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__38___ordinaria__16_junio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__39___ordinaria__17_junio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__39___ordinaria__17_junio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__3___ordinaria__17_marzo___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__3___ordinaria__17_marzo___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__40___ordinaria__18_junio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__40___ordinaria__18_junio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__41___especial__30_junio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__41___especial__30_junio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__42___ordinaria__30_junio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__42___ordinaria__30_junio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__43___ordinaria__1_julio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__43___ordinaria__1_julio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__44___ordinaria__2_julio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__44___ordinaria__2_julio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__45___ordinaria__7_julio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__45___ordinaria__7_julio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__46___ordinaria__8_julio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__46___ordinaria__8_julio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__47___ordinaria__9_julio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__47___ordinaria__9_julio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__48___especial__14_julio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__48___especial__14_julio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__49___ordinaria__14_julio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__49___ordinaria__14_julio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__4___ordinaria__18_marzo___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__4___ordinaria__18_marzo___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__50___ordinaria__15_julio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__50___ordinaria__15_julio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__51___ordinaria__21_julio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__51___ordinaria__21_julio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__52___ordinaria__22_julio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__52___ordinaria__22_julio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__53___ordinaria__23_julio___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__53___ordinaria__23_julio___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__54___ordinaria__4_agosto___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__54___ordinaria__4_agosto___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__55___ordinaria__5_agosto___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__55___ordinaria__5_agosto___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__57___ordinaria__11_agosto___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__57___ordinaria__11_agosto___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__58___ordinaria__12_agosto___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__58___ordinaria__12_agosto___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__59___ordinaria__13_agosto___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__59___ordinaria__13_agosto___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__5___ordinaria__19_marzo___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__5___ordinaria__19_marzo___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__60___ordinaria__19_agosto___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__60___ordinaria__19_agosto___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__61___ordinaria__20_agosto___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__61___ordinaria__20_agosto___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__62___ordinaria__21_agosto___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__62___ordinaria__21_agosto___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__63___ordinaria__1_septiembre___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__63___ordinaria__1_septiembre___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__64___ordinaria__2_septiembre___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__64___ordinaria__2_septiembre___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__65___especial__2_septiembre___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__65___especial__2_septiembre___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__66___ordinaria__3_septiembre___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__66___ordinaria__3_septiembre___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__67___ordinaria__8_septiembre___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__67___ordinaria__8_septiembre___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__68___ordinaria__9_septiembre___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__68___ordinaria__9_septiembre___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__6___ordinaria__24_marzo___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__6___ordinaria__24_marzo___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__7___ordinaria__25_marzo___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__7___ordinaria__25_marzo___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__8___ordinaria__26_marzo___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__8___ordinaria__26_marzo___2025.json
# ✅ Convertido: 373__LEGISLATURA__mar._2025_-_mar._2026__9___ordinaria__7_abril___2025.pdf -> 373__LEGISLATURA__mar._2025_-_mar._2026__9___ordinaria__7_abril___2025.json
#
# 🏁 Proceso de conversión finalizado.
#    Archivos convertidos exitosamente: 478
#    Archivos con errores: 0
#    Resultados guardados en: C:\Users\conjv\Desktop\json_descargados

# %%
import os
import re

# --- Configuración ---
# Directorio base donde están tus carpetas 'legislatura_XXX'
# (Basado en tu ejemplo: json_descargados/legislatura_372/...)
base_dir = "json_descargados" 
# ---------------------

# Patrón Regex para buscar el número de sesión en el *nombre del archivo*
# Esto es más fiable que el @NUMERO_SESION dentro del JSON,
# que a veces es '0' (como en boletin_111.json).
#
# Este patrón busca: __[NUMERO]___[TIPO]__
# Ejemplo: ...__5___ordinaria__... o ...__1___ordinaria__...
#
# __(\d+)_ -> Captura el grupo de dígitos (el número de sesión)
# _{2,}     -> Busca al menos 2 guiones bajos (para ___)
# (ordinaria|especial|extraordinaria) -> Busca el tipo de sesión para confirmar
#
filename_pattern = re.compile(r'__(\d+)_{2,}(ordinaria|especial|extraordinaria)', re.IGNORECASE)

print(f"🚀 Iniciando el proceso de renombrado en: {os.path.abspath(base_dir)}")
print("   Modo: Extrayendo N° de Sesión desde el *nombre del archivo* (es el método más fiable).")

files_renamed = 0
files_failed = 0
files_skipped = 0

if not os.path.isdir(base_dir):
    print(f"❌ Error: El directorio base '{base_dir}' no existe. Por favor, verifica la ruta.")
else:
    # Usamos os.walk para recorrer todas las subcarpetas
    for root, dirs, files in os.walk(base_dir):
        
        # No procesamos el directorio base, solo sus subcarpetas
        # (Asumiendo que los JSON están en legislatura_XXX)
        if root == base_dir:
            continue
            
        print(f"\n📁 Revisando carpeta: {root}")
        
        for filename in files:
            # Solo procesar archivos .json
            if filename.endswith(".json"):
                original_file_path = os.path.join(root, filename)

                # Omitir archivos que ya están renombrados
                if filename.startswith("boletin_"):
                    files_skipped += 1
                    continue

                # 1. Buscar el patrón en el nombre del archivo
                match = filename_pattern.search(filename)
                
                if match:
                    try:
                        # 2. Extraer el número de sesión (el primer grupo capturado)
                        sesion_numero_str = match.group(1)
                        # Limpiar ceros a la izquierda (ej: "005" -> "5")
                        sesion_numero_limpio = str(int(sesion_numero_str)) 
                        
                        # 3. Construir el nuevo nombre y ruta
                        nuevo_nombre = f"boletin_{sesion_numero_limpio}.json"
                        nuevo_file_path = os.path.join(root, nuevo_nombre)
                        
                        if os.path.exists(nuevo_file_path):
                            print(f"  ⚠️ Advertencia: Ya existe {nuevo_nombre}. Se eliminará el original duplicado: {filename}")
                            os.remove(original_file_path) # Elimina el archivo largo si el 'boletin_X.json' ya existe
                            files_failed += 1
                        else:
                            # 4. Renombrar el archivo
                            os.rename(original_file_path, nuevo_file_path)
                            print(f"  ✅ Renombrado: {filename} -> {nuevo_nombre}")
                            files_renamed += 1
                    
                    except Exception as e:
                        print(f"  ❌ Error (Inesperado) procesando {filename}: {e}")
                        files_failed += 1
                else:
                    # Si el nombre del archivo NO coincide con el patrón esperado
                    print(f"  ❌ Error (Patrón no encontrado): {filename}")
                    files_failed += 1

print("\n🏁 Proceso finalizado.")
print(f"   Archivos renombrados: {files_renamed}")
print(f"   Archivos omitidos (ya nombrados): {files_skipped}")
print(f"   Archivos fallidos/duplicados: {files_failed}")
# Out:
# 🚀 Iniciando el proceso de renombrado en: C:\Users\conjv\Desktop\json_descargados
#    Modo: Extrayendo N° de Sesión desde el *nombre del archivo* (es el método más fiable).
#
# 📁 Revisando carpeta: json_descargados\legislatura_372
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__100___especial__12_noviembre___2024.json -> boletin_100.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__101___especial__12_noviembre___2024.json -> boletin_101.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__102___ordinaria__13_noviembre___2024.json -> boletin_102.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__103___especial__14_noviembre___2024.json -> boletin_103.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__104___especial__15_noviembre___2024.json -> boletin_104.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__105___ordinaria__18_noviembre___2024.json -> boletin_105.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__106___ordinaria__19_noviembre___2024.json -> boletin_106.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__107___ordinaria__20_noviembre___2024.json -> boletin_107.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__108___ordinaria__25_noviembre___2024.json -> boletin_108.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__109___ordinaria__26_noviembre___2024.json -> boletin_109.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__10___ordinaria__1_abril___2024.json -> boletin_10.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__110___ordinaria__27_noviembre___2024.json -> boletin_110.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__111___ordinaria__2_diciembre___2024.json -> boletin_111.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__112___ordinaria__3_diciembre___2024.json -> boletin_112.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__113___ordinaria__4_diciembre___2024.json -> boletin_113.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__114___ordinaria__9_diciembre___2024.json -> boletin_114.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__115___ordinaria__10_diciembre___2024.json -> boletin_115.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__116___ordinaria__11_diciembre___2024.json -> boletin_116.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__117___especial__11_diciembre___2024.json -> boletin_117.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__118___ordinaria__16_diciembre___2024.json -> boletin_118.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__119___ordinaria__17_diciembre___2024.json -> boletin_119.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__11___ordinaria__2_abril___2024.json -> boletin_11.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__120___ordinaria__18_diciembre___2024.json -> boletin_120.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__121___especial__18_diciembre___2024.json -> boletin_121.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__122___ordinaria__6_enero___2025.json -> boletin_122.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__123___ordinaria__7_enero___2025.json -> boletin_123.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__124___especial__7_enero___2025.json -> boletin_124.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__125___ordinaria__8_enero___2025.json -> boletin_125.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__126___ordinaria__13_enero___2025.json -> boletin_126.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__127___ordinaria__14_enero___2025.json -> boletin_127.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__128___ordinaria__15_enero___2025.json -> boletin_128.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__129___ordinaria__20_enero___2025.json -> boletin_129.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__12___especial__2_abril___2024.json -> boletin_12.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__130___ordinaria__21_enero___2025.json -> boletin_130.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__131___ordinaria__22_enero___2025.json -> boletin_131.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__132___especial__22_enero___2025.json -> boletin_132.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__133___especial__28_enero___2025.json -> boletin_133.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__134___especial__29_enero___2025.json -> boletin_134.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__135___ordinaria__3_marzo___2025.json -> boletin_135.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__136___ordinaria__4_marzo___2025.json -> boletin_136.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__137___ordinaria__5_marzo___2025.json -> boletin_137.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__138___especial__10_marzo___2025.json -> boletin_138.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__139___ordinaria__10_marzo___2025.json -> boletin_139.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__13___ordinaria__3_abril___2024.json -> boletin_13.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__14___ordinaria__8_abril___2024.json -> boletin_14.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__15___ordinaria__9_abril___2024.json -> boletin_15.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__16___especial__9_abril___2024.json -> boletin_16.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__17___ordinaria__10_abril___2024.json -> boletin_17.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__18___ordinaria__15_abril___2024.json -> boletin_18.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__19___ordinaria__16_abril___2024.json -> boletin_19.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__1___ordinaria__11_marzo___2024.json -> boletin_1.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__20___ordinaria__17_abril___2024.json -> boletin_20.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__21___ordinaria__22_abril___2024.json -> boletin_21.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__22___ordinaria__23_abril___2024.json -> boletin_22.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__23___ordinaria__24_abril___2024.json -> boletin_23.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__24___especial__3_mayo___2024.json -> boletin_24.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__25___ordinaria__6_mayo___2024.json -> boletin_25.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__26___ordinaria__7_mayo___2024.json -> boletin_26.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__27___ordinaria__8_mayo___2024.json -> boletin_27.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__28___ordinaria__13_mayo___2024.json -> boletin_28.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__29___ordinaria__14_mayo___2024.json -> boletin_29.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__2___ordinaria__12_marzo___2024.json -> boletin_2.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__30___especial__14_mayo___2024.json -> boletin_30.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__31___ordinaria__15_mayo___2024.json -> boletin_31.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__32___ordinaria__29_mayo___2024.json -> boletin_32.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__33___ordinaria__30_mayo___2024.json -> boletin_33.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__34___especial__30_mayo___2024.json -> boletin_34.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__35___ordinaria__31_mayo___2024.json -> boletin_35.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__36___ordinaria__3_junio___2024.json -> boletin_36.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__37___ordinaria__4_junio___2024.json -> boletin_37.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__38___ordinaria__5_junio___2024.json -> boletin_38.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__39___ordinaria__10_junio___2024.json -> boletin_39.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__3___especial__12_marzo___2024.json -> boletin_3.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__40___ordinaria__11_junio___2024.json -> boletin_40.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__41___ordinaria__12_junio___2024.json -> boletin_41.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__42___ordinaria__17_junio___2024.json -> boletin_42.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__43___ordinaria__18_junio___2024.json -> boletin_43.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__44___ordinaria__19_junio___2024.json -> boletin_44.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__45___ordinaria__1_julio___2024.json -> boletin_45.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__46___ordinaria__2_julio___2024.json -> boletin_46.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__47___ordinaria__3_julio___2024.json -> boletin_47.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__48___especial__4_julio___2024.json -> boletin_48.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__49___ordinaria__8_julio___2024.json -> boletin_49.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__4___ordinaria__13_marzo___2024.json -> boletin_4.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__50___ordinaria__9_julio___2024.json -> boletin_50.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__51___ordinaria__10_julio___2024.json -> boletin_51.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__52___especial__10_julio___2024.json -> boletin_52.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__53___ordinaria__22_julio___2024.json -> boletin_53.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__54___ordinaria__23_julio___2024.json -> boletin_54.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__55___especial__23_julio___2024.json -> boletin_55.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__57___ordinaria__29_julio___2024.json -> boletin_57.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__58___ordinaria__30_julio___2024.json -> boletin_58.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__59___ordinaria__31_julio___2024.json -> boletin_59.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__5___ordinaria__18_marzo___2024.json -> boletin_5.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__60___ordinaria__5_agosto___2024.json -> boletin_60.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__61___ordinaria__6_agosto___2024.json -> boletin_61.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__62___especial__6_agosto___2024.json -> boletin_62.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__63___ordinaria__7_agosto___2024.json -> boletin_63.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__64___ordinaria__12_agosto___2024.json -> boletin_64.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__65___ordinaria__13_agosto___2024.json -> boletin_65.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__66___ordinaria__14_agosto___2024.json -> boletin_66.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__67___ordinaria__26_agosto___2024.json -> boletin_67.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__68___ordinaria__27_agosto___2024.json -> boletin_68.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__69___ordinaria__28_agosto___2024.json -> boletin_69.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__6___ordinaria__19_marzo___2024.json -> boletin_6.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__70___ordinaria__2_septiembre___2024.json -> boletin_70.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__71___ordinaria__3_septiembre___2024.json -> boletin_71.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__72___ordinaria__4_septiembre___2024.json -> boletin_72.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__73___ordinaria__9_septiembre___2024.json -> boletin_73.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__74___ordinaria__10_septiembre___2024.json -> boletin_74.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__75___especial__10_septiembre___2024.json -> boletin_75.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__76___ordinaria__11_septiembre___2024.json -> boletin_76.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__77___ordinaria__23_septiembre___2024.json -> boletin_77.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__78___ordinaria__24_septiembre___2024.json -> boletin_78.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__79___ordinaria__25_septiembre___2024.json -> boletin_79.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__7___especial__19_marzo___2024.json -> boletin_7.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__80___ordinaria__30_septiembre___2024.json -> boletin_80.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__81___ordinaria__1_octubre___2024.json -> boletin_81.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__82___especial__1_octubre___2024.json -> boletin_82.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__83___ordinaria__2_octubre___2024.json -> boletin_83.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__84___ordinaria__7_octubre___2024.json -> boletin_84.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__85___ordinaria__8_octubre___2024.json -> boletin_85.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__86___ordinaria__9_octubre___2024.json -> boletin_86.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__87___especial__10_octubre___2024.json -> boletin_87.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__88___ordinaria__14_octubre___2024.json -> boletin_88.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__89___ordinaria__15_octubre___2024.json -> boletin_89.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__8___ordinaria__20_marzo___2024.json -> boletin_8.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__90___ordinaria__16_octubre___2024.json -> boletin_90.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__91___especial__16_octubre___2024.json -> boletin_91.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__92___ordinaria__28_octubre___2024.json -> boletin_92.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__93___ordinaria__29_octubre___2024.json -> boletin_93.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__94___especial__29_octubre___2024.json -> boletin_94.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__95___ordinaria__30_octubre___2024.json -> boletin_95.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__96___ordinaria__4_noviembre___2024.json -> boletin_96.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__97___ordinaria__5_noviembre___2024.json -> boletin_97.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__98___ordinaria__6_noviembre___2024.json -> boletin_98.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__99___ordinaria__11_noviembre___2024.json -> boletin_99.json
#   ✅ Renombrado: 372__LEGISLATURA__mar._2024_-_mar._2025__9___especial__20_marzo___2024.json -> boletin_9.json
#
# 📁 Revisando carpeta: json_descargados\legislatura_373
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__10___ordinaria__8_abril___2025.json -> boletin_10.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__11___ordinaria__9_abril___2025.json -> boletin_11.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__12___ordinaria__14_abril___2025.json -> boletin_12.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__13___ordinaria__15_abril___2025.json -> boletin_13.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__14___especial__15_abril___2025.json -> boletin_14.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__15___ordinaria__16_abril___2025.json -> boletin_15.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__16___ordinaria__21_abril___2025.json -> boletin_16.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__17___ordinaria__22_abril___2025.json -> boletin_17.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__18___ordinaria__23_abril___2025.json -> boletin_18.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__19___ordinaria__5_mayo___2025.json -> boletin_19.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__1___ordinaria__11_marzo___2025.json -> boletin_1.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__20___ordinaria__6_mayo___2025.json -> boletin_20.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__21___especial__6_mayo___2025.json -> boletin_21.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__22___ordinaria__7_mayo___2025.json -> boletin_22.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__23___ordinaria__12_mayo___2025.json -> boletin_23.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__24___ordinaria__13_mayo___2025.json -> boletin_24.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__25___ordinaria__14_mayo___2025.json -> boletin_25.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__26___especial__15_mayo___2025.json -> boletin_26.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__27___ordinaria__19_mayo___2025.json -> boletin_27.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__28___especial__19_mayo___2025.json -> boletin_28.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__29___ordinaria__20_mayo___2025.json -> boletin_29.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__2___ordinaria__12_marzo___2025.json -> boletin_2.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__30___ordinaria__2_junio___2025.json -> boletin_30.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__31___ordinaria__3_junio___2025.json -> boletin_31.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__32___especial__3_junio___2025.json -> boletin_32.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__33___ordinaria__4_junio___2025.json -> boletin_33.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__34___ordinaria__9_junio___2025.json -> boletin_34.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__35___ordinaria__10_junio___2025.json -> boletin_35.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__36___ordinaria__11_junio___2025.json -> boletin_36.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__37___especial__16_junio___2025.json -> boletin_37.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__38___ordinaria__16_junio___2025.json -> boletin_38.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__39___ordinaria__17_junio___2025.json -> boletin_39.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__3___ordinaria__17_marzo___2025.json -> boletin_3.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__40___ordinaria__18_junio___2025.json -> boletin_40.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__41___especial__30_junio___2025.json -> boletin_41.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__42___ordinaria__30_junio___2025.json -> boletin_42.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__43___ordinaria__1_julio___2025.json -> boletin_43.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__44___ordinaria__2_julio___2025.json -> boletin_44.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__45___ordinaria__7_julio___2025.json -> boletin_45.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__46___ordinaria__8_julio___2025.json -> boletin_46.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__47___ordinaria__9_julio___2025.json -> boletin_47.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__48___especial__14_julio___2025.json -> boletin_48.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__49___ordinaria__14_julio___2025.json -> boletin_49.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__4___ordinaria__18_marzo___2025.json -> boletin_4.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__50___ordinaria__15_julio___2025.json -> boletin_50.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__51___ordinaria__21_julio___2025.json -> boletin_51.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__52___ordinaria__22_julio___2025.json -> boletin_52.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__53___ordinaria__23_julio___2025.json -> boletin_53.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__54___ordinaria__4_agosto___2025.json -> boletin_54.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__55___ordinaria__5_agosto___2025.json -> boletin_55.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__57___ordinaria__11_agosto___2025.json -> boletin_57.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__58___ordinaria__12_agosto___2025.json -> boletin_58.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__59___ordinaria__13_agosto___2025.json -> boletin_59.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__5___ordinaria__19_marzo___2025.json -> boletin_5.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__60___ordinaria__19_agosto___2025.json -> boletin_60.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__61___ordinaria__20_agosto___2025.json -> boletin_61.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__62___ordinaria__21_agosto___2025.json -> boletin_62.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__63___ordinaria__1_septiembre___2025.json -> boletin_63.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__64___ordinaria__2_septiembre___2025.json -> boletin_64.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__65___especial__2_septiembre___2025.json -> boletin_65.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__66___ordinaria__3_septiembre___2025.json -> boletin_66.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__67___ordinaria__8_septiembre___2025.json -> boletin_67.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__68___ordinaria__9_septiembre___2025.json -> boletin_68.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__6___ordinaria__24_marzo___2025.json -> boletin_6.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__7___ordinaria__25_marzo___2025.json -> boletin_7.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__8___ordinaria__26_marzo___2025.json -> boletin_8.json
#   ✅ Renombrado: 373__LEGISLATURA__mar._2025_-_mar._2026__9___ordinaria__7_abril___2025.json -> boletin_9.json
#
# 🏁 Proceso finalizado.
#    Archivos renombrados: 205
#    Archivos omitidos (ya nombrados): 0
#    Archivos fallidos/duplicados: 0

# %%
import json
import pandas as pd
import os
import re
import traceback

# --- Funciones Auxiliares (Robustecidas v14) ---

def safe_strip(data, default=""):
    """Limpia espacios en blanco de forma segura si es un string, sino devuelve default."""
    if isinstance(data, str):
        # Reemplazar múltiples espacios/saltos de línea con un solo
        return re.sub(r'\s+', ' ', data).strip()
    return default

def extract_legislatura(portada_text):
    """(NUEVO v13) Extrae el número de legislatura desde el texto de portada."""
    if not isinstance(portada_text, str):
        return 'N/A'
    
    # Busca "LEGISLATURA 370ª" o "LEGISLATURA 370a" o "Legislatura 360ª"
    match = re.search(r'LEGISLATURA\s+(\d+)[ªa]', portada_text, re.IGNORECASE)
    if match:
        return match.group(1)
        
    return 'N/A'

def parse_speaker_from_cue(cue_text, attribute_name=""):
    """
    (v12) Extrae nombre COMPLETO y tipo desde el CUE del texto.
    (v14) Mejorado para capturar nombres en formato APELLIDO (don Nombre) y 'La señorita'.
    """
    speaker_name = "Desconocido"
    speaker_type = "Desconocido"
    role_from_cue = ""
    role_text_lower = "" # (NUEVO v14) Inicializar

    # 1. Extraer Tipo (Rol)
    role_match = re.search(r'\((.*?)\)', cue_text)
    is_name_in_parens = False # (NUEVO v14)
    
    if role_match:
        role_from_cue = role_match.group(1).strip()
        role_text_lower = role_from_cue.lower()
        
        # (MODIFICADO v14) Si el paréntesis contiene "don" o "doña", NO es un rol, es parte del nombre.
        if 'don ' in role_text_lower or 'doña ' in role_text_lower:
            is_name_in_parens = True

    # (MODIFICADO v14) Asignar tipo basado en si el paréntesis era un nombre o un rol
    if role_match and not is_name_in_parens:
        # Mapeo de roles (si el paréntesis NO era un nombre)
        if 'vicepresidente' in role_text_lower: speaker_type = "Vicepresidente"
        elif 'presidente accidental' in role_text_lower: speaker_type = "Presidente (Accidental)"
        elif 'presidente' in role_text_lower: speaker_type = "Presidente"
        elif 'ministro' in role_text_lower or 'ministra' in role_text_lower: speaker_type = "Ministro"
        elif 'subsecretario' in role_text_lower or 'subsecretaria' in role_text_lower: speaker_type = "Subsecretario"
        elif 'secretario' in role_text_lower: speaker_type = "Secretario"
        elif 'prosecretario' in role_text_lower: speaker_type = "Prosecretario"
        elif 'senador' in role_text_lower or 'senadora' in role_text_lower: speaker_type = "Senador"
        elif any(role in role_text_lower for role in ['autoridad', 'director', 'fiscal', 'contralor', 'defensor']): speaker_type = "Autoridad"
        else: speaker_type = "Diputado" # Default
    else:
        # Heurística (si no hay paréntesis, o si el paréntesis era un nombre)
        lower_cue = cue_text.lower()
        # Evitar que "don" o "doña" se confundan con roles
        if not is_name_in_parens:
            if 'secretario' in lower_cue: speaker_type = "Secretario"
            elif 'prosecretario' in lower_cue: speaker_type = "Prosecretario"
            elif 'ministro' in lower_cue: speaker_type = "Ministro"
            else: speaker_type = "Diputado"
        else:
            speaker_type = "Diputado"

    # 2. Extraer Nombre Completo
    # (MODIFICADO v14) Añadido 'La señorita'
    name_match_regex = r'(?:El señor|La señora|La señorita)\s+(.*?)(?=\s*(?:\(.*\)\.-|\.-))'
    name_match = re.search(name_match_regex, cue_text, re.DOTALL)
    
    if name_match:
        full_name_match = name_match.group(1).strip()
        # (MODIFICADO v14) No quitar 'don' o 'doña' aún.
        speaker_name_cleaned = re.sub(r'\s+', ' ', full_name_match.replace('.', '')).strip()

        if speaker_name_cleaned.upper() == role_from_cue.upper() or \
           (speaker_name_cleaned.upper() == speaker_type.upper() and speaker_type not in ["Diputado", "Desconocido"]):
            
            if attribute_name and attribute_name != "Desconocido" and attribute_name.upper() != speaker_type.upper():
                   speaker_name = attribute_name
            else:
                   speaker_name = speaker_type
        else:
            # (NUEVO v14) Lógica para combinar APELLIDO (don Nombre)
            if is_name_in_parens and (speaker_type == "Diputado" or speaker_name == "Desconocido"):
                
                # speaker_name_cleaned es el APELLIDO (ej. RAMÍREZ)
                # role_from_cue es el Nombre (ej. don Matías)
                first_name_in_parens = re.sub(r'(don |doña )', '', role_from_cue, flags=re.IGNORECASE).strip()
                
                # Formatear a "Nombre Apellido" (ej. "Matías RAMÍREZ")
                speaker_name = f"{first_name_in_parens} {speaker_name_cleaned}"
            else:
                # Limpieza final si no es el caso APELLIDO (don Nombre)
                # (ej. "MUÑOZ, doña Adriana" o "LUCK")
                speaker_name = speaker_name_cleaned.replace('don ', '').replace('doña ', '').strip()
    else:
       if speaker_type != "Diputado": speaker_name = speaker_type
       elif attribute_name and attribute_name != "Desconocido": speaker_name = attribute_name

    # (NUEVO v14) Refinamiento final: si el nombre es solo un APELLIDO (mayúsculas)
    # e 'attribute_name' es un nombre completo, usar 'attribute_name'.
    # (ej. cue es "El señor DITTBORN.-" y attribute_name es "Dittborn, Julio")
    if (speaker_name.isupper() and ' ' not in speaker_name and 
        attribute_name and attribute_name != "Desconocido" and 
        speaker_name.upper() in attribute_name.upper().split(',')[0].strip()): # Comparamos solo con el apellido
        
        speaker_name = attribute_name
    
    speaker_name = speaker_name.rstrip(',').strip()
    return speaker_name, speaker_type


def segment_text_block(text_block, base_speaker_name="Texto No Estructurado", base_speaker_type="Narrador"):
    """
    (NUEVO v13) Divide un bloque #text en múltiples turnos (Cue + Texto).
    También detecta títulos de sección en texto plano.
    """
    dialogues = []
    
    # Regex para cues de orador. Captura (Grupo 1: El cue completo)
    speaker_regex_pattern = r'((?:El señor|La señora|La señorita)\s+.*?\.-\s*)' # (MODIFICADO v14) Añadido 'La señorita'
    # Regex para títulos de sección (Materia)
    section_title_regex_pattern = r'(\n\s*(?:[IVX]+\.?|A?)\s*.-?\s*[A-ZÁÉÍÓÚÑÑ\s,]{5,}(?=\n\s*\n|\n\s*(?:El señor|La señora|La señorita)))' # (MODIFICADO v14) Añadido 'La señorita'
    
    # Patrón combinado para buscar Cues O Títulos
    combined_regex = re.compile(f'({speaker_regex_pattern}|{section_title_regex_pattern})', re.DOTALL)

    # Usar finditer para obtener las posiciones de inicio/fin de cues y títulos
    matches = list(combined_regex.finditer(text_block))
    
    current_topic_title = "Texto Principal No Estructurado" # Default para fallback
    current_speaker_name = base_speaker_name
    current_speaker_type = base_speaker_type
    
    start_index = 0
    if matches:
        first_match_start = matches[0].start()
        # 1. Capturar texto ANTES del primer cue/título
        if first_match_start > 0:
            initial_text = text_block[0:first_match_start].strip()
            if initial_text:
                dialogues.append({
                    'name': current_speaker_name,
                    'type': current_speaker_type,
                    'text': safe_strip(initial_text),
                    'materia_fallback': current_topic_title # (FIX v12) Pasar el título
                })
        start_index = matches[0].end()
    else:
        # No hay matches, todo el bloque es un solo diálogo
        full_text = text_block.strip()
        if full_text:
            dialogues.append({
                'name': current_speaker_name,
                'type': current_speaker_type,
                'text': safe_strip(full_text),
                'materia_fallback': current_topic_title
            })
        return dialogues # Salir si no hay matches

    # 2. Iterar sobre los matches encontrados
    for i, match in enumerate(matches):
        # Determinar si este match es un CUE o un TÍTULO
        is_cue = re.fullmatch(speaker_regex_pattern, match.group(1), re.DOTALL)
        is_title = re.fullmatch(section_title_regex_pattern, match.group(1), re.DOTALL)

        # Determinar el texto que sigue a este match
        end_index = matches[i+1].start() if (i + 1) < len(matches) else len(text_block)
        following_text = text_block[match.end():end_index].strip()
        
        if is_cue:
            cue_text = match.group(1).strip()
            # Parsear el orador desde el cue
            current_speaker_name, current_speaker_type = parse_speaker_from_cue(cue_text, base_speaker_name)
            
            # (FIX v13) Crear UNA sola fila por intervención (Cue + Texto)
            full_dialogue_text = f"{cue_text} {following_text}".strip()
            
            dialogues.append({
                'name': current_speaker_name,
                'type': current_speaker_type,
                'text': safe_strip(full_dialogue_text), # Guardar el texto completo
                'materia_fallback': current_topic_title
            })
        
        elif is_title:
            # Es un título de sección (Materia)
            title_text = safe_strip(match.group(1))
            current_topic_title = re.sub(r'^[IVX]+\.?\s*.-?\s*', '', title_text).strip() # Limpiar "V. -"
            current_topic_title = re.sub(r'\s+', ' ', current_topic_title) # Normalizar espacios
            
            # El texto que sigue (si existe) es un 'Narrador' bajo este nuevo título
            if following_text:
                dialogues.append({
                    'name': "Narrador",
                    'type': "Narrador",
                    'text': safe_strip(following_text),
                    'materia_fallback': current_topic_title
                })
            # El próximo cue pertenecerá a este nuevo título

    return dialogues


def parse_speaker_info_from_attributes(intervention_key, intervention_data):
    """(v11) Extrae nombre COMPLETO y tipo del orador base desde atributos JSON."""
    speaker_name = "Desconocido"
    speaker_type = "Desconocido"
    raw_info = None

    try:
        # Presidente / Vicepresidente
        if intervention_key in ['INTERVENCION_PRESIDENTE', 'INTERVENCION_1VICE']:
            speaker_type = "Presidente" if intervention_key == 'INTERVENCION_PRESIDENTE' else "Vicepresidente"
            raw_info = intervention_data.get('@DIPUTADO', speaker_type)
            raw_info_str = safe_strip(raw_info, "")
            if raw_info_str:
                speaker_name_cleaned = re.sub(r'\s*\([^)]*\)$', '', raw_info_str).strip()
                speaker_name_cleaned = re.sub(r'^(El señor|La señora|La señorita)\s*', '', speaker_name_cleaned, flags=re.IGNORECASE).strip() # (MODIFICADO v14)
                speaker_name_cleaned = speaker_name_cleaned.replace('don ', '').replace('doña ', '').strip()
                if 'Vicepresident' in raw_info_str or 'Vicepresidenta' in raw_info_str: speaker_type = "Vicepresidente"
                elif 'accidental' in raw_info_str.lower() and 'Presidente' in speaker_type: speaker_type = "Presidente (Accidental)"
                speaker_name = speaker_name_cleaned if speaker_name_cleaned else speaker_type
            else: speaker_name = speaker_type
        # Diputado
        elif intervention_key == 'INTERVENCION_DIPUTADO':
            speaker_type = "Diputado"
            raw_info = intervention_data.get('@DIPUTADO', 'Diputado Desconocido')
            raw_info_str = safe_strip(raw_info, "")
            if raw_info_str:
                speaker_name_cleaned = re.sub(r'\s*\([^)]*\)$', '', raw_info_str).strip()
                speaker_name_cleaned = speaker_name_cleaned.replace('don ', '').replace('doña ', '').strip()
                speaker_name = speaker_name_cleaned if speaker_name_cleaned else "Diputado Desconocido"
            else: speaker_name = "Diputado Desconocido"
        # Autoridad
        elif intervention_key == 'INTERVENCION_AUTORIDAD':
            speaker_type = "Autoridad"
            raw_info = intervention_data.get('@DESCRIPCION', 'Autoridad Desconocida')
            raw_info_str = safe_strip(raw_info, "")
            if raw_info_str:
                name_match = re.search(r"(?:señor|señora)\s+([A-ZÁÉÍÓÚÑÑ][A-Za-záéíóúñÁÉÍÓÚÑÑ\s,'-]+)(?:,|\.|$)", raw_info_str)
                if name_match: speaker_name = name_match.group(1).strip()
                else:
                    speaker_name = raw_info_str.split(',')[0].strip();
                    if len(speaker_name) > 60: speaker_name = "Autoridad (ver desc.)"
                lower_info = raw_info_str.lower()
                if 'ministro' in lower_info or 'ministra' in lower_info: speaker_type = "Ministro"
                elif 'subsecretario' in lower_info or 'subsecretaria' in lower_info: speaker_type = "Subsecretario"
                elif 'senador' in lower_info or 'senadora' in lower_info: speaker_type = "Senador"
                elif 'fiscal' in lower_info: speaker_type = "Fiscal"
                elif 'director' in lower_info or 'directora' in lower_info : speaker_type = "Director"
                elif 'contralor' in lower_info: speaker_type = "Contralor"
                elif 'defensor' in lower_info: speaker_type = "Defensor"
                else: speaker_type = "Autoridad"
            else: speaker_name = "Autoridad Desconocida"
        # Otros roles
        elif intervention_key == 'INTERVENCION_SECRETARIO':
            speaker_type = "Secretario"
            raw_info = intervention_data.get('@SECRETARIO', 'Secretario')
            raw_info_str = safe_strip(raw_info, "")
            if raw_info_str and raw_info_str != "Secretario":
                 speaker_name_cleaned = re.sub(r'\s*\([^)]*\)$', '', raw_info_str).strip()
                 speaker_name_cleaned = re.sub(r'^(El señor|La señora|La señorita)\s*', '', speaker_name_cleaned, flags=re.IGNORECASE).strip() # (MODIFICADO v14)
                 speaker_name_cleaned = speaker_name_cleaned.replace('don ', '').replace('doña ', '').strip()
                 speaker_name = speaker_name_cleaned if speaker_name_cleaned else "Secretario"
            else: speaker_name = "Secretario"
        elif intervention_key == 'INTERVENCION_PROSECRETARIO':
            speaker_type = "Prosecretario"
            raw_info = intervention_data.get('@PROSECRETARIO', 'Prosecretario')
            raw_info_str = safe_strip(raw_info, "")
            if raw_info_str and raw_info_str != "Prosecretario":
                 speaker_name_cleaned = re.sub(r'\s*\([^)]*\)$', '', raw_info_str).strip()
                 speaker_name_cleaned = re.sub(r'^(El señor|La señora|La señorita)\s*', '', speaker_name_cleaned, flags=re.IGNORECASE).strip() # (MODIFICADO v14)
                 speaker_name_cleaned = speaker_name_cleaned.replace('don ', '').replace('doña ', '').strip()
                 speaker_name = speaker_name_cleaned if speaker_name_cleaned else "Prosecretario"
            else: speaker_name = "Prosecretario"
        elif intervention_key == 'INTERVENCION_SENADOR':
             speaker_type = "Senador"
             raw_info = intervention_data.get('@SENADOR', 'Senador Desconocido')
             raw_info_str = safe_strip(raw_info, "")
             speaker_name_cleaned = re.sub(r'\s*\([^)]*\)$', '', raw_info_str).strip()
             speaker_name_cleaned = speaker_name_cleaned.replace('don ', '').replace('doña ', '').strip()
             speaker_name = speaker_name_cleaned if speaker_name_cleaned else "Senador Desconocido"
             
        if isinstance(speaker_name, str):
            speaker_name = speaker_name.rstrip(',').strip()
        else: speaker_name = "Error Nombre"

    except Exception as e:
        speaker_name = "Error Nombre Attr"
        speaker_type = "Error Tipo Attr"

    # Devolvemos solo nombre y tipo
    return speaker_name, speaker_type


# Lista global de claves de intervención
potential_intervention_keys = [
    'INTERVENCION_PRESIDENTE', 'INTERVENCION_DIPUTADO', 'INTERVENCION_AUTORIDAD',
    'INTERVENCION_SECRETARIO', 'INTERVENCION_PROSECRETARIO', 'INTERVENCION_1VICE',
    'INTERVENCION_SENADOR', 'INTERVENCION_AFAVOR', 'INTERVENCION_ENCONTRA'
]

# Lista de claves a ignorar en recursión (simplificada)
keys_to_ignore_recursion = [
    '#text', '@TEMPLATE', '@VALID', '@NUMERO', '@FECHA_INICIO', '@FECHA_TERMINO', '@TIPO', 
    'PORTADA', 'INDICE', 'ASISTENCIA', 'FIN_SESION', 
    'DOCUMENTOS_CUENTA', 'OTROS_DOCUMENTOS_CUENTA', 'VOTACION',
    '@DESCRIPCION', '@DIPUTADO', '@DIPUTADOValue', 
    '@SENADOR', '@SENADORValue', '@SECRETARIO', '@SECRETARIOValue', 
    '@PROSECRETARIO', '@PROSECRETARIOValue'
    # No ignoramos TITULO ni @BOLETIN para que se propaguen
]

# --- Función Recursiva (v13 - Lógica de Boletín Corregida) ---
def find_interventions_recursive(item, session_info, current_boletin, file_path, all_dialogues, parent_key=None):
    """
    (Mejorada v13) Recorre recursivamente, propaga el boletín y segmenta #text.
    """
    global potential_intervention_keys, keys_to_ignore_recursion, files_with_unexpected_text

    try:
        # 1. Si es un Diccionario
        if isinstance(item, dict):
            
            # (NUEVO v13) Propagación de Boletín
            # Si este dict define un NUEVO boletín, usarlo. Si no, usar el heredado.
            new_bulletin = item.get('@BOLETIN', current_boletin) # Heredar
            # Si el nuevo boletín es diferente Y no es N/A, actualizar el contexto
            if new_bulletin and new_bulletin != 'N/A' and new_bulletin != current_boletin:
                 current_boletin = new_bulletin # Actualizar
            # Si es N/A, mantener el 'current_boletin' heredado (FIX)
            elif new_bulletin == 'N/A' or new_bulletin is None:
                 new_bulletin = current_boletin

            # --- PASO B: Buscar claves de intervención DENTRO de este dict ---
            for key, value in item.items():
                if key in potential_intervention_keys:
                    
                    if value is None: continue
                    value_list = value if isinstance(value, list) else [value]
                    
                    for intervention_item in value_list:
                        
                        actual_intervention_data = intervention_item
                        actual_key = key

                        if key in ['INTERVENCION_AFAVOR', 'INTERVENCION_ENCONTRA']:
                            if isinstance(intervention_item, dict):
                                nested_keys = [k for k in intervention_item if k.startswith('INTERVENCION_')]
                                if nested_keys:
                                    actual_key = nested_keys[0]; actual_intervention_data = intervention_item[actual_key]
                            else: continue
                        if not isinstance(actual_intervention_data, dict): continue

                        # (NUEVO v13) El boletín es el que heredamos (new_bulletin) o el específico de esta intervención
                        item_bulletin = actual_intervention_data.get('@BOLETIN', new_bulletin)
                        if (item_bulletin == 'N/A' or item_bulletin is None) and new_bulletin != 'N/A':
                             item_bulletin = new_bulletin # Asegurar herencia

                        # --- Extraer Orador Base y Texto ---
                        base_speaker_name, base_speaker_type = parse_speaker_info_from_attributes(actual_key, actual_intervention_data)
                        text_content = actual_intervention_data.get('#text')
                        
                        # --- Segmentar el Texto (NUEVO v13) ---
                        if isinstance(text_content, str):
                            # Usar la nueva lógica de segmentación v13
                            segmented_turns = segment_text_block(text_content, base_speaker_name, base_speaker_type)
                            
                            for turn in segmented_turns:
                                speaker_name_final = turn['name']
                                speaker_type_final = turn['type']
                                
                                # Refinamiento
                                if speaker_name_final == "Desconocido" and base_speaker_name != "Desconocido":
                                    speaker_name_final = base_speaker_name; speaker_type_final = base_speaker_type
                                elif speaker_type_final == "Diputado" and base_speaker_type not in ["Diputado", "Desconocido", "Error Tipo", "Error Tipo Attr"]:
                                     if base_speaker_name and speaker_name_final.upper() in base_speaker_name.upper():
                                          speaker_type_final = base_speaker_type
                                          if len(base_speaker_name) > len(speaker_name_final): speaker_name_final = base_speaker_name
                                if speaker_name_final.upper() == "PRESIDENTE": speaker_type_final = "Presidente"

                                all_dialogues.append({
                                    'numero_legislatura': session_info.get('legislatura', 'N/A'), # (NUEVO v13)
                                    'numero_sesion': session_info.get('id'), # (NUEVO v13)
                                    'fecha_sesion': session_info.get('start_time'), # (NUEVO v13)
                                    'boletin_proyecto': item_bulletin, # (FIX v13)
                                    'speaker_name': speaker_name_final, # <-- CAMBIO: Guardar directo, sin '_raw'
                                    'speaker_type': speaker_type_final,
                                    'text': turn['text'], # Texto segmentado
                                    'source_file': file_path
                                })
                                
                        elif text_content is not None:
                             if file_path not in files_with_unexpected_text: files_with_unexpected_text[file_path] = []
                             files_with_unexpected_text[file_path].append(f"Key: {actual_key}, Type: {type(text_content)}")

            # --- PASO C: Recurrir en todos los hijos ---
            for key, value in item.items():
                if key not in potential_intervention_keys and key not in keys_to_ignore_recursion:
                    # Pasar el boletín actualizado (new_bulletin)
                    find_interventions_recursive(value, session_info, new_bulletin, file_path, all_dialogues, parent_key=key)

        # 2. Si es una Lista
        elif isinstance(item, list):
            for element in item:
                # Pasar el boletín heredado (current_boletin)
                find_interventions_recursive(element, session_info, current_boletin, file_path, all_dialogues, parent_key)
        
        else: return # Caso base

    except Exception as e:
        tb_str = traceback.format_exc()
        if file_path not in error_files:
             error_files.append(f"{file_path} (RecursionError: {e})")
        return


# --- Main Processing Loop (v13) ---
all_dialogues = []
processed_files_count = 0
processed_folders = set()
root_directory = 'C:/Users/conjv/Desktop/boletines_json/'
error_files = []
files_with_unexpected_text = {}
dialogues_per_file = {} # (NUEVO v10)

# (ELIMINADO v13 - Normalización) Carga de nombres canónicos eliminada.

print(f"Starting recursive search in '{root_directory}'...")

for dirpath, dirnames, filenames in os.walk(root_directory):
    dirnames[:] = [d for d in dirnames if not d.startswith('.')]
    
    folder_name = os.path.basename(dirpath)
    if folder_name.startswith('legislatura_'):
        print(f"\nProcessing folder: {folder_name}")
        processed_folders.add(folder_name)
        folder_file_count = 0
        json_files_in_folder = sorted([f for f in filenames if f.startswith('boletin_') and f.endswith('.json')])

        if not json_files_in_folder:
            print(f"  No 'boletin_*.json' files found in this folder.")
            continue

        print(f"  Found {len(json_files_in_folder)} JSON files.")

        for file_name in json_files_in_folder:
            file_path = os.path.join(dirpath, file_name)
            initial_length = len(all_dialogues)
            dialogues_in_this_file = 0

            try:
                with open(file_path, 'r', encoding='utf-8') as f:
                    data = json.load(f)

                session_data = data.get('BOLETINXML', {}).get('SESION', {})
                if not session_data:
                    # (NUEVO v14) Intentar buscar SESION en la raíz si BOLETINXML no existe o está vacío
                    session_data = data.get('SESION', {})
                    if not session_data:
                        print(f"    Skipping {file_name}: No SESION data.")
                        dialogues_per_file[file_path] = 0
                        continue

                # (NUEVO v13) Extraer legislatura
                portada_text = ""
                # (MODIFICADO v14) Buscar PORTADA en session_data
                if isinstance(session_data.get('PORTADA'), dict):
                        portada_text = session_data['PORTADA'].get('#text', "")
                elif isinstance(session_data.get('PORTADA'), str):
                        portada_text = session_data['PORTADA']
                
                legislatura_num = extract_legislatura(portada_text)
                if legislatura_num == 'N/A': # Fallback
                    legislatura_match = re.search(r'legislatura_(\d+)', dirpath, re.IGNORECASE)
                    if legislatura_match: legislatura_num = legislatura_match.group(1)

                session_info = {
                    'id': session_data.get('@NUMERO'),
                    'type': session_data.get('@TIPO'),
                    'start_time': session_data.get('@FECHA_INICIO'),
                    'end_time': session_data.get('@FECHA_TERMINO'),
                    'legislatura': legislatura_num
                }

                # --- Iniciar Búsqueda Estructurada ---
                initial_boletin = 'N/A'
                dialogues_before_structured = len(all_dialogues)
                
                find_interventions_recursive(session_data, session_info, initial_boletin, file_path, all_dialogues)
                
                dialogues_found_structured = len(all_dialogues) - dialogues_before_structured

                # --- (NUEVO v11) Fallback para Texto No Estructurado ---
                unstructured_text = None
                if isinstance(session_data.get('#text'), str):
                    unstructured_text = session_data['#text']

                if dialogues_found_structured < 10 and unstructured_text: # Umbral
                    print(f"    Fallback Regex on {file_name} (found {dialogues_found_structured} structured)...")
                    
                    fallback_turns = segment_text_block(unstructured_text, "Narrador", "Narrador")
                    
                    current_fallback_bulletin = "N/A"
                    
                    for turn in fallback_turns:
                        # (NUEVO v13) Extraer boletín desde la materia detectada en fallback
                        # (FIX v12) Acceder a 'materia_fallback'
                        current_fallback_title = turn.get('materia_fallback', 'Texto Principal No Estructurado')
                        boletin_match = re.search(r'(?:Boletín|Boletines) Nos? ([\d.-]+(?: y [\d.-]+)*)', current_fallback_title, re.IGNORECASE)
                        if boletin_match:
                            current_fallback_bulletin = boletin_match.group(1)
                        # Si no es un título de boletín, mantenemos el N/A
                        elif "ORDEN DEL DÍA" not in current_fallback_title.upper():
                            current_fallback_bulletin = "N/A"
                        
                        all_dialogues.append({
                            'numero_legislatura': session_info.get('legislatura', 'N/A'),
                            'numero_sesion': session_info.get('id'),
                            'fecha_sesion': session_info.get('start_time'),
                            'boletin_proyecto': current_fallback_bulletin,
                            'speaker_name': turn['name'], # <-- CAMBIO: Guardar directo, sin '_raw'
                            'speaker_type': turn['type'],
                            'text': turn['text'],
                            'source_file': file_path
                        })

                # --- Contar y Reportar ---
                processed_files_count += 1
                folder_file_count += 1
                dialogues_in_this_file = len(all_dialogues) - initial_length
                dialogues_per_file[file_path] = dialogues_in_this_file
                # --- (NUEVO v13) Imprimir conteo por archivo ---
                if dialogues_in_this_file > 0:
                    print(f"    Processed {file_name}: Found {dialogues_in_this_file} dialogue turns.")
                else:
                    print(f"    Processed {file_name}: No dialogue turns found.")

            except json.JSONDecodeError:
                print(f"    Error: Could not decode JSON from {file_path}")
                error_files.append(f"{file_path} (JSONDecodeError)")
                dialogues_per_file[file_path] = -1
            except Exception as e:
                tb_str = traceback.format_exc()
                print(f"    An unexpected error occurred processing {file_path}: {e}\n{tb_str[:400]}...")
                error_files.append(f"{file_path} ({type(e).__name__}: {e})")
                dialogues_per_file[file_path] = -1

        print(f"  Finished processing {folder_file_count} files in this folder.")


# --- Post-Procesamiento (ELIMINADO v13): Normalización de Nombres ---
print("\n--- Skipping Post-Processing: Name normalization removed as requested. ---")
df = pd.DataFrame.from_records(all_dialogues)

if df.empty:
     print("\nDataFrame is empty. Skipping Post-Processing.")


# --- Final Output ---
valid_files_count = sum(1 for count in dialogues_per_file.values() if count >= 0)
average_dialogues = 0
if valid_files_count > 0:
    average_dialogues = len(df) / valid_files_count if not df.empty else 0

output_filename = 'segmented_dialogues_all_legislaturas_v14_name_fix.csv'
try:
    if not df.empty:
        # (NUEVO v13) Reordenar y seleccionar columnas finales
        final_columns = [
            'numero_legislatura', 
            'numero_sesion', 
            'fecha_sesion',
            'boletin_proyecto', # Este es el @BOLETIN (ID del proyecto), puede ser N/A
            'speaker_name', # <-- CAMBIO: Esta es ahora la columna "raw" (sin normalizar)
            'speaker_type', 
            'text', 
            'source_file'
        ]
        # Asegurarse de que todas las columnas existan
        for col in final_columns:
            if col not in df.columns:
                df[col] = pd.NA
                
        df = df[final_columns]
        
        # (NUEVO v13) Convertir a tipo string para asegurar compatibilidad
        for col in ['numero_legislatura', 'numero_sesion', 'boletin_proyecto', 'speaker_name', 'speaker_type']:
            if col in df.columns:
                # Rellenar Nulos (NaN, None) con 'N/A' antes de convertir a string
                df[col] = df[col].fillna('N/A').astype(str)

    
        df.to_csv(output_filename, index=False, encoding='utf-8-sig')
        total_folders = len(processed_folders)
        print(f"\nSuccessfully created DataFrame with {len(df)} dialogue turns from {processed_files_count} files ({valid_files_count} successfully processed) across {total_folders} folders.")
        print(f"Average dialogue turns per successfully processed file: {average_dialogues:.2f}")
        print(f"Data saved to {output_filename}")

        if error_files:
            print(f"\nWarning: {len(error_files)} files encountered errors during processing:")
            for i, error_file_info in enumerate(error_files[:30]): print(f"  - {error_file_info}")
            if len(error_files) > 30: print(f"  ... and {len(error_files) - 30} more.")

        if files_with_unexpected_text:
             print(f"\nWarning: Encountered unexpected non-string types for '#text' in {len(files_with_unexpected_text)} files:")
             count = 0
             for file, issues in files_with_unexpected_text.items():
                  print(f"  - {file}: {issues[:3]} {'...' if len(issues) > 3 else ''}")
                  count += 1;
                  if count >= 10: print(f"  ... and {len(files_with_unexpected_text) - 10} more files."); break

        if not df.empty:
            print("\nDataFrame Info:")
            df.info(verbose=True, show_counts=True)
            print("\nDataFrame Head (Muestra Inicial):")
            print(df.head())
            print("\nDataFrame Tail (Muestra Final):")
            print(df.tail())
            
            print("\nVerificación de Boletines (Ejemplos Aleatorios con Boletín):")
            boletin_sample = df[df['boletin_proyecto'] != 'N/A']
            if not boletin_sample.empty:
                print(boletin_sample.sample(min(5, len(boletin_sample)))[['boletin_proyecto', 'speaker_name', 'source_file']])
            else: print("  No se encontraron diálogos con número de boletín.")
                
            print("\nVerificación de Diálogos sin Boletín (N/A):")
            no_boletin_sample = df[df['boletin_proyecto'] == 'N/A']
            if not no_boletin_sample.empty:
                print(no_boletin_sample.sample(min(5, len(no_boletin_sample)))[['boletin_proyecto', 'speaker_name', 'source_file']])
            else: print("  No se encontraron diálogos sin número de boletín.")
                
            print("\nSample Speaker Types Found:")
            print(df['speaker_type'].value_counts().head(20))
            print("\nSample Speaker Names (NUEVO v14 - Corregido):")
            # (NUEVO v14) Mostrar ejemplos de nombres que no sean solo mayúsculas
            fixed_names_sample = df[df['speaker_name'].str.contains(' ', na=False) & ~df['speaker_name'].str.isupper()]
            if not fixed_names_sample.empty:
                print("Ejemplos de nombres combinados (ej. Matías Ramírez):")
                print(fixed_names_sample['speaker_name'].value_counts().head(10))
            else:
                print("No se encontraron nombres combinados (ej. Matías Ramírez) en esta muestra.")
            
            print("\nTop 30 nombres (Raw):")
            print(df['speaker_name'].value_counts().head(30))
            
            print("\nSpeakers with parsing errors (if any):")
            error_name_files = df[df['speaker_name'].isin(['Error Nombre', 'Error Nombre Attr', 'Desconocido'])]
            print(f"  Found {len(error_name_files)} turns with name errors or 'Desconocido'.")
            print(f"  Examples (source files): {error_name_files['source_file'].unique()[:10]}")
        else:
            print("\nWarning: The resulting DataFrame is empty.")

    else:
        print("\nWarning: The resulting DataFrame is empty. No CSV file saved.")
        total_folders = len(processed_folders)
        print(f"Processed {processed_files_count} files ({valid_files_count} successfully processed) across {total_folders} folders, but found 0 dialogue turns.")
        if error_files:
            print(f"\nWarning: {len(error_files)} files encountered errors during processing:")
            for i, error_file_info in enumerate(error_files[:30]): print(f"  - {error_file_info}")


except Exception as e:
    print(f"\nError saving DataFrame to CSV: {e}")
# Out:
# Starting recursive search in 'C:/Users/conjv/Desktop/boletines_json/'...
#
# Processing folder: legislatura_346
#   Found 20 JSON files.
#     Processed boletin_10.json: Found 146 dialogue turns.
#     Processed boletin_11.json: Found 90 dialogue turns.
#     Processed boletin_12.json: Found 150 dialogue turns.
#     Processed boletin_13.json: Found 148 dialogue turns.
#     Processed boletin_15.json: Found 143 dialogue turns.
#     Processed boletin_16.json: Found 69 dialogue turns.
#     Processed boletin_17.json: Found 90 dialogue turns.
#     Processed boletin_18.json: Found 50 dialogue turns.
#     Processed boletin_19.json: Found 142 dialogue turns.
#     Processed boletin_2.json: Found 23 dialogue turns.
#     Processed boletin_20.json: Found 80 dialogue turns.
#     Processed boletin_21.json: Found 138 dialogue turns.
#     Processed boletin_23.json: Found 64 dialogue turns.
#     Processed boletin_24.json: Found 105 dialogue turns.
#     Processed boletin_4.json: Found 200 dialogue turns.
#     Processed boletin_5.json: Found 134 dialogue turns.
#     Processed boletin_6.json: Found 108 dialogue turns.
#     Processed boletin_7.json: Found 114 dialogue turns.
#     Processed boletin_8.json: Found 138 dialogue turns.
#     Processed boletin_9.json: Found 113 dialogue turns.
#   Finished processing 20 files in this folder.
#
# Processing folder: legislatura_347
#   Found 38 JSON files.
#     Processed boletin_1.json: Found 60 dialogue turns.
#     Processed boletin_10.json: Found 89 dialogue turns.
#     Processed boletin_11.json: Found 139 dialogue turns.
#     Processed boletin_12.json: Found 122 dialogue turns.
#     Processed boletin_13.json: Found 115 dialogue turns.
#     Processed boletin_14.json: Found 106 dialogue turns.
#     Processed boletin_15.json: Found 36 dialogue turns.
#     Processed boletin_16.json: Found 93 dialogue turns.
#     Processed boletin_17.json: Found 130 dialogue turns.
#     Processed boletin_18.json: Found 121 dialogue turns.
#     Processed boletin_19.json: Found 65 dialogue turns.
#     Processed boletin_2.json: Found 156 dialogue turns.
#     Processed boletin_20.json: Found 105 dialogue turns.
#     Processed boletin_21.json: Found 133 dialogue turns.
#     Processed boletin_22.json: Found 142 dialogue turns.
#     Processed boletin_23.json: Found 125 dialogue turns.
#     Processed boletin_24.json: Found 101 dialogue turns.
#     Processed boletin_25.json: Found 94 dialogue turns.
#     Processed boletin_27.json: Found 144 dialogue turns.
#     Processed boletin_28.json: Found 174 dialogue turns.
#     Processed boletin_29.json: Found 56 dialogue turns.
#     Processed boletin_3.json: Found 117 dialogue turns.
#     Processed boletin_30.json: Found 96 dialogue turns.
#     Processed boletin_32.json: Found 130 dialogue turns.
#     Processed boletin_34.json: Found 38 dialogue turns.
#     Processed boletin_35.json: No dialogue turns found.
#     Processed boletin_36.json: Found 122 dialogue turns.
#     Processed boletin_37.json: Found 131 dialogue turns.
#     Processed boletin_38.json: Found 92 dialogue turns.
#     Processed boletin_39.json: Found 98 dialogue turns.
#     Processed boletin_4.json: Found 110 dialogue turns.
#     Processed boletin_40.json: Found 49 dialogue turns.
#     Processed boletin_42.json: Found 126 dialogue turns.
#     Processed boletin_5.json: Found 119 dialogue turns.
#     Processed boletin_6.json: Found 166 dialogue turns.
#     Processed boletin_7.json: Found 121 dialogue turns.
#     Processed boletin_8.json: Found 104 dialogue turns.
#     Processed boletin_9.json: Found 146 dialogue turns.
#   Finished processing 38 files in this folder.
#
# Processing folder: legislatura_348
#   Found 43 JSON files.
#     Processed boletin_35.json: Found 122 dialogue turns.
#     Processed boletin_40.json: Found 99 dialogue turns.
#     Processed boletin_41.json: Found 57 dialogue turns.
#     Processed boletin_42.json: Found 99 dialogue turns.
#     Processed boletin_43.json: Found 97 dialogue turns.
#     Processed boletin_44.json: Found 114 dialogue turns.
#     Processed boletin_45.json: Found 145 dialogue turns.
#     Processed boletin_46.json: Found 59 dialogue turns.
#     Fallback Regex on boletin_47.json (found 0 structured)...
#     Processed boletin_47.json: Found 141 dialogue turns.
#     Processed boletin_48.json: Found 92 dialogue turns.
#     Processed boletin_49.json: Found 106 dialogue turns.
#     Processed boletin_50.json: Found 66 dialogue turns.
#     Processed boletin_51.json: Found 147 dialogue turns.
#     Processed boletin_52.json: Found 40 dialogue turns.
#     Processed boletin_53.json: Found 68 dialogue turns.
#     Processed boletin_54.json: Found 64 dialogue turns.
#     Processed boletin_55.json: Found 116 dialogue turns.
#     Processed boletin_56.json: Found 59 dialogue turns.
#     Processed boletin_57.json: Found 87 dialogue turns.
#     Processed boletin_58.json: Found 82 dialogue turns.
#     Processed boletin_59.json: Found 102 dialogue turns.
#     Processed boletin_60.json: Found 108 dialogue turns.
#     Processed boletin_61.json: Found 62 dialogue turns.
#     Processed boletin_62.json: Found 25 dialogue turns.
#     Processed boletin_63.json: Found 86 dialogue turns.
#     Processed boletin_64.json: Found 78 dialogue turns.
#     Processed boletin_65.json: Found 60 dialogue turns.
#     Processed boletin_66.json: Found 127 dialogue turns.
#     Processed boletin_67.json: Found 81 dialogue turns.
#     Processed boletin_69.json: Found 62 dialogue turns.
#     Processed boletin_70.json: Found 159 dialogue turns.
#     Processed boletin_71.json: Found 105 dialogue turns.
#     Processed boletin_72.json: Found 130 dialogue turns.
#     Processed boletin_73.json: Found 98 dialogue turns.
#     Processed boletin_74.json: Found 110 dialogue turns.
#     Processed boletin_75.json: Found 33 dialogue turns.
#     Processed boletin_76.json: Found 97 dialogue turns.
#     Processed boletin_77.json: Found 95 dialogue turns.
#     Processed boletin_78.json: Found 89 dialogue turns.
#     Processed boletin_79.json: Found 42 dialogue turns.
#     Processed boletin_80.json: Found 112 dialogue turns.
#     Processed boletin_81.json: Found 121 dialogue turns.
#     Processed boletin_82.json: Found 118 dialogue turns.
#   Finished processing 43 files in this folder.
#
# Processing folder: legislatura_349
#   Found 40 JSON files.
#     Processed boletin_1.json: Found 139 dialogue turns.
#     Processed boletin_10.json: Found 99 dialogue turns.
#     Processed boletin_11.json: Found 88 dialogue turns.
#     Processed boletin_12.json: Found 97 dialogue turns.
#     Processed boletin_13.json: Found 86 dialogue turns.
#     Processed boletin_14.json: Found 113 dialogue turns.
#     Processed boletin_15.json: Found 80 dialogue turns.
#     Processed boletin_16.json: Found 112 dialogue turns.
#     Processed boletin_17.json: Found 108 dialogue turns.
#     Processed boletin_18.json: Found 107 dialogue turns.
#     Processed boletin_19.json: Found 88 dialogue turns.
#     Processed boletin_2.json: Found 93 dialogue turns.
#     Processed boletin_20.json: Found 72 dialogue turns.
#     Processed boletin_21.json: Found 75 dialogue turns.
#     Processed boletin_22.json: Found 45 dialogue turns.
#     Processed boletin_23.json: Found 92 dialogue turns.
#     Processed boletin_24.json: Found 89 dialogue turns.
#     Processed boletin_25.json: Found 51 dialogue turns.
#     Processed boletin_26.json: Found 79 dialogue turns.
#     Processed boletin_27.json: Found 87 dialogue turns.
#     Processed boletin_28.json: Found 116 dialogue turns.
#     Processed boletin_29.json: Found 103 dialogue turns.
#     Processed boletin_3.json: Found 101 dialogue turns.
#     Processed boletin_30.json: Found 67 dialogue turns.
#     Processed boletin_31.json: Found 105 dialogue turns.
#     Processed boletin_32.json: Found 56 dialogue turns.
#     Processed boletin_33.json: Found 94 dialogue turns.
#     Processed boletin_34.json: Found 28 dialogue turns.
#     Processed boletin_35.json: Found 98 dialogue turns.
#     Processed boletin_36.json: Found 89 dialogue turns.
#     Processed boletin_37.json: Found 68 dialogue turns.
#     Processed boletin_38.json: Found 81 dialogue turns.
#     Processed boletin_39.json: Found 91 dialogue turns.
#     Processed boletin_4.json: Found 92 dialogue turns.
#     Processed boletin_40.json: Found 53 dialogue turns.
#     Processed boletin_5.json: Found 73 dialogue turns.
#     Processed boletin_6.json: Found 103 dialogue turns.
#     Processed boletin_7.json: Found 67 dialogue turns.
#     Processed boletin_8.json: Found 113 dialogue turns.
#     Processed boletin_9.json: Found 121 dialogue turns.
#   Finished processing 40 files in this folder.
#
# Processing folder: legislatura_350
#   Found 90 JSON files.
#     Processed boletin_1.json: Found 103 dialogue turns.
#     Processed boletin_10.json: Found 74 dialogue turns.
#     Processed boletin_11.json: Found 73 dialogue turns.
#     Processed boletin_12.json: Found 93 dialogue turns.
#     Processed boletin_13.json: Found 70 dialogue turns.
#     Processed boletin_14.json: Found 101 dialogue turns.
#     Processed boletin_15.json: Found 97 dialogue turns.
#     Processed boletin_16.json: Found 73 dialogue turns.
#     Processed boletin_17.json: Found 69 dialogue turns.
#     Processed boletin_18.json: Found 80 dialogue turns.
#     Processed boletin_19.json: Found 138 dialogue turns.
#     Processed boletin_2.json: Found 44 dialogue turns.
#     Processed boletin_20.json: Found 135 dialogue turns.
#     Processed boletin_21.json: Found 88 dialogue turns.
#     Processed boletin_22.json: Found 61 dialogue turns.
#     Processed boletin_23.json: Found 108 dialogue turns.
#     Processed boletin_24.json: Found 76 dialogue turns.
#     Processed boletin_25.json: Found 94 dialogue turns.
#     Processed boletin_26.json: Found 95 dialogue turns.
#     Processed boletin_27.json: Found 85 dialogue turns.
#     Processed boletin_28.json: No dialogue turns found.
#     Processed boletin_29.json: Found 40 dialogue turns.
#     Processed boletin_3.json: Found 93 dialogue turns.
#     Processed boletin_30.json: Found 50 dialogue turns.
#     Processed boletin_31.json: Found 80 dialogue turns.
#     Processed boletin_32.json: Found 38 dialogue turns.
#     Processed boletin_33.json: Found 85 dialogue turns.
#     Processed boletin_34.json: Found 111 dialogue turns.
#     Processed boletin_35.json: Found 74 dialogue turns.
#     Processed boletin_36.json: Found 41 dialogue turns.
#     Processed boletin_37.json: Found 124 dialogue turns.
#     Processed boletin_38.json: Found 66 dialogue turns.
#     Processed boletin_39.json: Found 74 dialogue turns.
#     Processed boletin_4.json: Found 119 dialogue turns.
#     Fallback Regex on boletin_40.json (found 4 structured)...
#     Processed boletin_40.json: Found 5 dialogue turns.
#     Processed boletin_41.json: Found 97 dialogue turns.
#     Processed boletin_42.json: Found 62 dialogue turns.
#     Processed boletin_43.json: Found 38 dialogue turns.
#     Processed boletin_44.json: Found 50 dialogue turns.
#     Processed boletin_45.json: Found 72 dialogue turns.
#     Processed boletin_46.json: Found 130 dialogue turns.
#     Processed boletin_47.json: Found 126 dialogue turns.
#     Processed boletin_48.json: Found 45 dialogue turns.
#     Processed boletin_49.json: Found 30 dialogue turns.
#     Processed boletin_5.json: Found 105 dialogue turns.
#     Processed boletin_50.json: Found 74 dialogue turns.
#     Processed boletin_51.json: Found 107 dialogue turns.
#     Processed boletin_52.json: Found 80 dialogue turns.
#     Processed boletin_53.json: Found 95 dialogue turns.
#     Processed boletin_54.json: Found 74 dialogue turns.
#     Processed boletin_55.json: Found 52 dialogue turns.
#     Processed boletin_56.json: Found 76 dialogue turns.
#     Processed boletin_57.json: Found 53 dialogue turns.
#     Processed boletin_58.json: Found 77 dialogue turns.
#     Processed boletin_59.json: Found 69 dialogue turns.
#     Processed boletin_6.json: Found 47 dialogue turns.
#     Processed boletin_60.json: Found 57 dialogue turns.
#     Processed boletin_61.json: Found 105 dialogue turns.
#     Processed boletin_62.json: Found 31 dialogue turns.
#     Processed boletin_63.json: Found 99 dialogue turns.
#     Processed boletin_64.json: Found 59 dialogue turns.
#     Processed boletin_65.json: Found 88 dialogue turns.
#     Processed boletin_66.json: Found 47 dialogue turns.
#     Processed boletin_67.json: Found 56 dialogue turns.
#     Processed boletin_68.json: Found 72 dialogue turns.
#     Processed boletin_69.json: Found 114 dialogue turns.
#     Processed boletin_7.json: Found 65 dialogue turns.
#     Processed boletin_70.json: Found 98 dialogue turns.
#     Processed boletin_71.json: Found 109 dialogue turns.
#     Processed boletin_72.json: Found 66 dialogue turns.
#     Processed boletin_73.json: Found 43 dialogue turns.
#     Processed boletin_74.json: Found 23 dialogue turns.
#     Processed boletin_75.json: Found 69 dialogue turns.
#     Processed boletin_76.json: Found 73 dialogue turns.
#     Processed boletin_77.json: Found 113 dialogue turns.
#     Processed boletin_78.json: Found 72 dialogue turns.
#     Processed boletin_79.json: Found 103 dialogue turns.
#     Processed boletin_8.json: Found 105 dialogue turns.
#     Processed boletin_80.json: Found 99 dialogue turns.
#     Processed boletin_81.json: Found 61 dialogue turns.
#     Processed boletin_82.json: Found 104 dialogue turns.
#     Processed boletin_83.json: Found 71 dialogue turns.
#     Processed boletin_84.json: Found 94 dialogue turns.
#     Processed boletin_85.json: Found 44 dialogue turns.
#     Processed boletin_86.json: Found 84 dialogue turns.
#     Processed boletin_87.json: Found 105 dialogue turns.
#     Processed boletin_88.json: Found 42 dialogue turns.
#     Processed boletin_89.json: Found 118 dialogue turns.
#     Processed boletin_9.json: Found 86 dialogue turns.
#     Processed boletin_90.json: Found 99 dialogue turns.
#   Finished processing 90 files in this folder.
#
# Processing folder: legislatura_351
#   No 'boletin_*.json' files found in this folder.
#
# Processing folder: legislatura_352
#   Found 27 JSON files.
#     Processed boletin_1.json: Found 75 dialogue turns.
#     Processed boletin_12.json: Found 63 dialogue turns.
#     Processed boletin_13.json: Found 69 dialogue turns.
#     Processed boletin_14.json: Found 60 dialogue turns.
#     Processed boletin_15.json: Found 90 dialogue turns.
#     Processed boletin_16.json: Found 41 dialogue turns.
#     Processed boletin_17.json: Found 116 dialogue turns.
#     Processed boletin_18.json: Found 73 dialogue turns.
#     Processed boletin_19.json: Found 106 dialogue turns.
#     Processed boletin_2.json: Found 84 dialogue turns.
#     Processed boletin_20.json: Found 95 dialogue turns.
#     Processed boletin_21.json: Found 65 dialogue turns.
#     Processed boletin_22.json: Found 12 dialogue turns.
#     Processed boletin_23.json: Found 50 dialogue turns.
#     Processed boletin_25.json: Found 25 dialogue turns.
#     Processed boletin_26.json: Found 78 dialogue turns.
#     Processed boletin_27.json: Found 36 dialogue turns.
#     Processed boletin_3.json: Found 84 dialogue turns.
#     Processed boletin_31.json: Found 70 dialogue turns.
#     Processed boletin_36.json: Found 52 dialogue turns.
#     Processed boletin_37.json: Found 67 dialogue turns.
#     Processed boletin_4.json: Found 96 dialogue turns.
#     Processed boletin_40.json: Found 116 dialogue turns.
#     Processed boletin_46.json: Found 99 dialogue turns.
#     Processed boletin_5.json: Found 55 dialogue turns.
#     Processed boletin_6.json: Found 109 dialogue turns.
#     Processed boletin_8.json: Found 70 dialogue turns.
#   Finished processing 27 files in this folder.
#
# Processing folder: legislatura_353
#   Found 72 JSON files.
#     Processed boletin_1.json: Found 83 dialogue turns.
#     Processed boletin_10.json: Found 24 dialogue turns.
#     Processed boletin_11.json: Found 101 dialogue turns.
#     Processed boletin_12.json: Found 76 dialogue turns.
#     Processed boletin_13.json: Found 89 dialogue turns.
#     Processed boletin_14.json: Found 139 dialogue turns.
#     Processed boletin_15.json: Found 73 dialogue turns.
#     Processed boletin_16.json: Found 26 dialogue turns.
#     Processed boletin_17.json: Found 74 dialogue turns.
#     Processed boletin_18.json: Found 76 dialogue turns.
#     Processed boletin_19.json: Found 89 dialogue turns.
#     Processed boletin_2.json: Found 68 dialogue turns.
#     Processed boletin_20.json: Found 74 dialogue turns.
#     Processed boletin_21.json: Found 46 dialogue turns.
#     Processed boletin_22.json: Found 70 dialogue turns.
#     Processed boletin_23.json: Found 95 dialogue turns.
#     Processed boletin_24.json: Found 63 dialogue turns.
#     Processed boletin_25.json: No dialogue turns found.
#     Processed boletin_26.json: Found 86 dialogue turns.
#     Processed boletin_27.json: Found 102 dialogue turns.
#     Processed boletin_28.json: Found 67 dialogue turns.
#     Processed boletin_29.json: Found 102 dialogue turns.
#     Processed boletin_3.json: Found 35 dialogue turns.
#     Processed boletin_30.json: Found 91 dialogue turns.
#     Processed boletin_31.json: Found 71 dialogue turns.
#     Processed boletin_32.json: Found 71 dialogue turns.
#     Processed boletin_33.json: Found 69 dialogue turns.
#     Processed boletin_34.json: Found 122 dialogue turns.
#     Processed boletin_35.json: Found 88 dialogue turns.
#     Processed boletin_36.json: Found 39 dialogue turns.
#     Processed boletin_37.json: Found 44 dialogue turns.
#     Processed boletin_38.json: Found 50 dialogue turns.
#     Processed boletin_39.json: Found 80 dialogue turns.
#     Processed boletin_4.json: Found 42 dialogue turns.
#     Processed boletin_40.json: Found 111 dialogue turns.
#     Processed boletin_41.json: Found 101 dialogue turns.
#     Fallback Regex on boletin_42.json (found 0 structured)...
#     Processed boletin_42.json: Found 1 dialogue turns.
#     Processed boletin_43.json: Found 54 dialogue turns.
#     Processed boletin_45.json: Found 74 dialogue turns.
#     Processed boletin_46.json: Found 54 dialogue turns.
#     Processed boletin_47.json: Found 76 dialogue turns.
#     Processed boletin_49.json: Found 105 dialogue turns.
#     Processed boletin_5.json: Found 92 dialogue turns.
#     Processed boletin_50.json: Found 76 dialogue turns.
#     Processed boletin_51.json: Found 72 dialogue turns.
#     Processed boletin_52.json: Found 81 dialogue turns.
#     Processed boletin_53.json: Found 77 dialogue turns.
#     Processed boletin_54.json: Found 51 dialogue turns.
#     Processed boletin_55.json: Found 156 dialogue turns.
#     Processed boletin_56.json: Found 161 dialogue turns.
#     Processed boletin_57.json: Found 52 dialogue turns.
#     Processed boletin_59.json: Found 91 dialogue turns.
#     Processed boletin_6.json: Found 110 dialogue turns.
#     Processed boletin_60.json: Found 26 dialogue turns.
#     Processed boletin_61.json: Found 53 dialogue turns.
#     Processed boletin_62.json: Found 81 dialogue turns.
#     Processed boletin_63.json: Found 35 dialogue turns.
#     Processed boletin_64.json: Found 63 dialogue turns.
#     Processed boletin_65.json: Found 47 dialogue turns.
#     Processed boletin_66.json: Found 54 dialogue turns.
#     Processed boletin_67.json: Found 59 dialogue turns.
#     Processed boletin_68.json: Found 80 dialogue turns.
#     Processed boletin_69.json: Found 27 dialogue turns.
#     Processed boletin_7.json: Found 116 dialogue turns.
#     Processed boletin_70.json: Found 111 dialogue turns.
#     Processed boletin_71.json: Found 73 dialogue turns.
#     Processed boletin_72.json: Found 29 dialogue turns.
#     Processed boletin_73.json: Found 41 dialogue turns.
#     Processed boletin_74.json: Found 60 dialogue turns.
#     Processed boletin_75.json: Found 74 dialogue turns.
#     Processed boletin_8.json: Found 67 dialogue turns.
#     Processed boletin_9.json: Found 45 dialogue turns.
#   Finished processing 72 files in this folder.
#
# Processing folder: legislatura_354
#   Found 73 JSON files.
#     Processed boletin_0.json: Found 20 dialogue turns.
#     Processed boletin_1.json: Found 5 dialogue turns.
#     Processed boletin_10.json: Found 111 dialogue turns.
#     Processed boletin_11.json: Found 127 dialogue turns.
#     Processed boletin_110.json: Found 76 dialogue turns.
#     Processed boletin_111.json: Found 109 dialogue turns.
#     Processed boletin_112.json: Found 58 dialogue turns.
#     Processed boletin_113.json: Found 75 dialogue turns.
#     Processed boletin_114.json: Found 41 dialogue turns.
#     Processed boletin_115.json: Found 77 dialogue turns.
#     Processed boletin_116.json: Found 80 dialogue turns.
#     Processed boletin_117.json: Found 108 dialogue turns.
#     Processed boletin_118.json: Found 86 dialogue turns.
#     Processed boletin_119.json: Found 83 dialogue turns.
#     Processed boletin_12.json: Found 109 dialogue turns.
#     Processed boletin_120.json: Found 101 dialogue turns.
#     Processed boletin_121.json: Found 33 dialogue turns.
#     Processed boletin_122.json: Found 115 dialogue turns.
#     Processed boletin_123.json: Found 137 dialogue turns.
#     Processed boletin_124.json: Found 49 dialogue turns.
#     Processed boletin_125.json: Found 89 dialogue turns.
#     Processed boletin_126.json: Found 72 dialogue turns.
#     Processed boletin_127.json: Found 28 dialogue turns.
#     Processed boletin_128.json: Found 29 dialogue turns.
#     Processed boletin_13.json: Found 52 dialogue turns.
#     Processed boletin_14.json: Found 113 dialogue turns.
#     Processed boletin_15.json: Found 85 dialogue turns.
#     Processed boletin_16.json: Found 142 dialogue turns.
#     Processed boletin_17.json: Found 103 dialogue turns.
#     Processed boletin_18.json: Found 43 dialogue turns.
#     Processed boletin_19.json: Found 116 dialogue turns.
#     Processed boletin_2.json: Found 35 dialogue turns.
#     Processed boletin_20.json: Found 16 dialogue turns.
#     Processed boletin_21.json: Found 75 dialogue turns.
#     Processed boletin_22.json: Found 40 dialogue turns.
#     Processed boletin_23.json: Found 105 dialogue turns.
#     Processed boletin_24.json: Found 32 dialogue turns.
#     Processed boletin_25.json: Found 127 dialogue turns.
#     Processed boletin_26.json: Found 84 dialogue turns.
#     Processed boletin_27.json: Found 71 dialogue turns.
#     Processed boletin_28.json: Found 48 dialogue turns.
#     Processed boletin_29.json: Found 143 dialogue turns.
#     Processed boletin_3.json: Found 81 dialogue turns.
#     Processed boletin_30.json: Found 92 dialogue turns.
#     Processed boletin_31.json: Found 92 dialogue turns.
#     Processed boletin_32.json: Found 145 dialogue turns.
#     Processed boletin_33.json: Found 31 dialogue turns.
#     Processed boletin_34.json: Found 90 dialogue turns.
#     Processed boletin_35.json: Found 115 dialogue turns.
#     Processed boletin_36.json: Found 100 dialogue turns.
#     Processed boletin_37.json: Found 250 dialogue turns.
#     Processed boletin_38.json: Found 106 dialogue turns.
#     Processed boletin_39.json: Found 113 dialogue turns.
#     Fallback Regex on boletin_4.json (found 0 structured)...
#     Processed boletin_4.json: Found 118 dialogue turns.
#     Processed boletin_40.json: Found 103 dialogue turns.
#     Processed boletin_41.json: Found 44 dialogue turns.
#     Processed boletin_42.json: Found 91 dialogue turns.
#     Processed boletin_43.json: Found 26 dialogue turns.
#     Processed boletin_44.json: Found 66 dialogue turns.
#     Processed boletin_45.json: Found 56 dialogue turns.
#     Processed boletin_46.json: Found 99 dialogue turns.
#     Processed boletin_47.json: Found 139 dialogue turns.
#     Processed boletin_48.json: Found 111 dialogue turns.
#     Processed boletin_49.json: Found 111 dialogue turns.
#     Processed boletin_5.json: Found 101 dialogue turns.
#     Processed boletin_50.json: Found 111 dialogue turns.
#     Processed boletin_51.json: Found 48 dialogue turns.
#     Processed boletin_52.json: Found 114 dialogue turns.
#     Processed boletin_53.json: Found 114 dialogue turns.
#     Processed boletin_6.json: Found 37 dialogue turns.
#     Processed boletin_7.json: Found 75 dialogue turns.
#     Processed boletin_8.json: Found 103 dialogue turns.
#     Processed boletin_9.json: Found 56 dialogue turns.
#   Finished processing 73 files in this folder.
#
# Processing folder: legislatura_355
#   Found 138 JSON files.
#     Processed boletin_1.json: Found 100 dialogue turns.
#     Processed boletin_10.json: Found 42 dialogue turns.
#     Processed boletin_100.json: Found 85 dialogue turns.
#     Processed boletin_101.json: Found 1 dialogue turns.
#     Processed boletin_102.json: Found 169 dialogue turns.
#     Processed boletin_103.json: Found 87 dialogue turns.
#     Processed boletin_104.json: Found 76 dialogue turns.
#     Processed boletin_105.json: Found 508 dialogue turns.
#     Processed boletin_106.json: Found 92 dialogue turns.
#     Processed boletin_107.json: Found 25 dialogue turns.
#     Processed boletin_108.json: Found 140 dialogue turns.
#     Processed boletin_109.json: Found 23 dialogue turns.
#     Processed boletin_11.json: Found 42 dialogue turns.
#     Processed boletin_110.json: Found 140 dialogue turns.
#     Processed boletin_111.json: Found 105 dialogue turns.
#     Processed boletin_112.json: Found 80 dialogue turns.
#     Processed boletin_113.json: Found 107 dialogue turns.
#     Processed boletin_114.json: Found 120 dialogue turns.
#     Processed boletin_115.json: Found 114 dialogue turns.
#     Processed boletin_116.json: Found 119 dialogue turns.
#     Processed boletin_117.json: Found 113 dialogue turns.
#     Processed boletin_118.json: Found 70 dialogue turns.
#     Processed boletin_119.json: Found 85 dialogue turns.
#     Processed boletin_12.json: Found 83 dialogue turns.
#     Processed boletin_120.json: Found 51 dialogue turns.
#     Processed boletin_121.json: Found 80 dialogue turns.
#     Processed boletin_122.json: Found 115 dialogue turns.
#     Processed boletin_123.json: Found 104 dialogue turns.
#     Processed boletin_124.json: Found 43 dialogue turns.
#     Processed boletin_125.json: Found 9 dialogue turns.
#     Processed boletin_126.json: Found 72 dialogue turns.
#     Processed boletin_127.json: Found 34 dialogue turns.
#     Processed boletin_128.json: Found 177 dialogue turns.
#     Processed boletin_129.json: Found 115 dialogue turns.
#     Processed boletin_130.json: Found 97 dialogue turns.
#     Processed boletin_131.json: Found 77 dialogue turns.
#     Processed boletin_132.json: Found 114 dialogue turns.
#     Processed boletin_133.json: Found 40 dialogue turns.
#     Processed boletin_134.json: Found 39 dialogue turns.
#     Processed boletin_135.json: Found 57 dialogue turns.
#     Processed boletin_136.json: Found 76 dialogue turns.
#     Processed boletin_137.json: Found 100 dialogue turns.
#     Processed boletin_138.json: Found 88 dialogue turns.
#     Processed boletin_139.json: Found 94 dialogue turns.
#     Processed boletin_14.json: Found 46 dialogue turns.
#     Processed boletin_15.json: Found 112 dialogue turns.
#     Processed boletin_16.json: Found 94 dialogue turns.
#     Processed boletin_17.json: Found 122 dialogue turns.
#     Processed boletin_18.json: Found 99 dialogue turns.
#     Processed boletin_19.json: Found 105 dialogue turns.
#     Processed boletin_2.json: Found 88 dialogue turns.
#     Processed boletin_20.json: Found 68 dialogue turns.
#     Processed boletin_21.json: Found 126 dialogue turns.
#     Processed boletin_22.json: Found 107 dialogue turns.
#     Processed boletin_23.json: Found 134 dialogue turns.
#     Processed boletin_24.json: Found 58 dialogue turns.
#     Processed boletin_25.json: Found 81 dialogue turns.
#     Processed boletin_26.json: Found 178 dialogue turns.
#     Processed boletin_27.json: Found 68 dialogue turns.
#     Processed boletin_28.json: Found 128 dialogue turns.
#     Processed boletin_29.json: Found 138 dialogue turns.
#     Processed boletin_3.json: Found 78 dialogue turns.
#     Processed boletin_30.json: Found 125 dialogue turns.
#     Processed boletin_31.json: Found 98 dialogue turns.
#     Processed boletin_32.json: Found 46 dialogue turns.
#     Processed boletin_33.json: Found 80 dialogue turns.
#     Processed boletin_34.json: Found 74 dialogue turns.
#     Processed boletin_35.json: Found 98 dialogue turns.
#     Processed boletin_36.json: Found 46 dialogue turns.
#     Processed boletin_37.json: Found 136 dialogue turns.
#     Processed boletin_38.json: Found 125 dialogue turns.
#     Processed boletin_39.json: Found 42 dialogue turns.
#     Processed boletin_4.json: Found 100 dialogue turns.
#     Processed boletin_40.json: Found 35 dialogue turns.
#     Processed boletin_41.json: Found 60 dialogue turns.
#     Processed boletin_42.json: Found 144 dialogue turns.
#     Processed boletin_43.json: Found 30 dialogue turns.
#     Processed boletin_44.json: Found 82 dialogue turns.
#     Processed boletin_45.json: Found 104 dialogue turns.
#     Processed boletin_46.json: Found 70 dialogue turns.
#     Processed boletin_47.json: Found 109 dialogue turns.
#     Processed boletin_48.json: Found 92 dialogue turns.
#     Processed boletin_49.json: Found 21 dialogue turns.
#     Processed boletin_5.json: Found 67 dialogue turns.
#     Processed boletin_50.json: Found 47 dialogue turns.
#     Processed boletin_51.json: Found 76 dialogue turns.
#     Processed boletin_52.json: Found 92 dialogue turns.
#     Processed boletin_53.json: Found 20 dialogue turns.
#     Processed boletin_54.json: Found 120 dialogue turns.
#     Processed boletin_55.json: Found 91 dialogue turns.
#     Processed boletin_56.json: Found 88 dialogue turns.
#     Processed boletin_57.json: Found 53 dialogue turns.
#     Processed boletin_58.json: Found 112 dialogue turns.
#     Processed boletin_59.json: Found 94 dialogue turns.
#     Processed boletin_6.json: Found 101 dialogue turns.
#     Processed boletin_60.json: Found 122 dialogue turns.
#     Processed boletin_61.json: Found 115 dialogue turns.
#     Processed boletin_62.json: Found 112 dialogue turns.
#     Processed boletin_63.json: Found 110 dialogue turns.
#     Processed boletin_64.json: Found 105 dialogue turns.
#     Processed boletin_65.json: Found 120 dialogue turns.
#     Processed boletin_66.json: Found 182 dialogue turns.
#     Processed boletin_67.json: Found 103 dialogue turns.
#     Processed boletin_68.json: Found 34 dialogue turns.
#     Processed boletin_69.json: Found 65 dialogue turns.
#     Processed boletin_7.json: Found 109 dialogue turns.
#     Processed boletin_70.json: Found 74 dialogue turns.
#     Processed boletin_71.json: Found 95 dialogue turns.
#     Processed boletin_72.json: Found 98 dialogue turns.
#     Processed boletin_73.json: Found 97 dialogue turns.
#     Processed boletin_74.json: Found 52 dialogue turns.
#     Processed boletin_75.json: Found 91 dialogue turns.
#     Processed boletin_76.json: Found 69 dialogue turns.
#     Processed boletin_77.json: Found 101 dialogue turns.
#     Processed boletin_78.json: Found 118 dialogue turns.
#     Processed boletin_79.json: Found 65 dialogue turns.
#     Processed boletin_8.json: Found 111 dialogue turns.
#     Processed boletin_80.json: Found 46 dialogue turns.
#     Processed boletin_81.json: Found 124 dialogue turns.
#     Processed boletin_82.json: Found 60 dialogue turns.
#     Processed boletin_83.json: Found 98 dialogue turns.
#     Processed boletin_84.json: Found 110 dialogue turns.
#     Processed boletin_85.json: Found 64 dialogue turns.
#     Processed boletin_86.json: Found 37 dialogue turns.
#     Processed boletin_87.json: Found 96 dialogue turns.
#     Processed boletin_88.json: Found 134 dialogue turns.
#     Processed boletin_89.json: Found 90 dialogue turns.
#     Processed boletin_9.json: Found 128 dialogue turns.
#     Processed boletin_90.json: Found 113 dialogue turns.
#     Processed boletin_91.json: Found 101 dialogue turns.
#     Processed boletin_92.json: Found 94 dialogue turns.
#     Processed boletin_93.json: Found 105 dialogue turns.
#     Processed boletin_94.json: Found 53 dialogue turns.
#     Processed boletin_95.json: Found 98 dialogue turns.
#     Processed boletin_96.json: Found 121 dialogue turns.
#     Processed boletin_97.json: Found 139 dialogue turns.
#     Processed boletin_98.json: Found 68 dialogue turns.
#     Processed boletin_99.json: Found 110 dialogue turns.
#   Finished processing 138 files in this folder.
#
# Processing folder: legislatura_356
#   Found 51 JSON files.
#     Processed boletin_1.json: Found 112 dialogue turns.
#     Processed boletin_10.json: Found 111 dialogue turns.
#     Processed boletin_11.json: Found 111 dialogue turns.
#     Processed boletin_12.json: Found 29 dialogue turns.
#     Processed boletin_14.json: Found 76 dialogue turns.
#     Processed boletin_15.json: Found 45 dialogue turns.
#     Processed boletin_16.json: Found 156 dialogue turns.
#     Processed boletin_17.json: Found 95 dialogue turns.
#     Processed boletin_18.json: Found 126 dialogue turns.
#     Processed boletin_19.json: Found 132 dialogue turns.
#     Processed boletin_2.json: Found 98 dialogue turns.
#     Processed boletin_20.json: Found 114 dialogue turns.
#     Processed boletin_21.json: Found 95 dialogue turns.
#     Processed boletin_24.json: Found 96 dialogue turns.
#     Processed boletin_25.json: Found 81 dialogue turns.
#     Processed boletin_26.json: Found 104 dialogue turns.
#     Processed boletin_27.json: Found 110 dialogue turns.
#     Processed boletin_28.json: Found 70 dialogue turns.
#     Processed boletin_29.json: Found 33 dialogue turns.
#     Processed boletin_3.json: Found 109 dialogue turns.
#     Processed boletin_30.json: Found 62 dialogue turns.
#     Processed boletin_31.json: Found 107 dialogue turns.
#     Processed boletin_32.json: No dialogue turns found.
#     Processed boletin_33.json: Found 96 dialogue turns.
#     Processed boletin_34.json: Found 110 dialogue turns.
#     Processed boletin_37.json: Found 18 dialogue turns.
#     Processed boletin_38.json: Found 90 dialogue turns.
#     Processed boletin_39.json: Found 84 dialogue turns.
#     Processed boletin_4.json: Found 97 dialogue turns.
#     Processed boletin_40.json: Found 68 dialogue turns.
#     Processed boletin_41.json: Found 27 dialogue turns.
#     Processed boletin_42.json: Found 50 dialogue turns.
#     Processed boletin_43.json: Found 124 dialogue turns.
#     Processed boletin_44.json: Found 262 dialogue turns.
#     Processed boletin_45.json: Found 139 dialogue turns.
#     Processed boletin_46.json: Found 95 dialogue turns.
#     Processed boletin_48.json: Found 85 dialogue turns.
#     Processed boletin_49.json: Found 73 dialogue turns.
#     Processed boletin_5.json: Found 40 dialogue turns.
#     Processed boletin_50.json: Found 31 dialogue turns.
#     Processed boletin_51.json: Found 70 dialogue turns.
#     Processed boletin_52.json: Found 107 dialogue turns.
#     Processed boletin_53.json: Found 141 dialogue turns.
#     Processed boletin_54.json: Found 128 dialogue turns.
#     Processed boletin_55.json: Found 92 dialogue turns.
#     Processed boletin_56.json: Found 77 dialogue turns.
#     Processed boletin_57.json: Found 91 dialogue turns.
#     Fallback Regex on boletin_59.json (found 7 structured)...
#     Processed boletin_59.json: Found 8 dialogue turns.
#     Processed boletin_6.json: Found 41 dialogue turns.
#     Processed boletin_7.json: Found 87 dialogue turns.
#     Processed boletin_8.json: Found 7 dialogue turns.
#   Finished processing 51 files in this folder.
#
# Processing folder: legislatura_357
#   Found 123 JSON files.
#     Processed boletin_1.json: Found 94 dialogue turns.
#     Processed boletin_10.json: Found 42 dialogue turns.
#     Processed boletin_100.json: Found 99 dialogue turns.
#     Processed boletin_101.json: Found 137 dialogue turns.
#     Processed boletin_102.json: Found 53 dialogue turns.
#     Processed boletin_103.json: Found 172 dialogue turns.
#     Processed boletin_104.json: Found 95 dialogue turns.
#     Processed boletin_106.json: Found 61 dialogue turns.
#     Processed boletin_107.json: Found 57 dialogue turns.
#     Processed boletin_108.json: Found 79 dialogue turns.
#     Processed boletin_109.json: Found 30 dialogue turns.
#     Processed boletin_11.json: Found 101 dialogue turns.
#     Processed boletin_110.json: Found 45 dialogue turns.
#     Fallback Regex on boletin_111.json (found 0 structured)...
#     Processed boletin_111.json: Found 1 dialogue turns.
#     Processed boletin_112.json: Found 74 dialogue turns.
#     Processed boletin_113.json: Found 47 dialogue turns.
#     Processed boletin_114.json: Found 67 dialogue turns.
#     Processed boletin_115.json: Found 59 dialogue turns.
#     Processed boletin_116.json: Found 88 dialogue turns.
#     Processed boletin_117.json: Found 84 dialogue turns.
#     Processed boletin_118.json: Found 51 dialogue turns.
#     Processed boletin_119.json: Found 49 dialogue turns.
#     Processed boletin_12.json: Found 58 dialogue turns.
#     Processed boletin_120.json: Found 60 dialogue turns.
#     Processed boletin_121.json: Found 99 dialogue turns.
#     Processed boletin_122.json: Found 40 dialogue turns.
#     Processed boletin_123.json: Found 49 dialogue turns.
#     Processed boletin_124.json: Found 27 dialogue turns.
#     Processed boletin_125.json: Found 67 dialogue turns.
#     Processed boletin_13.json: Found 89 dialogue turns.
#     Processed boletin_14.json: Found 87 dialogue turns.
#     Processed boletin_15.json: Found 52 dialogue turns.
#     Processed boletin_16.json: Found 97 dialogue turns.
#     Processed boletin_17.json: Found 39 dialogue turns.
#     Processed boletin_18.json: Found 60 dialogue turns.
#     Processed boletin_19.json: Found 86 dialogue turns.
#     Processed boletin_2.json: Found 79 dialogue turns.
#     Processed boletin_20.json: Found 117 dialogue turns.
#     Processed boletin_21.json: Found 89 dialogue turns.
#     Processed boletin_23.json: Found 95 dialogue turns.
#     Processed boletin_24.json: Found 45 dialogue turns.
#     Processed boletin_25.json: Found 99 dialogue turns.
#     Processed boletin_26.json: Found 79 dialogue turns.
#     Processed boletin_27.json: Found 69 dialogue turns.
#     Processed boletin_28.json: Found 83 dialogue turns.
#     Processed boletin_29.json: Found 109 dialogue turns.
#     Processed boletin_3.json: Found 113 dialogue turns.
#     Processed boletin_30.json: Found 146 dialogue turns.
#     Processed boletin_31.json: Found 87 dialogue turns.
#     Processed boletin_32.json: Found 76 dialogue turns.
#     Processed boletin_33.json: Found 52 dialogue turns.
#     Processed boletin_34.json: Found 102 dialogue turns.
#     Processed boletin_35.json: Found 85 dialogue turns.
#     Processed boletin_36.json: Found 119 dialogue turns.
#     Processed boletin_37.json: Found 90 dialogue turns.
#     Processed boletin_38.json: Found 105 dialogue turns.
#     Processed boletin_39.json: Found 48 dialogue turns.
#     Processed boletin_4.json: Found 52 dialogue turns.
#     Processed boletin_40.json: Found 93 dialogue turns.
#     Processed boletin_41.json: Found 83 dialogue turns.
#     Processed boletin_42.json: Found 60 dialogue turns.
#     Processed boletin_43.json: Found 105 dialogue turns.
#     Processed boletin_44.json: Found 113 dialogue turns.
#     Processed boletin_45.json: Found 102 dialogue turns.
#     Processed boletin_46.json: Found 62 dialogue turns.
#     Processed boletin_47.json: Found 113 dialogue turns.
#     Processed boletin_48.json: Found 83 dialogue turns.
#     Processed boletin_49.json: Found 12 dialogue turns.
#     Processed boletin_5.json: Found 91 dialogue turns.
#     Processed boletin_50.json: Found 90 dialogue turns.
#     Processed boletin_51.json: Found 41 dialogue turns.
#     Processed boletin_52.json: Found 92 dialogue turns.
#     Processed boletin_53.json: Found 48 dialogue turns.
#     Processed boletin_54.json: Found 113 dialogue turns.
#     Processed boletin_55.json: Found 81 dialogue turns.
#     Processed boletin_56.json: Found 133 dialogue turns.
#     Processed boletin_57.json: Found 94 dialogue turns.
#     Processed boletin_58.json: Found 134 dialogue turns.
#     Processed boletin_59.json: Found 111 dialogue turns.
#     Processed boletin_6.json: Found 95 dialogue turns.
#     Processed boletin_60.json: Found 92 dialogue turns.
#     Processed boletin_61.json: Found 86 dialogue turns.
#     Processed boletin_62.json: Found 51 dialogue turns.
#     Processed boletin_63.json: Found 88 dialogue turns.
#     Processed boletin_64.json: Found 37 dialogue turns.
#     Processed boletin_65.json: Found 55 dialogue turns.
#     Processed boletin_66.json: Found 70 dialogue turns.
#     Processed boletin_67.json: Found 70 dialogue turns.
#     Processed boletin_68.json: Found 125 dialogue turns.
#     Processed boletin_69.json: Found 80 dialogue turns.
#     Processed boletin_7.json: Found 170 dialogue turns.
#     Processed boletin_70.json: Found 41 dialogue turns.
#     Processed boletin_71.json: Found 52 dialogue turns.
#     Processed boletin_72.json: Found 82 dialogue turns.
#     Processed boletin_73.json: Found 106 dialogue turns.
#     Processed boletin_74.json: Found 106 dialogue turns.
#     Processed boletin_75.json: Found 51 dialogue turns.
#     Processed boletin_76.json: Found 73 dialogue turns.
#     Fallback Regex on boletin_77.json (found 0 structured)...
#     Processed boletin_77.json: Found 152 dialogue turns.
#     Processed boletin_78.json: Found 79 dialogue turns.
#     Processed boletin_79.json: Found 61 dialogue turns.
#     Processed boletin_8.json: Found 83 dialogue turns.
#     Processed boletin_80.json: Found 27 dialogue turns.
#     Processed boletin_81.json: Found 74 dialogue turns.
#     Processed boletin_82.json: Found 96 dialogue turns.
#     Processed boletin_83.json: Found 84 dialogue turns.
#     Processed boletin_84.json: Found 74 dialogue turns.
#     Processed boletin_85.json: Found 70 dialogue turns.
#     Processed boletin_86.json: Found 125 dialogue turns.
#     Processed boletin_87.json: Found 93 dialogue turns.
#     Processed boletin_88.json: Found 118 dialogue turns.
#     Processed boletin_89.json: Found 38 dialogue turns.
#     Processed boletin_9.json: Found 95 dialogue turns.
#     Processed boletin_90.json: Found 91 dialogue turns.
#     Processed boletin_91.json: Found 72 dialogue turns.
#     Processed boletin_92.json: Found 85 dialogue turns.
#     Processed boletin_93.json: Found 34 dialogue turns.
#     Processed boletin_94.json: Found 91 dialogue turns.
#     Processed boletin_95.json: Found 42 dialogue turns.
#     Processed boletin_96.json: Found 90 dialogue turns.
#     Processed boletin_97.json: Found 41 dialogue turns.
#     Processed boletin_98.json: Found 109 dialogue turns.
#     Processed boletin_99.json: Found 58 dialogue turns.
#   Finished processing 123 files in this folder.
#
# Processing folder: legislatura_358
#   Found 135 JSON files.
#     Fallback Regex on boletin_0.json (found 6 structured)...
#     Processed boletin_0.json: Found 8 dialogue turns.
#     Processed boletin_1.json: Found 61 dialogue turns.
#     Processed boletin_10.json: Found 88 dialogue turns.
#     Processed boletin_100.json: Found 616 dialogue turns.
#     Processed boletin_101.json: Found 115 dialogue turns.
#     Processed boletin_102.json: Found 149 dialogue turns.
#     Processed boletin_103.json: Found 243 dialogue turns.
#     Processed boletin_104.json: Found 118 dialogue turns.
#     Processed boletin_105.json: Found 144 dialogue turns.
#     Processed boletin_106.json: Found 37 dialogue turns.
#     Processed boletin_107.json: Found 82 dialogue turns.
#     Processed boletin_108.json: Found 186 dialogue turns.
#     Processed boletin_109.json: Found 70 dialogue turns.
#     Processed boletin_11.json: Found 120 dialogue turns.
#     Processed boletin_110.json: Found 20 dialogue turns.
#     Processed boletin_111.json: Found 54 dialogue turns.
#     Processed boletin_112.json: Found 31 dialogue turns.
#     Processed boletin_113.json: Found 83 dialogue turns.
#     Processed boletin_114.json: Found 107 dialogue turns.
#     Processed boletin_115.json: Found 46 dialogue turns.
#     Processed boletin_116.json: Found 53 dialogue turns.
#     Processed boletin_117.json: Found 91 dialogue turns.
#     Processed boletin_118.json: Found 146 dialogue turns.
#     Processed boletin_119.json: Found 76 dialogue turns.
#     Processed boletin_12.json: Found 85 dialogue turns.
#     Processed boletin_120.json: Found 163 dialogue turns.
#     Processed boletin_121.json: Found 136 dialogue turns.
#     Processed boletin_122.json: Found 60 dialogue turns.
#     Processed boletin_123.json: Found 110 dialogue turns.
#     Processed boletin_124.json: Found 121 dialogue turns.
#     Processed boletin_125.json: Found 95 dialogue turns.
#     Processed boletin_126.json: Found 85 dialogue turns.
#     Processed boletin_127.json: Found 115 dialogue turns.
#     Processed boletin_128.json: Found 64 dialogue turns.
#     Processed boletin_129.json: Found 39 dialogue turns.
#     Processed boletin_13.json: Found 101 dialogue turns.
#     Processed boletin_130.json: Found 122 dialogue turns.
#     Processed boletin_131.json: Found 109 dialogue turns.
#     Processed boletin_132.json: Found 111 dialogue turns.
#     Processed boletin_133.json: Found 94 dialogue turns.
#     Processed boletin_134.json: Found 131 dialogue turns.
#     Processed boletin_135.json: Found 32 dialogue turns.
#     Processed boletin_136.json: Found 49 dialogue turns.
#     Processed boletin_137.json: Found 10 dialogue turns.
#     Processed boletin_14.json: Found 84 dialogue turns.
#     Processed boletin_15.json: Found 93 dialogue turns.
#     Processed boletin_16.json: Found 158 dialogue turns.
#     Processed boletin_17.json: Found 59 dialogue turns.
#     Processed boletin_18.json: Found 72 dialogue turns.
#     Processed boletin_19.json: Found 83 dialogue turns.
#     Processed boletin_2.json: Found 38 dialogue turns.
#     Processed boletin_20.json: Found 138 dialogue turns.
#     Processed boletin_21.json: Found 50 dialogue turns.
#     Processed boletin_22.json: Found 79 dialogue turns.
#     Processed boletin_23.json: Found 121 dialogue turns.
#     Processed boletin_24.json: Found 36 dialogue turns.
#     Processed boletin_25.json: Found 68 dialogue turns.
#     Processed boletin_26.json: Found 62 dialogue turns.
#     Processed boletin_27.json: Found 115 dialogue turns.
#     Processed boletin_28.json: Found 88 dialogue turns.
#     Processed boletin_29.json: Found 86 dialogue turns.
#     Processed boletin_3.json: Found 90 dialogue turns.
#     Processed boletin_30.json: Found 115 dialogue turns.
#     Processed boletin_31.json: Found 96 dialogue turns.
#     Processed boletin_32.json: Found 61 dialogue turns.
#     Processed boletin_33.json: Found 98 dialogue turns.
#     Processed boletin_34.json: Found 146 dialogue turns.
#     Processed boletin_35.json: Found 71 dialogue turns.
#     Processed boletin_36.json: Found 35 dialogue turns.
#     Processed boletin_37.json: Found 128 dialogue turns.
#     Processed boletin_38.json: Found 114 dialogue turns.
#     Processed boletin_39.json: Found 109 dialogue turns.
#     Processed boletin_4.json: Found 118 dialogue turns.
#     Processed boletin_40.json: Found 86 dialogue turns.
#     Processed boletin_41.json: Found 122 dialogue turns.
#     Processed boletin_42.json: Found 85 dialogue turns.
#     Processed boletin_43.json: Found 41 dialogue turns.
#     Processed boletin_44.json: Found 92 dialogue turns.
#     Processed boletin_45.json: Found 51 dialogue turns.
#     Processed boletin_46.json: Found 106 dialogue turns.
#     Processed boletin_47.json: Found 130 dialogue turns.
#     Processed boletin_48.json: Found 120 dialogue turns.
#     Processed boletin_49.json: Found 95 dialogue turns.
#     Processed boletin_5.json: Found 114 dialogue turns.
#     Processed boletin_50.json: Found 65 dialogue turns.
#     Processed boletin_51.json: Found 116 dialogue turns.
#     Processed boletin_52.json: Found 110 dialogue turns.
#     Processed boletin_53.json: Found 42 dialogue turns.
#     Processed boletin_54.json: Found 143 dialogue turns.
#     Processed boletin_55.json: Found 141 dialogue turns.
#     Processed boletin_56.json: Found 114 dialogue turns.
#     Processed boletin_57.json: Found 85 dialogue turns.
#     Processed boletin_58.json: Found 80 dialogue turns.
#     Processed boletin_59.json: Found 121 dialogue turns.
#     Processed boletin_6.json: Found 84 dialogue turns.
#     Processed boletin_60.json: Found 100 dialogue turns.
#     Processed boletin_62.json: Found 100 dialogue turns.
#     Processed boletin_63.json: Found 156 dialogue turns.
#     Processed boletin_65.json: Found 106 dialogue turns.
#     Processed boletin_66.json: Found 37 dialogue turns.
#     Processed boletin_67.json: Found 107 dialogue turns.
#     Processed boletin_68.json: Found 142 dialogue turns.
#     Processed boletin_69.json: Found 76 dialogue turns.
# ...
#     Processed boletin_96.json: Found 97 dialogue turns.
#     Fallback Regex on boletin_97.json (found 0 structured)...
#     Processed boletin_97.json: Found 181 dialogue turns.
#     Fallback Regex on boletin_98.json (found 0 structured)...
#     Processed boletin_98.json: Found 136 dialogue turns.
#     Fallback Regex on boletin_99.json (found 0 structured)...
#     Processed boletin_99.json: Found 175 dialogue turns.
#   Finished processing 138 files in this folder.
#
# Processing folder: legislatura_373
#   Found 67 JSON files.
#     Fallback Regex on boletin_1.json (found 0 structured)...
#     Processed boletin_1.json: Found 200 dialogue turns.
#     Fallback Regex on boletin_10.json (found 0 structured)...
#     Processed boletin_10.json: Found 204 dialogue turns.
#     Fallback Regex on boletin_11.json (found 0 structured)...
#     Processed boletin_11.json: Found 276 dialogue turns.
#     Fallback Regex on boletin_12.json (found 0 structured)...
#     Processed boletin_12.json: Found 120 dialogue turns.
#     Fallback Regex on boletin_13.json (found 0 structured)...
#     Processed boletin_13.json: Found 205 dialogue turns.
#     Fallback Regex on boletin_14.json (found 0 structured)...
#     Processed boletin_14.json: Found 68 dialogue turns.
#     Fallback Regex on boletin_15.json (found 0 structured)...
#     Processed boletin_15.json: Found 176 dialogue turns.
#     Fallback Regex on boletin_16.json (found 0 structured)...
#     Processed boletin_16.json: Found 142 dialogue turns.
#     Fallback Regex on boletin_17.json (found 0 structured)...
#     Processed boletin_17.json: Found 233 dialogue turns.
#     Fallback Regex on boletin_18.json (found 0 structured)...
#     Processed boletin_18.json: Found 214 dialogue turns.
#     Fallback Regex on boletin_19.json (found 0 structured)...
#     Processed boletin_19.json: Found 95 dialogue turns.
#     Fallback Regex on boletin_2.json (found 0 structured)...
#     Processed boletin_2.json: Found 202 dialogue turns.
#     Fallback Regex on boletin_20.json (found 0 structured)...
#     Processed boletin_20.json: Found 216 dialogue turns.
#     Fallback Regex on boletin_21.json (found 0 structured)...
#     Processed boletin_21.json: Found 105 dialogue turns.
#     Fallback Regex on boletin_22.json (found 0 structured)...
#     Processed boletin_22.json: Found 231 dialogue turns.
#     Fallback Regex on boletin_23.json (found 0 structured)...
#     Processed boletin_23.json: Found 175 dialogue turns.
#     Fallback Regex on boletin_24.json (found 0 structured)...
#     Processed boletin_24.json: Found 198 dialogue turns.
#     Fallback Regex on boletin_25.json (found 0 structured)...
#     Processed boletin_25.json: Found 252 dialogue turns.
#     Fallback Regex on boletin_26.json (found 0 structured)...
#     Processed boletin_26.json: Found 170 dialogue turns.
#     Fallback Regex on boletin_27.json (found 0 structured)...
#     Processed boletin_27.json: Found 105 dialogue turns.
#     Fallback Regex on boletin_28.json (found 0 structured)...
#     Processed boletin_28.json: Found 109 dialogue turns.
#     Fallback Regex on boletin_29.json (found 0 structured)...
#     Processed boletin_29.json: Found 82 dialogue turns.
#     Fallback Regex on boletin_3.json (found 0 structured)...
#     Processed boletin_3.json: Found 136 dialogue turns.
#     Fallback Regex on boletin_30.json (found 0 structured)...
#     Processed boletin_30.json: Found 162 dialogue turns.
#     Fallback Regex on boletin_31.json (found 0 structured)...
#     Processed boletin_31.json: Found 155 dialogue turns.
#     Fallback Regex on boletin_32.json (found 0 structured)...
#     Processed boletin_32.json: Found 41 dialogue turns.
#     Fallback Regex on boletin_33.json (found 0 structured)...
#     Processed boletin_33.json: Found 259 dialogue turns.
#     Fallback Regex on boletin_34.json (found 0 structured)...
#     Processed boletin_34.json: Found 112 dialogue turns.
#     Fallback Regex on boletin_35.json (found 0 structured)...
#     Processed boletin_35.json: Found 214 dialogue turns.
#     Fallback Regex on boletin_36.json (found 0 structured)...
#     Processed boletin_36.json: Found 211 dialogue turns.
#     Fallback Regex on boletin_37.json (found 0 structured)...
#     Processed boletin_37.json: Found 52 dialogue turns.
#     Fallback Regex on boletin_38.json (found 0 structured)...
#     Processed boletin_38.json: Found 85 dialogue turns.
#     Fallback Regex on boletin_39.json (found 0 structured)...
#     Processed boletin_39.json: Found 222 dialogue turns.
#     Fallback Regex on boletin_4.json (found 0 structured)...
#     Processed boletin_4.json: Found 181 dialogue turns.
#     Fallback Regex on boletin_40.json (found 0 structured)...
#     Processed boletin_40.json: Found 201 dialogue turns.
#     Fallback Regex on boletin_41.json (found 0 structured)...
#     Processed boletin_41.json: Found 70 dialogue turns.
#     Fallback Regex on boletin_42.json (found 0 structured)...
#     Processed boletin_42.json: Found 131 dialogue turns.
#     Fallback Regex on boletin_43.json (found 0 structured)...
#     Processed boletin_43.json: Found 284 dialogue turns.
#     Fallback Regex on boletin_44.json (found 0 structured)...
#     Processed boletin_44.json: Found 184 dialogue turns.
#     Fallback Regex on boletin_45.json (found 0 structured)...
#     Processed boletin_45.json: Found 102 dialogue turns.
#     Fallback Regex on boletin_46.json (found 0 structured)...
#     Processed boletin_46.json: Found 194 dialogue turns.
#     Fallback Regex on boletin_47.json (found 0 structured)...
#     Processed boletin_47.json: Found 191 dialogue turns.
#     Fallback Regex on boletin_48.json (found 0 structured)...
#     Processed boletin_48.json: Found 60 dialogue turns.
#     Fallback Regex on boletin_49.json (found 0 structured)...
#     Processed boletin_49.json: Found 117 dialogue turns.
#     Fallback Regex on boletin_5.json (found 0 structured)...
#     Processed boletin_5.json: Found 222 dialogue turns.
#     Fallback Regex on boletin_50.json (found 0 structured)...
#     Processed boletin_50.json: Found 214 dialogue turns.
#     Fallback Regex on boletin_51.json (found 0 structured)...
#     Processed boletin_51.json: Found 131 dialogue turns.
#     Fallback Regex on boletin_52.json (found 0 structured)...
#     Processed boletin_52.json: Found 245 dialogue turns.
#     Fallback Regex on boletin_53.json (found 0 structured)...
#     Processed boletin_53.json: Found 70 dialogue turns.
#     Fallback Regex on boletin_54.json (found 0 structured)...
#     Processed boletin_54.json: Found 121 dialogue turns.
#     Fallback Regex on boletin_55.json (found 0 structured)...
#     Processed boletin_55.json: Found 202 dialogue turns.
#     Fallback Regex on boletin_57.json (found 0 structured)...
#     Processed boletin_57.json: Found 139 dialogue turns.
#     Fallback Regex on boletin_58.json (found 0 structured)...
#     Processed boletin_58.json: Found 200 dialogue turns.
#     Fallback Regex on boletin_59.json (found 0 structured)...
#     Processed boletin_59.json: Found 255 dialogue turns.
#     Fallback Regex on boletin_6.json (found 0 structured)...
#     Processed boletin_6.json: Found 138 dialogue turns.
#     Fallback Regex on boletin_60.json (found 0 structured)...
#     Processed boletin_60.json: Found 178 dialogue turns.
#     Fallback Regex on boletin_61.json (found 0 structured)...
#     Processed boletin_61.json: Found 339 dialogue turns.
#     Fallback Regex on boletin_62.json (found 0 structured)...
#     Processed boletin_62.json: Found 124 dialogue turns.
#     Fallback Regex on boletin_63.json (found 0 structured)...
#     Processed boletin_63.json: Found 96 dialogue turns.
#     Fallback Regex on boletin_64.json (found 0 structured)...
#     Processed boletin_64.json: Found 219 dialogue turns.
#     Fallback Regex on boletin_65.json (found 0 structured)...
#     Processed boletin_65.json: Found 78 dialogue turns.
#     Fallback Regex on boletin_66.json (found 0 structured)...
#     Processed boletin_66.json: Found 205 dialogue turns.
#     Fallback Regex on boletin_67.json (found 0 structured)...
#     Processed boletin_67.json: Found 127 dialogue turns.
#     Fallback Regex on boletin_68.json (found 0 structured)...
#     Processed boletin_68.json: Found 167 dialogue turns.
#     Fallback Regex on boletin_7.json (found 0 structured)...
#     Processed boletin_7.json: Found 265 dialogue turns.
#     Fallback Regex on boletin_8.json (found 0 structured)...
#     Processed boletin_8.json: Found 158 dialogue turns.
#     Fallback Regex on boletin_9.json (found 0 structured)...
#     Processed boletin_9.json: Found 135 dialogue turns.
#   Finished processing 67 files in this folder.
#
# --- Skipping Post-Processing: Name normalization removed as requested. ---
#
# Successfully created DataFrame with 253442 dialogue turns from 2541 files (2541 successfully processed) across 28 folders.
# Average dialogue turns per successfully processed file: 99.74
# Data saved to segmented_dialogues_all_legislaturas_v14_name_fix.csv
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253442 entries, 0 to 253441
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   numero_legislatura  253442 non-null  object
#  1   numero_sesion       253442 non-null  object
#  2   fecha_sesion        253442 non-null  object
#  3   boletin_proyecto    253442 non-null  object
#  4   speaker_name        253442 non-null  object
#  5   speaker_type        253442 non-null  object
#  6   text                253442 non-null  object
#  7   source_file         253442 non-null  object
# dtypes: object(8)
# memory usage: 15.5+ MB
#
# DataFrame Head (Muestra Inicial):
#   numero_legislatura numero_sesion         fecha_sesion boletin_proyecto  \
# 0                346            10  10-04-2002 10:36:00      2852-07 (S)
# 1                346            10  10-04-2002 10:36:00      2852-07 (S)
# 2                346            10  10-04-2002 10:36:00      2852-07 (S)
# 3                346            10  10-04-2002 10:36:00      2852-07 (S)
# 4                346            10  10-04-2002 10:36:00      2852-07 (S)
#
#      speaker_name speaker_type  \
# 0  MUÑOZ, Adriana   Presidente
# 1  MUÑOZ, Adriana   Presidente
# 2  MUÑOZ, Adriana   Presidente
# 3        ESCALONA     Diputado
# 4  MUÑOZ, Adriana   Presidente
#
#                                                 text  \
# 0  La señora MUÑOZ, doña Adriana (Presidenta).- E...
# 1  La señora MUÑOZ, doña Adriana (Presidenta).- T...
# 2  La señora MUÑOZ, doña Adriana (Presidenta).- L...
# 3   El señor ESCALONA.- Muy bien, señora Presidenta.
# 4  La señora MUÑOZ, doña Adriana (Presidenta).- T...
#
#                                          source_file
# 0  C:/Users/conjv/Desktop/boletines_json/legislat...
# 1  C:/Users/conjv/Desktop/boletines_json/legislat...
# 2  C:/Users/conjv/Desktop/boletines_json/legislat...
# 3  C:/Users/conjv/Desktop/boletines_json/legislat...
# 4  C:/Users/conjv/Desktop/boletines_json/legislat...
#
# DataFrame Tail (Muestra Final):
#        numero_legislatura numero_sesion fecha_sesion boletin_proyecto  \
# 253437                373             9   07-04-2025              N/A
# 253438                373             9   07-04-2025              N/A
# 253439                373             9   07-04-2025              N/A
# 253440                373             9   07-04-2025              N/A
# 253441                373             9   07-04-2025              N/A
#
#           speaker_name    speaker_type  \
# 253437           RIVAS  Vicepresidente
# 253438  Matías RAMÍREZ        Diputado
# 253439           RIVAS  Vicepresidente
# 253440          GUZMÁN        Diputado
# 253441          CASTRO      Presidente
#
#                                                      text  \
# 253437  El señor RIVAS (Vicepresidente).- En discusión...
# 253438  El señor RAMÍREZ (don Matías).- Señor Presiden...
# 253439  El señor RIVAS (Vicepresidente).- Tiene la pal...
# 253440  El señor GUZMÁN.- Señor Presidente, hoy nos co...
# 253441  El señor CASTRO (Presidente).- Ha concluido el...
#
#                                               source_file
# 253437  C:/Users/conjv/Desktop/boletines_json/legislat...
# 253438  C:/Users/conjv/Desktop/boletines_json/legislat...
# 253439  C:/Users/conjv/Desktop/boletines_json/legislat...
# 253440  C:/Users/conjv/Desktop/boletines_json/legislat...
# 253441  C:/Users/conjv/Desktop/boletines_json/legislat...
#
# Verificación de Boletines (Ejemplos Aleatorios con Boletín):
#            boletin_proyecto     speaker_name  \
# 35523               5498-05           WALKER
# 152774             10975-25  ESPINOZA, Fidel
# 143705              9862-33   Marisol TURRES
# 145937             10752-11          ANDRADE
# 166830  10685-07 Y 10692-07  FERNÁNDEZ, Maya
#
#                                               source_file
# 35523   C:/Users/conjv/Desktop/boletines_json/legislat...
# 152774  C:/Users/conjv/Desktop/boletines_json/legislat...
# 143705  C:/Users/conjv/Desktop/boletines_json/legislat...
# 145937  C:/Users/conjv/Desktop/boletines_json/legislat...
# 166830  C:/Users/conjv/Desktop/boletines_json/legislat...
#
# Verificación de Diálogos sin Boletín (N/A):
#        boletin_proyecto       speaker_name  \
# 82796               N/A          BERTOLINO
# 83981               N/A     Marisol TURRES
# 92477               N/A      Díaz, Marcelo
# 219907              N/A               AEDO
# 155024              N/A  Hernández, Javier
#
#                                               source_file
# 82796   C:/Users/conjv/Desktop/boletines_json/legislat...
# 83981   C:/Users/conjv/Desktop/boletines_json/legislat...
# 92477   C:/Users/conjv/Desktop/boletines_json/legislat...
# 219907  C:/Users/conjv/Desktop/boletines_json/legislat...
# 155024  C:/Users/conjv/Desktop/boletines_json/legislat...
#
# Sample Speaker Types Found:
# speaker_type
# Diputado                   128280
# Presidente                  52528
# Vicepresidente              46956
# Presidente (Accidental)     15439
# Secretario                   5929
# Ministro                     3503
# Autoridad                     263
# Narrador                      240
# Prosecretario                 152
# Subsecretario                 143
# Desconocido                     4
# Director                        4
# Fiscal                          1
# Name: count, dtype: int64
#
# Sample Speaker Names (NUEVO v14 - Corregido):
# Ejemplos de nombres combinados (ej. Matías Ramírez):
# speaker_name
# CARIOLA, Karol          7626
# FLORES, Iván            4034
# MONCKEBERG, Nicolás     3667
# SEPÚLVEDA, Alejandra    3508
# NÚÑEZ, Marco Antonio    3453
# FERNÁNDEZ, Maya         2700
# ALLENDE, Isabel         2321
# Melero, Patricio        2312
# ESPINOZA, Fidel         2276
# Jaramillo, Enrique      1993
# Name: count, dtype: int64
#
# Top 30 nombres (Raw):
# speaker_name
# CARIOLA, Karol          7626
# RIVAS                   4487
# FLORES, Iván            4034
# AEDO                    3815
# ORTIZ                   3803
# MONCKEBERG, Nicolás     3667
# SEPÚLVEDA, Alejandra    3508
# NÚÑEZ, Marco Antonio    3453
# FERNÁNDEZ, Maya         2700
# ÁLVAREZ                 2602
# SALAS                   2570
# ANDRADE                 2530
# CORNEJO                 2523
# CIFUENTES               2474
# ALLENDE, Isabel         2321
# Melero, Patricio        2312
# CASTRO                  2310
# ESPINOZA, Fidel         2276
# SEPÚLVEDA               2257
# MELERO                  2156
# WALKER                  2144
# ELUCHANS                2109
# PAULSEN                 2074
# Jaramillo, Enrique      1993
# MEZA                    1979
# MIX, Claudia            1933
# SOTO, Raúl              1768
# LEAL                    1752
# CARVAJAL, Ma Loreto     1702
# BECKER                  1692
# Name: count, dtype: int64
#
# Speakers with parsing errors (if any):
#   Found 4 turns with name errors or 'Desconocido'.
#   Examples (source files): ['C:/Users/conjv/Desktop/boletines_json/legislatura_356\\boletin_7.json'
#  'C:/Users/conjv/Desktop/boletines_json/legislatura_361\\boletin_3.json'
#  'C:/Users/conjv/Desktop/boletines_json/legislatura_361\\boletin_5.json'
#  'C:/Users/conjv/Desktop/boletines_json/legislatura_364\\boletin_42.json']

# %%
df
# Out:
#        numero_legislatura numero_sesion         fecha_sesion boletin_proyecto  \
# 0                     346            10  10-04-2002 10:36:00      2852-07 (S)
# 1                     346            10  10-04-2002 10:36:00      2852-07 (S)
# 2                     346            10  10-04-2002 10:36:00      2852-07 (S)
# 3                     346            10  10-04-2002 10:36:00      2852-07 (S)
# 4                     346            10  10-04-2002 10:36:00      2852-07 (S)
# ...                   ...           ...                  ...              ...
# 253437                373             9           07-04-2025              N/A
# 253438                373             9           07-04-2025              N/A
# 253439                373             9           07-04-2025              N/A
# 253440                373             9           07-04-2025              N/A
# 253441                373             9           07-04-2025              N/A
#
#           speaker_name    speaker_type  \
# 0       MUÑOZ, Adriana      Presidente
# 1       MUÑOZ, Adriana      Presidente
# 2       MUÑOZ, Adriana      Presidente
# 3             ESCALONA        Diputado
# 4       MUÑOZ, Adriana      Presidente
# ...                ...             ...
# 253437           RIVAS  Vicepresidente
# 253438  Matías RAMÍREZ        Diputado
# 253439           RIVAS  Vicepresidente
# 253440          GUZMÁN        Diputado
# 253441          CASTRO      Presidente
#
#                                                      text  \
# 0       La señora MUÑOZ, doña Adriana (Presidenta).- E...
# 1       La señora MUÑOZ, doña Adriana (Presidenta).- T...
# 2       La señora MUÑOZ, doña Adriana (Presidenta).- L...
# 3        El señor ESCALONA.- Muy bien, señora Presidenta.
# 4       La señora MUÑOZ, doña Adriana (Presidenta).- T...
# ...                                                   ...
# 253437  El señor RIVAS (Vicepresidente).- En discusión...
# 253438  El señor RAMÍREZ (don Matías).- Señor Presiden...
# 253439  El señor RIVAS (Vicepresidente).- Tiene la pal...
# 253440  El señor GUZMÁN.- Señor Presidente, hoy nos co...
# 253441  El señor CASTRO (Presidente).- Ha concluido el...
#
#                                               source_file
# 0       C:/Users/conjv/Desktop/boletines_json/legislat...
# 1       C:/Users/conjv/Desktop/boletines_json/legislat...
# 2       C:/Users/conjv/Desktop/boletines_json/legislat...
# 3       C:/Users/conjv/Desktop/boletines_json/legislat...
# 4       C:/Users/conjv/Desktop/boletines_json/legislat...
# ...                                                   ...
# 253437  C:/Users/conjv/Desktop/boletines_json/legislat...
# 253438  C:/Users/conjv/Desktop/boletines_json/legislat...
# 253439  C:/Users/conjv/Desktop/boletines_json/legislat...
# 253440  C:/Users/conjv/Desktop/boletines_json/legislat...
# 253441  C:/Users/conjv/Desktop/boletines_json/legislat...
#
# [253442 rows x 8 columns]

# %%
# --- (NUEVO PASO) Crear un DataFrame filtrado solo con 'Diputado' ---

print("\n--- Creando DataFrame filtrado solo para 'Diputado' ---")

# Filtramos el DataFrame 'df' para quedarnos solo con las filas donde 'speaker_type' es 'Diputado'
# Usamos .copy() para asegurar que sea un DataFrame nuevo e independiente
df_diputados = df[df['speaker_type'] == 'Diputado'].copy()

# Opcional: Mostrar la cabecera del nuevo DataFrame para verificar
print(f"Total de filas en el DF original: {len(df)}")
print(f"Total de filas en el nuevo DF (Solo Diputados): {len(df_diputados)}")
print("\nMuestra del nuevo DataFrame (df_diputados):")
print(df_diputados.head())

# Opcional: Guardar este nuevo DataFrame en su propio CSV
try:
    output_filename_diputados = 'segmented_dialogues_SOLO_DIPUTADOS.csv'
    #df_diputados.to_csv(output_filename_diputados, index=False, encoding='utf-8-sig')
    print(f"\nDataFrame solo con diputados guardado exitosamente en: {output_filename_diputados}")
except Exception as e:
    print(f"\nError al guardar el CSV de solo diputados: {e}")

df_diputados
# Out:
# --- Creando DataFrame filtrado solo para 'Diputado' ---
# Total de filas en el DF original: 253442
# Total de filas en el nuevo DF (Solo Diputados): 128280
#
# Muestra del nuevo DataFrame (df_diputados):
#    numero_legislatura numero_sesion         fecha_sesion boletin_proyecto  \
# 3                 346            10  10-04-2002 10:36:00      2852-07 (S)
# 7                 346            10  10-04-2002 10:36:00      2852-07 (S)
# 8                 346            10  10-04-2002 10:36:00      2852-07 (S)
# 9                 346            10  10-04-2002 10:36:00      2852-07 (S)
# 10                346            10  10-04-2002 10:36:00      2852-07 (S)
#
#           speaker_name speaker_type  \
# 3             ESCALONA     Diputado
# 7         Bustos, Juan     Diputado
# 8       MUÑOZ, Adriana     Diputado
# 9   Ortiz, José Miguel     Diputado
# 10      MUÑOZ, Adriana     Diputado
#
#                                                  text  \
# 3    El señor ESCALONA.- Muy bien, señora Presidenta.
# 7   El señor BUSTOS.- Señora Presidenta, la reform...
# 8   La señora MUÑOZ, doña Adriana (Presidenta).- T...
# 9   El señor ORTIZ.- Señora Presidenta, el día de ...
# 10  La señora MUÑOZ, doña Adriana (Presidenta).- T...
#
#                                           source_file
# 3   C:/Users/conjv/Desktop/boletines_json/legislat...
# 7   C:/Users/conjv/Desktop/boletines_json/legislat...
# 8   C:/Users/conjv/Desktop/boletines_json/legislat...
# 9   C:/Users/conjv/Desktop/boletines_json/legislat...
# 10  C:/Users/conjv/Desktop/boletines_json/legislat...
#
# DataFrame solo con diputados guardado exitosamente en: segmented_dialogues_SOLO_DIPUTADOS.csv
#        numero_legislatura numero_sesion         fecha_sesion boletin_proyecto  \
# 3                     346            10  10-04-2002 10:36:00      2852-07 (S)
# 7                     346            10  10-04-2002 10:36:00      2852-07 (S)
# 8                     346            10  10-04-2002 10:36:00      2852-07 (S)
# 9                     346            10  10-04-2002 10:36:00      2852-07 (S)
# 10                    346            10  10-04-2002 10:36:00      2852-07 (S)
# ...                   ...           ...                  ...              ...
# 253425                373             9           07-04-2025              N/A
# 253427                373             9           07-04-2025              N/A
# 253436                373             9           07-04-2025              N/A
# 253438                373             9           07-04-2025              N/A
# 253440                373             9           07-04-2025              N/A
#
#               speaker_name speaker_type  \
# 3                 ESCALONA     Diputado
# 7             Bustos, Juan     Diputado
# 8           MUÑOZ, Adriana     Diputado
# 9       Ortiz, José Miguel     Diputado
# 10          MUÑOZ, Adriana     Diputado
# ...                    ...          ...
# 253425         Mónica ARCE     Diputado
# 253427              KAISER     Diputado
# 253436            MATHESON     Diputado
# 253438      Matías RAMÍREZ     Diputado
# 253440              GUZMÁN     Diputado
#
#                                                      text  \
# 3        El señor ESCALONA.- Muy bien, señora Presidenta.
# 7       El señor BUSTOS.- Señora Presidenta, la reform...
# 8       La señora MUÑOZ, doña Adriana (Presidenta).- T...
# 9       El señor ORTIZ.- Señora Presidenta, el día de ...
# 10      La señora MUÑOZ, doña Adriana (Presidenta).- T...
# ...                                                   ...
# 253425  La señora ARCE (doña Mónica).- Señor President...
# 253427  El señor KAISER.- Señor Presidente, de hecho, ...
# 253436  El señor MATHESON (de pie).- Honorable Cámara,...
# 253438  El señor RAMÍREZ (don Matías).- Señor Presiden...
# 253440  El señor GUZMÁN.- Señor Presidente, hoy nos co...
#
#                                               source_file
# 3       C:/Users/conjv/Desktop/boletines_json/legislat...
# 7       C:/Users/conjv/Desktop/boletines_json/legislat...
# 8       C:/Users/conjv/Desktop/boletines_json/legislat...
# 9       C:/Users/conjv/Desktop/boletines_json/legislat...
# 10      C:/Users/conjv/Desktop/boletines_json/legislat...
# ...                                                   ...
# 253425  C:/Users/conjv/Desktop/boletines_json/legislat...
# 253427  C:/Users/conjv/Desktop/boletines_json/legislat...
# 253436  C:/Users/conjv/Desktop/boletines_json/legislat...
# 253438  C:/Users/conjv/Desktop/boletines_json/legislat...
# 253440  C:/Users/conjv/Desktop/boletines_json/legislat...
#
# [128280 rows x 8 columns]

# %%
import pandas as pd
from rapidfuzz import process, fuzz
import re

# === 1. Cargar datos ===
try:
    nombres_df = pd.read_csv("C:/Users/conjv/Desktop/boletines_json/nombres_unicos.csv")
except FileNotFoundError:
    print("Error: No se pudo encontrar el archivo 'nombres_unicos.csv'. Asegúrate de que la ruta sea correcta.")
    exit()

# === 2. Funciones de limpieza y NUEVAS funciones de género ===

def limpiar_nombre(nombre):
    """Limpia comas, espacios extra y convierte a minúsculas"""
    if pd.isna(nombre):
        return ""
    return nombre.replace(",", "").strip().lower()

def eliminar_ultimo_apellido(nombre):
    """Elimina el último token (apellido final) y convierte a minúsculas"""
    if pd.isna(nombre):
        return ""
    tokens = nombre.strip().split()
    base = " ".join(tokens[:-1]) if len(tokens) > 1 else tokens[0]
    return base.lower()

def guess_gender(full_name):
    """
    (NUEVO) Intenta adivinar el género basado en nombres comunes en español.
    Esto es una heurística, pero es crucial para desambiguar.
    """
    if pd.isna(full_name):
        return 'unknown'
    
    name_lower = full_name.lower()
    tokens = name_lower.split()
    if not tokens:
        return 'unknown'
    
    first_name = tokens[0]
    
    # Lista de nombres femeninos comunes (se puede expandir)
    female_names = ['maría', 'pía', 'adriana', 'mónica', 'karol', 'maya', 'daniella', 'karin', 'carolina', 'maite', 'marisela', 'virginia', 'francesca', 'catalina', 'claudia', 'lorena']
    # Lista de nombres masculinos comunes (se puede expandir)
    male_names = ['jorge', 'camilo', 'juan', 'josé', 'matías', 'sergio', 'christian', 'johannes', 'ramón', 'julio', 'eugenio', 'rené', 'josé', 'camilo', 'germán', 'enrique', 'claudio', 'carlos', 'pablo', 'felipe', 'alfonso', 'antonio']

    if first_name in female_names:
        return 'female'
    if first_name in male_names:
        return 'male'
    
    # Heurística de terminación si no está en la lista
    if first_name.endswith('a'):
        return 'female'
    if first_name.endswith('o'):
        return 'male'
        
    return 'unknown'

def extract_gender_from_cue(text_cue):
    """
    (NUEVO) Extrae el género ("male", "female") del texto de la intervención.
    """
    if pd.isna(text_cue):
        return 'unknown'
    
    text_lower = text_cue.lower()
    
    # Usar regex para buscar las palabras clave al inicio o con paréntesis
    if re.search(r'el señor|\(don ', text_lower):
        return 'male'
    if re.search(r'la señora|la señorita|\(doña ', text_lower):
        return 'female'
        
    return 'unknown'

# === 3. Preparar los DataFrames ===
# Aplicar limpieza
df_diputados["speaker_name_clean"] = df_diputados["speaker_name"].astype(str).apply(limpiar_nombre)
nombres_df["nombre_sin_ultimo"] = nombres_df["nombre_completos"].astype(str).apply(eliminar_ultimo_apellido)

# (NUEVO) Añadir columnas de género a ambos DataFrames
nombres_df["gender_guess"] = nombres_df["nombre_completos"].apply(guess_gender)
df_diputados["cue_gender"] = df_diputados["text"].apply(extract_gender_from_cue)

# (NUEVO) Crear listas de referencia filtradas por género
lista_ref_male = nombres_df[nombres_df["gender_guess"] == 'male']["nombre_sin_ultimo"].tolist()
lista_ref_female = nombres_df[nombres_df["gender_guess"] == 'female']["nombre_sin_ultimo"].tolist()
lista_ref_all = nombres_df["nombre_sin_ultimo"].tolist()

# === 4. Fuzzy matching con rapidfuzz (Función CORREGIDA) ===

def obtener_nombre_completo(row):
    """
    (CORREGIDO) Ahora acepta una 'row' completa para poder usar el género como filtro.
    """
    nombre_limpio = row['speaker_name_clean']
    genero_del_cue = row['cue_gender']
    
    if not nombre_limpio:
        return None
    
    lista_a_usar = lista_ref_all
    
    # (NUEVA LÓGICA) Elegir la lista de búsqueda correcta basada en el género del texto
    if genero_del_cue == 'male':
        lista_a_usar = lista_ref_male
    elif genero_del_cue == 'female':
        lista_a_usar = lista_ref_female
    # Si el género es 'unknown', usará la lista_ref_all (comportamiento anterior)

    match = process.extractOne(
        nombre_limpio,
        lista_a_usar,
        scorer=fuzz.token_set_ratio,
        score_cutoff=85  # Umbral de confianza
    )
    
    if match is None:
        # Si no encontró nada en la lista filtrada, intentar con la lista completa como último recurso
        match = process.extractOne(
            nombre_limpio,
            lista_ref_all,
            scorer=fuzz.token_set_ratio,
            score_cutoff=85
        )
        if match is None:
            return None

    # Encontrar el nombre completo original usando el match
    mejor_match = match[0]
    fila = nombres_df.loc[nombres_df["nombre_sin_ultimo"] == mejor_match, "nombre_completos"]
    return fila.iloc[0] if not fila.empty else None

# === 5. Aplicar la función ===
# (CORREGIDO) Usamos axis=1 para pasar la fila completa a la función
df_diputados["nombre_normalizado_final"] = df_diputados.apply(obtener_nombre_completo, axis=1)

# === 6. Mostrar resultados ===
print("Verificación del match para 'GUZMÁN' (El señor...):")
print(df_diputados[df_diputados['speaker_name'] == 'GUZMÁN'][['text', 'speaker_name_clean', 'cue_gender', 'nombre_normalizado_final']])

print("\nVerificación del match para 'KAISER' (El señor...):")
print(df_diputados[df_diputados['speaker_name'] == 'KAISER'][['text', 'speaker_name_clean', 'cue_gender', 'nombre_normalizado_final']])

print("\nDataFrame final (muestra):")
print(df_diputados[['speaker_name', 'text', 'nombre_normalizado_final']].head())
# Out:
# Verificación del match para 'GUZMÁN' (El señor...):
#                                                      text speaker_name_clean  \
# 195149  El señor GUZMÁN.- Señor Presidente, desde ya a...             guzmán
# 196386  El señor GUZMÁN.- Señor Presidente, algunos de...             guzmán
# 196432  El señor GUZMÁN.- Señor Presidente, vengo a in...             guzmán
# 201328  El señor GUZMÁN.- Señor Presidente, en el mome...             guzmán
# 203476  El señor GUZMÁN.- Señora Presidenta, la Conven...             guzmán
# ...                                                   ...                ...
# 252901  El señor GUZMÁN.- Señor Presidente, nadie debi...             guzmán
# 252979  El señor GUZMÁN.- Señor Presidente, el 26 de m...             guzmán
# 253269  El señor GUZMÁN.- Señor Presidente, usted tien...             guzmán
# 253324  El señor GUZMÁN.- Señor Presidente, por su int...             guzmán
# 253440  El señor GUZMÁN.- Señor Presidente, hoy nos co...             guzmán
#
#        cue_gender nombre_normalizado_final
# 195149       male      Jorge Guzmán Zepeda
# 196386       male      Jorge Guzmán Zepeda
# 196432       male      Jorge Guzmán Zepeda
# 201328       male      Jorge Guzmán Zepeda
# 203476       male      Jorge Guzmán Zepeda
# ...           ...                      ...
# 252901       male      Jorge Guzmán Zepeda
# 252979       male      Jorge Guzmán Zepeda
# 253269       male      Jorge Guzmán Zepeda
# 253324       male      Jorge Guzmán Zepeda
# 253440       male      Jorge Guzmán Zepeda
#
# [162 rows x 4 columns]
#
# Verificación del match para 'KAISER' (El señor...):
#                                                      text speaker_name_clean  \
# 195163  El señor KAISER.- Señor Presidente, en mi mano...             kaiser
# 196274  El señor KAISER.- Señor Presidente, les deseo ...             kaiser
# 196328  El señor KAISER.- Señor Presidente, hay gente ...             kaiser
# 196345  El señor KAISER.- Señor Presidente, solicito a...             kaiser
# 200114  El señor KAISER.- Señor Presidente, ¿quiénes h...             kaiser
# ...                                                   ...                ...
# 252373  El señor KAISER.- Señor Presidente, la ley es ...             kaiser
# 252494  El señor KAISER.- Señor Presidente, nosotros l...             kaiser
# 252713  El señor KAISER.- Señor Presidente, consideran...             kaiser
# 253273  El señor KAISER.- Señor Presidente, en esta se...             kaiser
# 253427  El señor KAISER.- Señor Presidente, de hecho, ...             kaiser
#
#        cue_gender                nombre_normalizado_final
# 195163       male  Johannes Kaiser Barents-Von Hohenhagen
# 196274       male  Johannes Kaiser Barents-Von Hohenhagen
# 196328       male  Johannes Kaiser Barents-Von Hohenhagen
# 196345       male  Johannes Kaiser Barents-Von Hohenhagen
# 200114       male  Johannes Kaiser Barents-Von Hohenhagen
# ...           ...                                     ...
# 252373       male  Johannes Kaiser Barents-Von Hohenhagen
# 252494       male  Johannes Kaiser Barents-Von Hohenhagen
# 252713       male  Johannes Kaiser Barents-Von Hohenhagen
# 253273       male  Johannes Kaiser Barents-Von Hohenhagen
# 253427       male  Johannes Kaiser Barents-Von Hohenhagen
#
# [329 rows x 4 columns]
#
# DataFrame final (muestra):
#           speaker_name                                               text  \
# 3             ESCALONA   El señor ESCALONA.- Muy bien, señora Presidenta.
# 7         Bustos, Juan  El señor BUSTOS.- Señora Presidenta, la reform...
# 8       MUÑOZ, Adriana  La señora MUÑOZ, doña Adriana (Presidenta).- T...
# 9   Ortiz, José Miguel  El señor ORTIZ.- Señora Presidenta, el día de ...
# 10      MUÑOZ, Adriana  La señora MUÑOZ, doña Adriana (Presidenta).- T...
#
#    nombre_normalizado_final
# 3    Camilo Escalona Medina
# 7       Juan Bustos Ramírez
# 8    Adriana Muñoz D'Albora
# 9   José Miguel Ortiz Novoa
# 10   Adriana Muñoz D'Albora

# %%
df_diputados
# Out:
#        numero_legislatura numero_sesion         fecha_sesion boletin_proyecto  \
# 3                     346            10  10-04-2002 10:36:00      2852-07 (S)
# 7                     346            10  10-04-2002 10:36:00      2852-07 (S)
# 8                     346            10  10-04-2002 10:36:00      2852-07 (S)
# 9                     346            10  10-04-2002 10:36:00      2852-07 (S)
# 10                    346            10  10-04-2002 10:36:00      2852-07 (S)
# ...                   ...           ...                  ...              ...
# 253425                373             9           07-04-2025              N/A
# 253427                373             9           07-04-2025              N/A
# 253436                373             9           07-04-2025              N/A
# 253438                373             9           07-04-2025              N/A
# 253440                373             9           07-04-2025              N/A
#
#               speaker_name speaker_type  \
# 3                 ESCALONA     Diputado
# 7             Bustos, Juan     Diputado
# 8           MUÑOZ, Adriana     Diputado
# 9       Ortiz, José Miguel     Diputado
# 10          MUÑOZ, Adriana     Diputado
# ...                    ...          ...
# 253425         Mónica ARCE     Diputado
# 253427              KAISER     Diputado
# 253436            MATHESON     Diputado
# 253438      Matías RAMÍREZ     Diputado
# 253440              GUZMÁN     Diputado
#
#                                                      text  \
# 3        El señor ESCALONA.- Muy bien, señora Presidenta.
# 7       El señor BUSTOS.- Señora Presidenta, la reform...
# 8       La señora MUÑOZ, doña Adriana (Presidenta).- T...
# 9       El señor ORTIZ.- Señora Presidenta, el día de ...
# 10      La señora MUÑOZ, doña Adriana (Presidenta).- T...
# ...                                                   ...
# 253425  La señora ARCE (doña Mónica).- Señor President...
# 253427  El señor KAISER.- Señor Presidente, de hecho, ...
# 253436  El señor MATHESON (de pie).- Honorable Cámara,...
# 253438  El señor RAMÍREZ (don Matías).- Señor Presiden...
# 253440  El señor GUZMÁN.- Señor Presidente, hoy nos co...
#
#                                               source_file speaker_name_clean  \
# 3       C:/Users/conjv/Desktop/boletines_json/legislat...           escalona
# 7       C:/Users/conjv/Desktop/boletines_json/legislat...        bustos juan
# 8       C:/Users/conjv/Desktop/boletines_json/legislat...      muñoz adriana
# 9       C:/Users/conjv/Desktop/boletines_json/legislat...  ortiz josé miguel
# 10      C:/Users/conjv/Desktop/boletines_json/legislat...      muñoz adriana
# ...                                                   ...                ...
# 253425  C:/Users/conjv/Desktop/boletines_json/legislat...        mónica arce
# 253427  C:/Users/conjv/Desktop/boletines_json/legislat...             kaiser
# 253436  C:/Users/conjv/Desktop/boletines_json/legislat...           matheson
# 253438  C:/Users/conjv/Desktop/boletines_json/legislat...     matías ramírez
# 253440  C:/Users/conjv/Desktop/boletines_json/legislat...             guzmán
#
#        cue_gender                nombre_normalizado_final
# 3            male                  Camilo Escalona Medina
# 7            male                     Juan Bustos Ramírez
# 8          female                  Adriana Muñoz D'Albora
# 9            male                 José Miguel Ortiz Novoa
# 10         female                  Adriana Muñoz D'Albora
# ...           ...                                     ...
# 253425     female                      Mónica Arce Castro
# 253427       male  Johannes Kaiser Barents-Von Hohenhagen
# 253436       male               Christian Matheson Villán
# 253438       male                   Matías Ramírez Pascal
# 253440       male                     Jorge Guzmán Zepeda
#
# [128280 rows x 11 columns]

# %%
columns_a_eliminar = ["speaker_name", "speaker_name_clean"]
df_final = df_diputados.drop(columns=columns_a_eliminar).copy()
df_final.to_parquet("df_dialogue_master_chief_pro_crack.parquet", index=False)
