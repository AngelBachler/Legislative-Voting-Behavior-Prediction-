# %% [markdown]
# # 03: Enriquecimiento Biográfico
#
# **Propósito:** Este *notebook* enriquece la lista de diputados (`diputados.csv`) con datos biográficos detallados, creando `diputados_bio.csv`.
#
# **Proceso:**
# 1.  Carga la lista de períodos (`periodos_master.csv`).
# 2.  Carga la tabla de consulta de BCN (`bcn_url_master_lookup.csv`).
# 3.  Para cada período:
#     a. Carga `diputados.csv`.
#     b. Resuelve las URLs de BCN usando *fuzzy matching* contra la tabla de consulta.
#     c. Scrapea el texto de las biografías y el distrito desde las URLs encontradas.
#     d. Usa un LLM (Ollama) para extraer datos estructurados (JSON) del texto.
#     e. Guarda el `DataFrame` enriquecido como `diputados_bio.csv`.
#
# **Dependencias:**
# * `data/01_raw/periodos_master.csv` (de `00_Extraction_Periods`)
# * `data/01_raw/bcn_url_master_lookup.csv` (de `02_Extraction_BCN_Lookup`)
# * `data/01_raw/[periodo]/diputados.csv` (de `01_Extraction_Deputies`)
#
# **Artefactos de Salida:**
# * `data/01_raw/[periodo]/diputados_bio.csv`

# %%
import pandas as pd
from pathlib import Path
import sys
import logging
import json
from tqdm.notebook import tqdm # Para barras de progreso

# --- Configurar Logging ---
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# --- Importar lógica personalizada de /src ---
sys.path.append('../') 
try:
    from src.common_utils import sanitize_filename, get_ollama_client
    from src.bio_utils import (
        find_best_match_bcn,    
        scrape_bcn_bio_data,       
        extract_bio_data_llm
    )
except ImportError as e:
    logging.error(f"ERROR: No se pudieron importar las funciones desde /src. {e}")
    logging.error("Asegúrese de que 'src/extraction_utils.py' y 'src/bio_utils.py' existan y contengan las funciones.")
    raise

tqdm.pandas()

# %%
# --- 1. Configuración de Rutas y Constantes ---
ROOT = Path.cwd().parent
DATA_DIR_RAW = ROOT / "data" / "01_raw"

# --- Definir ARCHIVOS DE ENTRADA (Dependencias) ---
MASTER_PERIOD_FILE = DATA_DIR_RAW / "periodos_master.csv"
BCN_LOOKUP_FILE = DATA_DIR_RAW / "bcn_url_master_lookup.csv"

# --- Configuración del LLM ---
OLLAMA_HOST = 'http://127.0.0.1:11434'
OLLAMA_MODEL = 'llama3:instruct' # Modelo recomendado
FUZZY_MATCH_THRESHOLD = 70       # Umbral de confianza para el matching

logging.info(f"Ruta Raíz: {ROOT}")
logging.info(f"Directorio de Datos Raw: {DATA_DIR_RAW}")
logging.info(f"Modelo LLM: {OLLAMA_MODEL}")
# Out:
# 2025-10-26 11:25:20,618 - INFO - Ruta Raíz: C:\Users\angel\OneDrive\Documents\U\2025-2\Proyecto de Grado\Legislative-Voting-Behavior-Prediction-
# 2025-10-26 11:25:20,620 - INFO - Directorio de Datos Raw: C:\Users\angel\OneDrive\Documents\U\2025-2\Proyecto de Grado\Legislative-Voting-Behavior-Prediction-\data\01_raw
# 2025-10-26 11:25:20,621 - INFO - Modelo LLM: llama3:instruct

# %% [markdown]
# ## 2. Carga de Dependencias (Períodos, BCN Lookup, Cliente LLM)
#
# Cargamos los artefactos maestros necesarios para el bucle y conectamos con Ollama.

# %%
try:
    df_periodos = pd.read_csv(MASTER_PERIOD_FILE)
    logging.info(f"Se cargó la lista maestra de {len(df_periodos)} períodos.")
    
    df_bcn_lookup = pd.read_csv(BCN_LOOKUP_FILE)
    logging.info(f"Se cargó la tabla de consulta BCN con {len(df_bcn_lookup)} registros.")
    
    # Crear la lista de períodos válidos para la función de scraping
    # (Corregido el bug de la variable global 'periodos')
    lista_periodos_validos = df_periodos['Nombre'].tolist()
    logging.info(f"Lista de {len(lista_periodos_validos)} períodos válidos creada.")

except FileNotFoundError as e:
    logging.error(f"ERROR FATAL: No se encontró el archivo de dependencia: {e.filename}")
    logging.error("Por favor, ejecute los notebooks '00' y '02' primero.")
    raise

# Inicializar cliente Ollama (UNA SOLA VEZ)
ollama_client = get_ollama_client(OLLAMA_HOST)
if ollama_client is None:
    logging.warning("No se pudo conectar a Ollama. La extracción de datos estructurados (LLM) se omitirá.")
# Out:
# 2025-10-25 22:45:49,901 - INFO - Se cargó la lista maestra de 10 períodos.
# 2025-10-25 22:45:49,906 - INFO - Se cargó la tabla de consulta BCN con 623 registros.
# 2025-10-25 22:45:49,907 - INFO - Lista de 10 períodos válidos creada.
# 2025-10-25 22:45:50,195 - INFO - HTTP Request: GET http://127.0.0.1:11434/api/tags "HTTP/1.1 200 OK"
# 2025-10-25 22:45:50,198 - INFO - Cliente Ollama conectado exitosamente en http://127.0.0.1:11434

# %%
logging.info(f"Iniciando enriquecimiento biográfico para {len(df_periodos)} períodos...")

choices_bcn = df_bcn_lookup['nombre_en_lista'].tolist()
url_map_bcn = df_bcn_lookup.set_index('nombre_en_lista')['url_wiki'].to_dict()

for row in tqdm(df_periodos.itertuples(), total=len(df_periodos), desc="Procesando Períodos"):
    nombre_periodo = row.Nombre
    nombre_carpeta = sanitize_filename(nombre_periodo)
    carpeta_periodo = DATA_DIR_RAW / nombre_carpeta
    ruta_input_diputados = carpeta_periodo / "diputados.csv"
    ruta_output_bio = carpeta_periodo / "diputados_bio.csv"

    logging.info(f"--- Procesando Período: {nombre_periodo} ---")

    # --- Chequeos ---
    if not ruta_input_diputados.exists():
        logging.warning(f"Saltando período: No se encontró archivo de diputados en {ruta_input_diputados}")
        continue
    if ruta_output_bio.exists():
        logging.info(f"Saltando período: El archivo 'diputados_bio.csv' ya existe.")
        continue

    try:
        # --- 1. Cargar Datos y Crear 'nombre_completo' ---
        df_diputados = pd.read_csv(ruta_input_diputados)
        logging.info(f"Cargados {len(df_diputados)} diputados.")

        try:
            cols_nombre = ['Diputado.Nombre', 'Diputado.ApellidoPaterno', 'Diputado.ApellidoMaterno']
            df_diputados['nombre_completo'] = (
                df_diputados[cols_nombre[0]].astype(str) + ' ' + 
                df_diputados[cols_nombre[1]].astype(str) + ' ' + 
                df_diputados[cols_nombre[2]].astype(str)
            )
            df_diputados['nombre_completo'] = df_diputados['nombre_completo'].str.replace('nan', '', case=False).str.strip().str.replace(r'\s+', ' ', regex=True)
            logging.info("Columna 'nombre_completo' creada.")
        except KeyError as e:
            logging.error(f"ERROR: Faltan columnas de nombre clave {e}. No se puede hacer fuzzy matching.")
            continue 

        # --- 2. OPTIMIZACIÓN DE MATCHING ---
        logging.info("Optimizando: Creando lista de nombres únicos...")
        
        # Obtenemos los nombres únicos del DataFrame de diputados
        nombres_unicos = df_diputados['nombre_completo'].unique()
        logging.info(f"Se encontraron {len(nombres_unicos)} nombres únicos para {len(df_diputados)} filas.")
        
        df_queries = pd.DataFrame(nombres_unicos, columns=['nombre_completo'])

        tqdm.pandas(desc="Fuzzy Matching (Únicos)")
        match_results = df_queries['nombre_completo'].progress_apply(
            lambda nombre_query: find_best_match_bcn(
                nombre_query, 
                choices_bcn, 
                threshold=FUZZY_MATCH_THRESHOLD
            )
        )
        
        df_match = pd.DataFrame(
            match_results.tolist(), 
            index=df_queries.index, 
            columns=['match_nombre_bcn', 'match_score']
        )
        
        df_lookup_final = df_queries.join(df_match)
        df_lookup_final['url_wiki'] = df_lookup_final['match_nombre_bcn'].map(url_map_bcn)

        # --- 3. MAPEO DE VUELTA ---
        df_dip_matched = (pd.merge(
            df_diputados,
            df_lookup_final,
            on='nombre_completo',
            how='left' # Mantiene todos los diputados originales
        ).drop_duplicates(subset=['nombre_completo']))
        # --- 4. Scraping ---
        logging.info("Iniciando scraping de biografías BCN...")
        scraped_data_list = df_dip_matched['url_wiki'].progress_apply(
            lambda url: scrape_bcn_bio_data(url, lista_periodos_validos)
        )
        df_scraped = pd.DataFrame(scraped_data_list.tolist(), index=df_dip_matched.index)
        df_dip_scraped = df_dip_matched.join(df_scraped)
        display(df_dip_scraped.head(3))
        # --- 5. Extracción LLM ---
        logging.info("Iniciando extracción con LLM (Ollama)...")
        if ollama_client:
            bio_data_list = df_dip_scraped['bio_texto_completo'].progress_apply(
                lambda x: extract_bio_data_llm(ollama_client, x, OLLAMA_MODEL)
            )
            df_bio_extraida = pd.DataFrame(
                [data if isinstance(data, dict) else {} for data in bio_data_list],
                index=df_dip_scraped.index
            )
            df_final_enriquecido = pd.concat([df_dip_scraped, df_bio_extraida], axis=1)
        else:
            logging.warning("Omitiendo extracción LLM (cliente no disponible).")
            df_final_enriquecido = df_dip_scraped

        # --- 6. Guardar ---
        df_final_enriquecido.to_csv(ruta_output_bio, index=False, encoding="utf-8")
        logging.info(f"Guardado exitosamente: {ruta_output_bio}")

    except Exception as e:
        logging.error(f"ERROR FATAL al procesar período {nombre_periodo}: {e}", exc_info=True)

logging.info("--- Enriquecimiento biográfico finalizado ---")
# Out:
# 2025-10-25 22:46:16,514 - INFO - Iniciando enriquecimiento biográfico para 10 períodos...
# Procesando Períodos:   0%|          | 0/10 [00:00<?, ?it/s]
# 2025-10-25 22:46:16,527 - INFO - --- Procesando Período: 1965-1969 ---
# 2025-10-25 22:46:16,528 - WARNING - Saltando período: No se encontró archivo de diputados en C:\Users\angel\OneDrive\Documents\U\2025-2\Proyecto de Grado\Legislative-Voting-Behavior-Prediction-\data\01_raw\1965-1969\diputados.csv
# 2025-10-25 22:46:16,529 - INFO - --- Procesando Período: 1990-1994 ---
# 2025-10-25 22:46:16,530 - WARNING - Saltando período: No se encontró archivo de diputados en C:\Users\angel\OneDrive\Documents\U\2025-2\Proyecto de Grado\Legislative-Voting-Behavior-Prediction-\data\01_raw\1990-1994\diputados.csv
# 2025-10-25 22:46:16,531 - INFO - --- Procesando Período: 1994-1998 ---
# 2025-10-25 22:46:16,532 - WARNING - Saltando período: No se encontró archivo de diputados en C:\Users\angel\OneDrive\Documents\U\2025-2\Proyecto de Grado\Legislative-Voting-Behavior-Prediction-\data\01_raw\1994-1998\diputados.csv
# 2025-10-25 22:46:16,532 - INFO - --- Procesando Período: 1998-2002 ---
# 2025-10-25 22:46:16,533 - INFO - Saltando período: El archivo 'diputados_bio.csv' ya existe.
# 2025-10-25 22:46:16,534 - INFO - --- Procesando Período: 2002-2006 ---
# 2025-10-25 22:46:16,535 - INFO - Saltando período: El archivo 'diputados_bio.csv' ya existe.
# 2025-10-25 22:46:16,535 - INFO - --- Procesando Período: 2006-2010 ---
# 2025-10-25 22:46:16,536 - INFO - Saltando período: El archivo 'diputados_bio.csv' ya existe.
# 2025-10-25 22:46:16,536 - INFO - --- Procesando Período: 2010-2014 ---
# 2025-10-25 22:46:16,537 - INFO - Saltando período: El archivo 'diputados_bio.csv' ya existe.
# 2025-10-25 22:46:16,537 - INFO - --- Procesando Período: 2014-2018 ---
# 2025-10-25 22:46:16,546 - INFO - Cargados 394 diputados.
# 2025-10-25 22:46:16,550 - INFO - Columna 'nombre_completo' creada.
# 2025-10-25 22:46:16,551 - INFO - Optimizando: Creando lista de nombres únicos...
# 2025-10-25 22:46:16,552 - INFO - Se encontraron 121 nombres únicos para 394 filas.
# Fuzzy Matching (Únicos):   0%|          | 0/121 [00:00<?, ?it/s]
# 2025-10-25 22:46:17,042 - INFO - Iniciando scraping de biografías BCN...
# Fuzzy Matching (Únicos):   0%|          | 0/121 [00:00<?, ?it/s]
#    FechaInicio  FechaTermino  Diputado.Id Diputado.Nombre  Diputado.Nombre2  \
# 0   2018-03-10           NaN          177          Felipe               NaN
# 4   2018-03-10           NaN          802          Sergio               NaN
# 11  2018-03-10           NaN          811           Ramón               NaN
#
#    Diputado.ApellidoPaterno Diputado.ApellidoMaterno Diputado.FechaNacimiento  \
# 0                  Letelier               Norambuena               1956-05-11
# 4                    Aguiló                     Melo               1953-02-09
# 11                   Barros                  Montero               1958-03-05
#
#     Diputado.FechaDefucion  Diputado.RUT  ...  Partido.Alias  \
# 0                      NaN           NaN  ...            PPD
# 4                      NaN           NaN  ...             PS
# 11                     NaN           NaN  ...            UDI
#
#                nombre_completo            match_nombre_bcn match_score  \
# 0   Felipe Letelier Norambuena  Letelier Norambuena Felipe       100.0
# 4           Sergio Aguiló Melo          Aguiló Melo Sergio       100.0
# 11        Ramón Barros Montero  Barros Montero Ramón  José       100.0
#
#                                              url_wiki status distrito  \
# 0   https://www.bcn.cl/historiapolitica/resenas_pa...    200       33
# 4   https://www.bcn.cl/historiapolitica/resenas_pa...    200       37
# 11  https://www.bcn.cl/historiapolitica/resenas_pa...    200       16
#
#                             familia_juventud_parrafos  \
# 0   [Nació en Parral, el 11 de mayo de 1956. Hijo ...
# 4   [Nació el 9 de febrero de 1953 en Santiago. Hi...
# 11  [Nació el 5 de marzo de 1958, en Santiago. Hij...
#
#                        estudios_vida_laboral_parrafos  \
# 0                                                  []
# 4   [Realizó su formación primaria en el Instituto...
# 11  [Realizó sus estudios primarios y secundarios ...
#
#                                    bio_texto_completo
# 0   Nació en Parral, el 11 de mayo de 1956. Hijo d...
# 4   Nació el 9 de febrero de 1953 en Santiago. Hij...
# 11  Nació el 5 de marzo de 1958, en Santiago. Hijo...
#
# [3 rows x 30 columns]
# 2025-10-25 22:47:06,195 - INFO - Iniciando extracción con LLM (Ollama)...
# Fuzzy Matching (Únicos):   0%|          | 0/121 [00:00<?, ?it/s]
# 2025-10-25 22:47:41,044 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:48:09,728 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:48:31,328 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:48:55,386 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:49:33,229 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:50:09,971 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:50:41,295 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:51:08,562 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:51:48,133 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:52:08,917 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:52:38,791 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:53:11,155 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:53:47,896 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:54:19,309 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:54:47,039 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:55:17,782 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:55:45,869 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:56:15,730 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:57:00,449 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:57:18,537 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:57:40,134 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:58:12,720 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:58:39,319 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:59:04,769 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 22:59:38,926 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:00:03,489 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:00:34,429 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:01:07,256 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:01:43,681 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:02:14,062 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:02:57,008 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:04:07,445 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:04:42,403 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:05:37,566 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:06:51,327 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:07:25,683 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:08:05,241 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:08:31,091 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:08:55,303 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:09:21,871 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:09:58,986 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:10:16,313 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:10:48,405 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:11:20,981 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:11:47,037 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:12:12,709 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:13:33,534 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:14:07,031 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:14:41,104 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:15:03,842 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:15:35,406 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:15:57,649 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:16:30,438 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:16:55,245 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:17:25,380 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:17:53,095 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:18:27,688 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:18:54,563 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:19:25,546 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:20:10,773 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:20:42,436 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:21:03,960 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:21:34,067 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:22:12,037 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:22:46,126 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:23:08,621 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:23:49,822 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:24:18,825 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:24:47,323 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:25:11,397 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:25:38,160 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:26:03,561 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:26:34,832 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:27:19,822 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:27:48,342 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:28:23,826 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:29:00,536 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:29:48,765 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:30:23,511 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:30:47,444 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:31:22,930 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:31:47,488 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:32:08,335 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:32:37,787 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:33:22,615 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:33:42,371 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:34:08,675 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:34:31,541 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:34:53,712 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:35:15,994 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:35:37,946 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:36:01,013 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:36:30,176 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:36:58,345 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:37:21,460 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:38:02,343 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:38:33,019 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:38:59,628 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:39:29,988 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:39:57,138 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:40:27,448 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:40:58,394 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:41:25,883 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:41:46,333 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:42:07,598 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:42:40,784 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:43:20,403 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:43:57,182 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:44:21,212 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:44:59,469 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:45:33,746 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:46:02,277 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:46:40,226 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:47:12,421 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:47:43,251 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:48:06,833 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:48:30,137 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:48:55,023 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:49:30,346 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:49:49,389 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:50:22,854 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:50:22,873 - INFO - Guardado exitosamente: C:\Users\angel\OneDrive\Documents\U\2025-2\Proyecto de Grado\Legislative-Voting-Behavior-Prediction-\data\01_raw\2014-2018\diputados_bio.csv
# 2025-10-25 23:50:22,875 - INFO - --- Procesando Período: 2018-2022 ---
# 2025-10-25 23:50:22,881 - INFO - Cargados 460 diputados.
# 2025-10-25 23:50:22,885 - INFO - Columna 'nombre_completo' creada.
# 2025-10-25 23:50:22,885 - INFO - Optimizando: Creando lista de nombres únicos...
# 2025-10-25 23:50:22,887 - INFO - Se encontraron 163 nombres únicos para 460 filas.
# Fuzzy Matching (Únicos):   0%|          | 0/163 [00:00<?, ?it/s]
# 2025-10-25 23:50:23,527 - INFO - Iniciando scraping de biografías BCN...
# Fuzzy Matching (Únicos):   0%|          | 0/163 [00:00<?, ?it/s]
#             FechaInicio  FechaTermino  Distrito  Diputado.Id Diputado.Nombre  \
# 0   2022-03-10 23:59:59           NaN       NaN           74           Jaime
# 6   2022-03-10 23:59:59           NaN       NaN          172          Carlos
# 11  2022-03-10 23:59:59           NaN       NaN          660          Manuel
#
#     Diputado.Nombre2 Diputado.ApellidoPaterno Diputado.ApellidoMaterno  \
# 0                NaN                  Naranjo                    Ortiz
# 6                NaN                  Kuschel                    Silva
# 11               NaN                    Matta                   Aragay
#
#    Diputado.FechaNacimiento  Diputado.FechaDefucion  ...  Partido.Alias  \
# 0                1951-01-12                     NaN  ...             PS
# 6                1953-03-16                     NaN  ...             RN
# 11               1946-11-10                     NaN  ...             DC
#
#          nombre_completo                match_nombre_bcn  match_score  \
# 0    Jaime Naranjo Ortiz             Naranjo Ortiz Jaime        100.0
# 6   Carlos Kuschel Silva    Kuschel Silva Carlos Ignacio        100.0
# 11   Manuel Matta Aragay  Matta Aragay Manuel José Ramón        100.0
#
#                                              url_wiki status distrito  \
# 0   https://www.bcn.cl/historiapolitica/resenas_pa...    200       18
# 6   https://www.bcn.cl/historiapolitica/resenas_pa...    200       26
# 11  https://www.bcn.cl/historiapolitica/resenas_pa...    200       18
#
#                             familia_juventud_parrafos  \
# 0   [Nació el 12 de enero de 1951, en Melipilla., ...
# 6   [Nació en el 16 de marzo de 1953 en Frutillar....
# 11  [Nació en Talca 10 de noviembre de 1946. Hijo ...
#
#                        estudios_vida_laboral_parrafos  \
# 0   [Cursó sus estudios primarios en el Colegio Sa...
# 6   [Realizó su enseñanza primaria en el Instituto...
# 11  [Realizó sus estudios secundarios en el Intern...
#
#                                    bio_texto_completo
# 0   Nació el 12 de enero de 1951, en Melipilla. Ca...
# 6   Nació en el 16 de marzo de 1953 en Frutillar. ...
# 11  Nació en Talca 10 de noviembre de 1946. Hijo d...
#
# [3 rows x 29 columns]
# 2025-10-25 23:53:33,613 - INFO - Iniciando extracción con LLM (Ollama)...
# Fuzzy Matching (Únicos):   0%|          | 0/163 [00:00<?, ?it/s]
# 2025-10-25 23:54:19,840 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:55:16,932 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:56:11,019 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:56:37,413 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:57:03,079 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:57:25,201 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:57:44,677 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:58:25,309 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:58:57,718 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-25 23:59:30,307 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:00:00,349 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:00:31,886 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:00:56,083 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:01:32,661 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:02:24,835 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:02:47,378 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:03:13,954 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:03:47,673 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:04:16,882 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:04:48,621 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:05:15,402 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:05:45,336 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:06:15,739 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:06:50,085 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:07:16,012 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:07:33,457 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:08:10,663 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:08:42,561 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:10:02,555 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:10:36,231 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:10:58,467 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:11:31,431 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:11:58,802 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:12:22,167 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:12:57,941 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:13:19,890 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:14:03,713 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:14:30,454 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:15:09,400 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:15:33,258 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:16:01,524 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:16:32,858 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:17:02,801 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:17:37,787 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:18:14,026 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:18:48,602 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:19:20,228 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:19:43,366 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:20:24,517 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:20:45,933 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:21:17,358 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:22:01,152 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:22:21,331 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:22:49,684 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:23:13,083 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:23:38,440 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:24:01,570 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:24:26,248 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:25:08,988 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:25:32,626 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:26:07,043 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:26:29,602 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:27:06,395 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:27:32,816 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:27:53,612 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:28:30,304 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:29:03,211 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:29:32,617 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:30:13,788 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:30:39,950 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:31:17,452 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:31:43,385 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:32:08,849 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:32:49,554 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:33:09,183 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:33:39,049 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:34:07,048 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:34:40,474 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:35:24,134 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:35:53,306 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:36:29,801 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:36:51,952 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:37:24,363 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:37:47,157 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:38:08,376 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:38:35,941 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:39:03,597 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:39:28,121 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:39:52,811 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:40:17,730 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:41:03,253 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:41:36,809 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:42:01,938 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:42:39,414 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:43:00,627 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:43:23,663 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:43:48,470 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:44:16,915 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:45:15,709 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:45:52,346 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:46:20,468 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:46:47,075 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:47:37,809 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:48:12,182 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:48:34,345 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:49:08,288 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:49:56,152 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:50:22,534 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:50:46,491 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:51:14,950 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:51:38,787 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:52:18,062 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:52:41,164 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:53:32,754 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:54:24,726 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:54:57,019 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:55:20,376 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:55:44,166 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:56:36,847 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:57:00,534 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:57:18,239 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:57:48,359 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:58:16,993 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:58:45,297 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:59:10,127 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 00:59:36,591 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:00:01,537 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:00:34,085 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:00:56,690 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:01:34,910 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:02:16,546 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:02:38,623 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:03:30,148 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:03:56,528 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:04:19,933 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:04:51,115 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:05:18,486 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:06:05,978 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:06:36,593 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:06:59,379 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:07:22,864 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:08:01,061 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:08:26,792 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:08:50,733 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:09:15,943 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:09:42,676 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:10:09,768 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:10:30,335 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:11:00,730 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:11:35,902 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:12:18,682 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:12:45,665 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:13:20,193 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:13:41,252 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:14:01,384 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:14:35,734 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:15:01,045 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:15:26,323 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:15:57,594 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:16:49,209 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:17:20,163 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:17:45,414 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:18:09,725 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 2025-10-26 01:18:09,743 - INFO - Guardado exitosamente: C:\Users\angel\OneDrive\Documents\U\2025-2\Proyecto de Grado\Legislative-Voting-Behavior-Prediction-\data\01_raw\2018-2022\diputados_bio.csv
# 2025-10-26 01:18:09,744 - INFO - --- Procesando Período: 2022-2026 ---
# 2025-10-26 01:18:09,746 - INFO - Saltando período: El archivo 'diputados_bio.csv' ya existe.
# 2025-10-26 01:18:09,748 - INFO - --- Enriquecimiento biográfico finalizado ---
